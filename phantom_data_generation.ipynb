# %%
import numpy as np
import skimage.draw
import skimage.data
import skimage.transform
import matplotlib.pyplot as plt

# %%
def generate_phantom(image_size, n_shapes, min_size, max_size, pad=8, seed=None):
    '''
    Generate random stiffness and texture images.
    '''
    np.random.seed(seed)

    n_textures = 4
    texture_map = np.random.permutation(n_textures)
    texture_sources = [
        skimage.transform.resize(skimage.data.grass(), image_size),
        skimage.transform.resize(skimage.data.brick(), image_size),
        skimage.transform.resize(skimage.data.gravel(), image_size),
        skimage.transform.resize(skimage.data.text(), image_size)
    ]

    stiffness_map = np.random.permutation(4)
    stiffness_values = [2e3, 4e3, 8e3, 16e3]
    background_stiffness = 1e3

    redraw_shapes = True
    while redraw_shapes:
        print('\ndrawing random shapes')
        image, labels = skimage.draw.random_shapes(
            image_shape=image_size,
            min_shapes=n_shapes,
            max_shapes=n_shapes,
            min_size=min_size,
            max_size=max_size,
            channel_axis=None,
            intensity_range=(1, n_textures),
            allow_overlap=False,
            rng=seed
        )
        redraw_shapes = False
        if len(labels) < n_shapes:
            redraw_shapes = True
        for i, (category, bbox) in enumerate(labels):
            print(category, bbox)
            if category == 'triangle':
                redraw_shapes = True
            elif check_boundary_overlap(bbox, image_size, pad):
                redraw_shapes = True
            for j in range(i + 1, len(labels)):
                if check_bbox_overlap(bbox, labels[j][1], pad):
                    redraw_shapes = True

    # set background value to 0
    image = np.where(image == 255, 0, image)

    # assign textures
    texture_image = np.zeros_like(image)
    for i in range(n_textures):
        texture_source = texture_sources[texture_map[i]]
        texture_image = np.where(image == i + 1, texture_source, texture_image)

    # assign stiffness
    stiffness_image = np.ones_like(image) * background_stiffness
    for i in range(n_textures):
        stiffness_value = stiffness_values[stiffness_map[i]]
        stiffness_image = np.where(image == i + 1, stiffness_value, stiffness_image)

    # simulate displacement
    wave_image = solve_forward_problem(stiffness_image)

    return image, labels, texture_image, stiffness_image, wave_image


def check_boundary_overlap(bbox, image_size, pad=0):
    row_interval, col_interval = bbox
    height, width = image_size
    return (
        row_interval[0] < pad or
        col_interval[0] < pad or
        row_interval[1] >= height - pad or
        col_interval[1] >= width - pad
    )


def check_bbox_overlap(bbox1, bbox2, pad=0):
    row_interval1, col_interval1 = bbox1
    row_interval2, col_interval2 = bbox2
    return (
        check_interval_overlap(row_interval1, row_interval2, pad) and
        check_interval_overlap(col_interval1, col_interval2, pad)
    )


def check_interval_overlap(a, b, pad=0):
    overlap = (max(a[0], b[0]), min(a[1], b[1]))
    return overlap[0] < overlap[1] + pad


def solve_forward_problem(mu):
    return (mu - 2000)**2 / 1000

# %%
image, labels, texture, mu, u = generate_phantom(
    (128, 128),
    n_shapes=3,
    min_size=20,
    max_size=100
)
# Out:
# drawing random shapes
# triangle ((25, 45), (47, 69))
# triangle ((47, 101), (0, 62))
# circle ((89, 126), (64, 101))
#
# drawing random shapes
# ellipse ((48, 101), (15, 64))
# rectangle ((76, 101), (65, 121))
# circle ((47, 66), (89, 108))
#
# drawing random shapes
# triangle ((50, 93), (61, 110))
# triangle ((42, 80), (14, 57))
# circle ((5, 30), (66, 91))
#
# drawing random shapes
# ellipse ((49, 116), (46, 107))
# ellipse ((64, 93), (7, 46))
# triangle ((21, 42), (25, 48))
#
# drawing random shapes
# ellipse ((8, 41), (66, 97))
# circle ((85, 124), (76, 115))
# triangle ((13, 39), (20, 49))
#
# drawing random shapes
# triangle ((-8, 10), (36, 56))
# rectangle ((67, 91), (93, 127))
# circle ((65, 90), (46, 71))
#
# drawing random shapes
# triangle ((9, 30), (6, 30))
# circle ((47, 126), (40, 119))
# circle ((7, 34), (80, 107))
#
# drawing random shapes
# triangle ((71, 91), (99, 121))
# circle ((18, 79), (7, 68))
# circle ((11, 30), (75, 94))
#
# drawing random shapes
# rectangle ((106, 126), (101, 127))
# rectangle ((42, 106), (55, 82))
# ellipse ((27, 56), (93, 116))
#
# drawing random shapes
# triangle ((26, 54), (9, 41))
# circle ((2, 57), (61, 116))
# rectangle ((86, 108), (53, 73))
#
# drawing random shapes
# ellipse ((48, 109), (62, 115))
# rectangle ((94, 121), (37, 58))
# rectangle ((1, 39), (77, 116))
#
# drawing random shapes
# circle ((72, 127), (68, 123))
# triangle ((49, 67), (95, 115))
# ellipse ((19, 58), (9, 40))
#
# drawing random shapes
# triangle ((47, 86), (6, 50))
# ellipse ((40, 99), (54, 115))
# rectangle ((94, 125), (0, 34))
#
# drawing random shapes
# ellipse ((74, 99), (4, 41))
# ellipse ((12, 45), (34, 83))
# triangle ((-12, 6), (3, 23))
#
# drawing random shapes
# circle ((86, 123), (64, 101))
# triangle ((-9, 9), (15, 35))
# circle ((52, 85), (80, 113))
#
# drawing random shapes
# ellipse ((74, 99), (3, 28))
# triangle ((32, 59), (83, 113))
# rectangle ((7, 84), (38, 79))
#
# drawing random shapes
# ellipse ((57, 102), (1, 52))
# circle ((3, 22), (81, 100))
# triangle ((-7, 11), (102, 122))
#
# drawing random shapes
# ellipse ((1, 24), (93, 116))
# triangle ((18, 65), (10, 64))
# triangle ((50, 73), (96, 122))
#
# drawing random shapes
# circle ((32, 75), (7, 50))
# triangle ((33, 58), (73, 101))
# circle ((96, 117), (14, 35))
#
# drawing random shapes
# triangle ((10, 37), (97, 127))
# triangle ((-3, 15), (16, 36))
# rectangle ((48, 93), (31, 84))
#
# drawing random shapes
# rectangle ((1, 81), (91, 115))
# ellipse ((42, 128), (23, 70))
# rectangle ((89, 116), (87, 126))
#
# drawing random shapes
# ellipse ((70, 101), (77, 124))
# ellipse ((7, 46), (72, 111))
# circle ((78, 103), (3, 28))
#
# drawing random shapes
# rectangle ((74, 114), (56, 108))
# rectangle ((21, 72), (8, 58))
# circle ((21, 74), (71, 124))
#
# drawing random shapes
# ellipse ((58, 121), (68, 93))
# circle ((39, 74), (19, 54))
# triangle ((59, 77), (106, 126))
#
# drawing random shapes
# triangle ((28, 49), (56, 79))
# rectangle ((104, 124), (48, 73))
# triangle ((61, 89), (94, 126))
#
# drawing random shapes
# rectangle ((89, 121), (75, 109))
# ellipse ((1, 30), (35, 56))
# rectangle ((12, 70), (64, 110))
#
# drawing random shapes
# rectangle ((100, 122), (92, 119))
# ellipse ((5, 74), (30, 93))
# triangle ((-13, 5), (70, 90))
#
# drawing random shapes
# ellipse ((3, 30), (43, 70))
# rectangle ((41, 61), (58, 122))
# rectangle ((66, 108), (64, 114))
#
# drawing random shapes
# circle ((90, 123), (91, 124))
# rectangle ((22, 51), (55, 107))
# circle ((54, 89), (24, 59))
#
# drawing random shapes
# rectangle ((0, 21), (91, 111))
# rectangle ((81, 101), (13, 56))
# ellipse ((0, 25), (23, 46))
#
# drawing random shapes
# circle ((74, 127), (41, 94))
# triangle ((-4, 14), (7, 27))
# triangle ((-2, 16), (61, 81))
#
# drawing random shapes
# triangle ((30, 57), (34, 65))
# triangle ((3, 21), (46, 66))
# circle ((17, 40), (4, 27))
#
# drawing random shapes
# rectangle ((5, 73), (60, 115))
# triangle ((12, 34), (33, 58))
# ellipse ((78, 103), (32, 83))
#
# drawing random shapes
# ellipse ((30, 59), (2, 31))
# ellipse ((65, 116), (3, 52))
# triangle ((36, 57), (53, 77))
#
# drawing random shapes
# triangle ((6, 32), (18, 47))
# ellipse ((64, 107), (83, 104))
# circle ((59, 106), (19, 66))
#
# drawing random shapes
# circle ((86, 121), (19, 54))
# ellipse ((15, 74), (47, 104))
# rectangle ((101, 126), (56, 102))
#
# drawing random shapes
# rectangle ((88, 118), (78, 116))
# triangle ((13, 55), (54, 102))
# ellipse ((36, 85), (13, 56))
#
# drawing random shapes
# circle ((3, 22), (21, 40))
# ellipse ((50, 71), (0, 21))
# ellipse ((76, 115), (32, 79))
#
# drawing random shapes
# circle ((42, 65), (31, 54))
# ellipse ((17, 50), (91, 122))
# circle ((81, 124), (84, 127))
#
# drawing random shapes
# circle ((77, 120), (55, 98))
# triangle ((16, 49), (58, 95))
# triangle ((43, 70), (87, 118))
#
# drawing random shapes
# ellipse ((68, 125), (67, 116))
# circle ((18, 53), (82, 117))
# triangle ((9, 34), (22, 50))
#
# drawing random shapes
# triangle ((43, 69), (91, 120))
# circle ((85, 112), (78, 105))
# circle ((17, 74), (24, 81))
#
# drawing random shapes
# triangle ((24, 92), (25, 103))
# triangle ((-4, 14), (36, 56))
# triangle ((0, 18), (107, 127))
#
# drawing random shapes
# ellipse ((42, 93), (9, 60))
# ellipse ((6, 31), (5, 34))
# circle ((10, 55), (56, 101))
#
# drawing random shapes
# triangle ((46, 97), (4, 62))
# ellipse ((2, 23), (44, 67))
# rectangle ((79, 125), (65, 98))
#
# drawing random shapes
# ellipse ((16, 49), (68, 113))
# circle ((71, 94), (75, 98))
# ellipse ((5, 32), (12, 43))
#
# drawing random shapes
# circle ((20, 95), (12, 87))
# ellipse ((0, 21), (69, 90))
# rectangle ((18, 45), (104, 127))
#
# drawing random shapes
# triangle ((4, 22), (87, 107))
# ellipse ((3, 72), (0, 69))
# circle ((66, 115), (48, 97))
#
# drawing random shapes
# rectangle ((47, 89), (53, 76))
# circle ((81, 126), (77, 122))
# ellipse ((72, 115), (6, 39))
#
# drawing random shapes
# rectangle ((34, 65), (49, 106))
# circle ((11, 30), (97, 116))
# circle ((91, 114), (91, 114))
#
# drawing random shapes
# circle ((26, 89), (60, 123))
# triangle ((-17, 1), (10, 30))
# ellipse ((81, 106), (6, 49))
#
# drawing random shapes
# ellipse ((32, 67), (22, 59))
# triangle ((62, 82), (102, 124))
# rectangle ((77, 98), (66, 87))
#
# drawing random shapes
# ellipse ((16, 43), (51, 102))
# triangle ((87, 108), (98, 122))
# rectangle ((55, 124), (26, 64))
#
# drawing random shapes
# triangle ((57, 79), (61, 86))
# rectangle ((25, 111), (90, 110))
# circle ((89, 110), (16, 37))
#
# drawing random shapes
# ellipse ((0, 39), (66, 95))
# ellipse ((33, 54), (25, 64))
# triangle ((47, 91), (39, 89))
#
# drawing random shapes
# rectangle ((8, 97), (80, 100))
# triangle ((27, 61), (0, 39))
# circle ((16, 45), (41, 70))
#
# drawing random shapes
# rectangle ((79, 113), (54, 87))
# circle ((49, 70), (97, 118))
# triangle ((29, 52), (20, 46))
#
# drawing random shapes
# ellipse ((9, 42), (1, 34))
# rectangle ((77, 113), (94, 121))
# circle ((89, 116), (13, 40))
#
# drawing random shapes
# triangle ((66, 91), (85, 113))
# rectangle ((74, 111), (20, 74))
# circle ((8, 29), (29, 50))
#
# drawing random shapes
# ellipse ((57, 110), (39, 86))
# circle ((29, 54), (90, 115))
# ellipse ((57, 82), (87, 118))
#
# drawing random shapes
# triangle ((20, 52), (49, 85))
# circle ((86, 127), (75, 116))
# ellipse ((53, 92), (7, 40))
#
# drawing random shapes
# circle ((21, 68), (5, 52))
# circle ((35, 70), (63, 98))
# ellipse ((0, 25), (95, 116))
#
# drawing random shapes
# rectangle ((80, 126), (61, 96))
# ellipse ((25, 46), (0, 21))
# rectangle ((28, 51), (100, 125))
#
# drawing random shapes
# rectangle ((104, 126), (7, 79))
# ellipse ((2, 27), (69, 92))
# triangle ((69, 108), (83, 127))
#
# drawing random shapes
# triangle ((75, 108), (68, 105))
# ellipse ((1, 26), (32, 55))
# triangle ((6, 29), (56, 82))
#
# drawing random shapes
# ellipse ((50, 77), (80, 105))
# triangle ((6, 26), (4, 26))
# circle ((13, 42), (40, 69))
#
# drawing random shapes
# triangle ((65, 90), (25, 53))
# circle ((58, 81), (3, 26))
# ellipse ((12, 49), (13, 60))
#
# drawing random shapes
# rectangle ((67, 124), (84, 109))
# circle ((28, 61), (71, 104))
# ellipse ((65, 90), (1, 26))
#
# drawing random shapes
# ellipse ((33, 82), (38, 107))
# rectangle ((82, 125), (61, 120))
# circle ((25, 44), (18, 37))
#
# drawing random shapes
# triangle ((-6, 12), (51, 71))
# ellipse ((3, 68), (68, 125))
# rectangle ((26, 121), (2, 56))
#
# drawing random shapes
# circle ((70, 125), (29, 84))
# rectangle ((23, 50), (105, 126))
# circle ((13, 38), (67, 92))
#
# drawing random shapes
# rectangle ((29, 68), (15, 102))
# triangle ((11, 29), (106, 126))
# circle ((73, 94), (33, 54))
#
# drawing random shapes
# ellipse ((89, 114), (53, 106))
# circle ((24, 45), (90, 111))
# triangle ((42, 65), (63, 89))
#
# drawing random shapes
# circle ((19, 42), (32, 55))
# rectangle ((47, 69), (42, 107))
# circle ((43, 66), (13, 36))
#
# drawing random shapes
# ellipse ((10, 51), (17, 48))
# triangle ((9, 27), (59, 79))
# circle ((80, 101), (4, 25))
#
# drawing random shapes
# triangle ((-1, 17), (81, 101))
# ellipse ((80, 113), (83, 116))
# rectangle ((79, 100), (1, 52))
#
# drawing random shapes
# triangle ((35, 98), (21, 93))
# rectangle ((37, 118), (94, 123))
# circle ((23, 48), (10, 35))
#
# drawing random shapes
# triangle ((-13, 5), (1, 21))
# ellipse ((55, 112), (20, 73))
# rectangle ((29, 116), (104, 124))
#
# drawing random shapes
# ellipse ((45, 106), (34, 115))
# rectangle ((45, 77), (106, 127))
# ellipse ((24, 49), (3, 30))
#
# drawing random shapes
# triangle ((1, 19), (2, 22))
# rectangle ((42, 112), (41, 78))
# triangle ((24, 47), (12, 38))
#
# drawing random shapes
# ellipse ((25, 72), (55, 108))
# ellipse ((63, 110), (27, 70))
# rectangle ((43, 63), (17, 45))
#
# drawing random shapes
# circle ((82, 127), (49, 94))
# rectangle ((38, 61), (76, 111))
# ellipse ((73, 110), (1, 42))
#
# drawing random shapes
# rectangle ((70, 104), (53, 89))
# triangle ((-15, 3), (92, 112))
# rectangle ((45, 65), (61, 84))
#
# drawing random shapes
# triangle ((31, 75), (25, 75))
# circle ((52, 91), (87, 126))
# rectangle ((21, 60), (7, 34))
#
# drawing random shapes
# circle ((54, 75), (17, 38))
# triangle ((46, 71), (61, 89))
# rectangle ((78, 101), (105, 125))
#
# drawing random shapes
# triangle ((9, 28), (12, 33))
# rectangle ((61, 92), (44, 113))
# ellipse ((5, 30), (90, 117))
#
# drawing random shapes
# ellipse ((33, 76), (48, 89))
# triangle ((2, 20), (62, 82))
# ellipse ((62, 99), (10, 49))
#
# drawing random shapes
# circle ((77, 118), (18, 59))
# circle ((6, 63), (28, 85))
# rectangle ((67, 111), (74, 116))
#
# drawing random shapes
# circle ((65, 98), (6, 39))
# ellipse ((9, 36), (68, 105))
# circle ((32, 53), (7, 28))
#
# drawing random shapes
# rectangle ((70, 122), (77, 116))
# circle ((2, 23), (18, 39))
# circle ((19, 70), (67, 118))
#
# drawing random shapes
# circle ((94, 117), (76, 99))
# rectangle ((10, 35), (104, 127))
# ellipse ((49, 78), (14, 41))
#
# drawing random shapes
# triangle ((10, 34), (66, 93))
# rectangle ((13, 98), (7, 42))
# ellipse ((55, 112), (53, 126))
#
# drawing random shapes
# rectangle ((72, 112), (57, 112))
# rectangle ((88, 121), (5, 48))
# triangle ((63, 85), (22, 47))
#
# drawing random shapes
# rectangle ((64, 120), (56, 81))
# ellipse ((33, 60), (54, 125))
# ellipse ((3, 26), (68, 95))
#
# drawing random shapes
# ellipse ((47, 84), (8, 39))
# circle ((54, 103), (76, 125))
# circle ((14, 53), (58, 97))
#
# drawing random shapes
# circle ((85, 108), (2, 25))
# ellipse ((25, 66), (23, 58))
# circle ((84, 127), (54, 97))
#
# drawing random shapes
# ellipse ((16, 87), (59, 128))
# circle ((43, 68), (17, 42))
# circle ((3, 28), (33, 58))
#
# drawing random shapes
# circle ((54, 123), (8, 77))
# circle ((2, 23), (61, 82))
# rectangle ((23, 116), (96, 119))
#
# drawing random shapes
# ellipse ((24, 113), (22, 119))
# ellipse ((78, 99), (0, 21))
# triangle ((-5, 13), (73, 93))
#
# drawing random shapes
# rectangle ((94, 114), (99, 123))
# triangle ((58, 85), (62, 93))
# circle ((14, 47), (2, 35))
#
# drawing random shapes
# triangle ((-6, 12), (25, 45))
# rectangle ((102, 123), (106, 126))
# rectangle ((32, 88), (57, 126))
#
# drawing random shapes
# rectangle ((52, 79), (42, 127))
# rectangle ((87, 124), (4, 49))
# circle ((7, 32), (39, 64))
#
# drawing random shapes
# rectangle ((103, 124), (83, 110))
# circle ((51, 90), (12, 51))
# circle ((92, 111), (16, 35))
#
# drawing random shapes
# circle ((41, 94), (10, 63))
# triangle ((11, 35), (61, 88))
# circle ((38, 61), (81, 104))
#
# drawing random shapes
# triangle ((79, 106), (95, 125))
# rectangle ((53, 97), (17, 44))
# ellipse ((0, 27), (8, 31))
#
# drawing random shapes
# rectangle ((16, 49), (57, 127))
# triangle ((75, 105), (90, 124))
# ellipse ((54, 85), (20, 49))
#
# drawing random shapes
# triangle ((1, 19), (2, 22))
# ellipse ((39, 114), (20, 105))
# rectangle ((100, 127), (102, 126))
#
# drawing random shapes
# ellipse ((80, 103), (0, 25))
# triangle ((7, 36), (71, 104))
# circle ((2, 21), (94, 113))
#
# drawing random shapes
# rectangle ((99, 119), (104, 125))
# rectangle ((47, 122), (34, 56))
# triangle ((6, 31), (73, 101))
#
# drawing random shapes
# triangle ((42, 81), (51, 95))
# rectangle ((99, 126), (82, 123))
# ellipse ((53, 82), (4, 27))
#
# drawing random shapes
# circle ((19, 96), (12, 89))
# ellipse ((10, 33), (87, 118))
# rectangle ((105, 126), (103, 123))
#
# drawing random shapes
# circle ((46, 123), (37, 114))
# circle ((4, 43), (63, 102))
# triangle ((19, 47), (31, 63))
#
# drawing random shapes
# ellipse ((31, 78), (3, 72))
# rectangle ((61, 83), (75, 111))
# circle ((5, 40), (68, 103))
#
# drawing random shapes
# triangle ((59, 107), (68, 123))
# rectangle ((38, 66), (8, 60))
# circle ((34, 57), (63, 86))
#
# drawing random shapes
# ellipse ((90, 113), (40, 91))
# circle ((2, 21), (38, 57))
# rectangle ((23, 56), (107, 127))
#
# drawing random shapes
# rectangle ((40, 125), (107, 127))
# circle ((69, 90), (25, 46))
# rectangle ((94, 121), (58, 89))
#
# drawing random shapes
# ellipse ((56, 111), (32, 81))
# rectangle ((62, 86), (97, 126))
# circle ((5, 44), (74, 113))
#
# drawing random shapes
# circle ((37, 58), (45, 66))
# ellipse ((10, 37), (48, 91))
# triangle ((30, 62), (79, 115))
#
# drawing random shapes
# ellipse ((28, 59), (10, 33))
# ellipse ((9, 54), (47, 84))
# triangle ((37, 75), (19, 62))
#
# drawing random shapes
# rectangle ((102, 124), (3, 56))
# ellipse ((1, 22), (50, 71))
# triangle ((18, 36), (59, 79))
#
# drawing random shapes
# ellipse ((69, 90), (0, 23))
# rectangle ((47, 103), (92, 124))
# rectangle ((45, 84), (40, 81))
#
# drawing random shapes
# circle ((10, 29), (62, 81))
# triangle ((-9, 9), (63, 83))
# triangle ((47, 66), (52, 73))
#
# drawing random shapes
# ellipse ((4, 47), (83, 114))
# circle ((51, 124), (15, 88))
# circle ((24, 45), (4, 25))
#
# drawing random shapes
# ellipse ((84, 119), (8, 45))
# circle ((13, 32), (71, 90))
# triangle ((21, 57), (40, 81))
#
# drawing random shapes
# circle ((74, 101), (33, 60))
# ellipse ((8, 29), (15, 44))
# rectangle ((12, 74), (48, 96))
#
# drawing random shapes
# ellipse ((52, 85), (5, 40))
# triangle ((77, 104), (83, 113))
# circle ((34, 63), (70, 99))
#
# drawing random shapes
# circle ((53, 92), (55, 94))
# triangle ((58, 76), (103, 123))
# rectangle ((77, 100), (103, 124))
#
# drawing random shapes
# triangle ((23, 75), (60, 119))
# triangle ((-7, 11), (78, 98))
# rectangle ((96, 118), (48, 115))
#
# drawing random shapes
# triangle ((1, 19), (81, 101))
# triangle ((50, 102), (41, 100))
# ellipse ((17, 40), (5, 56))
#
# drawing random shapes
# rectangle ((16, 102), (105, 125))
# circle ((20, 41), (8, 29))
# ellipse ((21, 48), (52, 83))
#
# drawing random shapes
# ellipse ((34, 87), (29, 80))
# triangle ((29, 50), (100, 123))
# triangle ((78, 99), (98, 122))
#
# drawing random shapes
# rectangle ((54, 93), (77, 115))
# circle ((65, 92), (40, 67))
# rectangle ((99, 121), (52, 119))
#
# drawing random shapes
# rectangle ((87, 120), (62, 94))
# triangle ((34, 58), (19, 46))
# ellipse ((89, 124), (21, 56))
#
# drawing random shapes
# rectangle ((51, 111), (28, 117))
# triangle ((-4, 14), (44, 64))
# circle ((21, 42), (3, 24))
#
# drawing random shapes
# rectangle ((47, 70), (14, 34))
# circle ((34, 65), (43, 74))
# triangle ((0, 18), (12, 32))
#
# drawing random shapes
# rectangle ((27, 74), (6, 104))
# circle ((97, 118), (14, 35))
# triangle ((-2, 16), (14, 34))
#
# drawing random shapes
# rectangle ((88, 118), (40, 82))
# rectangle ((73, 103), (91, 114))
# rectangle ((0, 71), (49, 85))
#
# drawing random shapes
# circle ((12, 83), (21, 92))
# rectangle ((106, 126), (80, 103))
# triangle ((-6, 12), (73, 93))
#
# drawing random shapes
# ellipse ((10, 33), (72, 95))
# ellipse ((36, 79), (81, 114))
# ellipse ((6, 73), (9, 72))
#
# drawing random shapes
# triangle ((65, 104), (44, 88))
# triangle ((73, 96), (90, 116))
# circle ((73, 108), (6, 41))
#
# drawing random shapes
# rectangle ((86, 109), (78, 114))
# triangle ((13, 46), (59, 96))
# ellipse ((37, 76), (0, 41))
#
# drawing random shapes
# ellipse ((40, 99), (46, 105))
# circle ((5, 26), (75, 96))
# rectangle ((94, 117), (96, 120))
#
# drawing random shapes
# ellipse ((28, 61), (9, 40))
# rectangle ((46, 74), (66, 117))
# circle ((83, 106), (51, 74))

# %%
fig, ax = plt.subplots(figsize=(5, 4))
im = ax.imshow(image, cmap='turbo', vmin=0, vmax=8)
cbar = fig.colorbar(im)
fig.tight_layout()

fig, ax = plt.subplots(figsize=(5, 4))
im = ax.imshow(texture, cmap='Greys_r')
cbar = fig.colorbar(im)
fig.tight_layout()

fig, ax = plt.subplots(figsize=(5, 5))
im = ax.imshow(mu, cmap='viridis', vmin=0)
cbar = fig.colorbar(im)
fig.tight_layout()

fig, ax = plt.subplots(figsize=(5, 5))
im = ax.imshow(u, cmap='seismic')
cbar = fig.colorbar(im)
fig.tight_layout()
