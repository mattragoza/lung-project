# %%
# %matplotlib notebook
# %load_ext autoreload
# %autoreload 1
# %pwd
# Out:
# '/ocean/projects/asc170022p/mtragoza/lung-project'

# %%
import sys, os
import numpy as np
# %aimport data
# Out:
# <style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>
# <div id='p1002'>
#   <div id="e8d4f8eb-0a37-427f-aef8-49694c895533" data-root-id="p1002" style="display: contents;"></div>
# </div>
# <script type="application/javascript">(function(root) {
#   var docs_json = {"12e5ad7c-5833-4b43-93d2-137a9f4d6528":{"version":"3.3.1","title":"Bokeh Application","roots":[{"type":"object","name":"panel.models.browser.BrowserInfo","id":"p1002"},{"type":"object","name":"panel.models.comm_manager.CommManager","id":"p1003","attributes":{"plot_id":"p1002","comm_id":"e665aa548e794e3d818aab3f3c1e9899","client_comm_id":"f88952c52b994bffbd123e6e06de5f9a"}}],"defs":[{"type":"model","name":"ReactiveHTML1"},{"type":"model","name":"FlexBox1","properties":[{"name":"align_content","kind":"Any","default":"flex-start"},{"name":"align_items","kind":"Any","default":"flex-start"},{"name":"flex_direction","kind":"Any","default":"row"},{"name":"flex_wrap","kind":"Any","default":"wrap"},{"name":"justify_content","kind":"Any","default":"flex-start"}]},{"type":"model","name":"FloatPanel1","properties":[{"name":"config","kind":"Any","default":{"type":"map"}},{"name":"contained","kind":"Any","default":true},{"name":"position","kind":"Any","default":"right-top"},{"name":"offsetx","kind":"Any","default":null},{"name":"offsety","kind":"Any","default":null},{"name":"theme","kind":"Any","default":"primary"},{"name":"status","kind":"Any","default":"normalized"}]},{"type":"model","name":"GridStack1","properties":[{"name":"mode","kind":"Any","default":"warn"},{"name":"ncols","kind":"Any","default":null},{"name":"nrows","kind":"Any","default":null},{"name":"allow_resize","kind":"Any","default":true},{"name":"allow_drag","kind":"Any","default":true},{"name":"state","kind":"Any","default":[]}]},{"type":"model","name":"drag1","properties":[{"name":"slider_width","kind":"Any","default":5},{"name":"slider_color","kind":"Any","default":"black"},{"name":"value","kind":"Any","default":50}]},{"type":"model","name":"click1","properties":[{"name":"terminal_output","kind":"Any","default":""},{"name":"debug_name","kind":"Any","default":""},{"name":"clears","kind":"Any","default":0}]},{"type":"model","name":"toggle_value1","properties":[{"name":"active_icons","kind":"Any","default":{"type":"map"}},{"name":"options","kind":"Any","default":{"type":"map","entries":[["favorite","heart"]]}},{"name":"value","kind":"Any","default":[]},{"name":"_reactions","kind":"Any","default":[]},{"name":"_base_url","kind":"Any","default":"https://tabler-icons.io/static/tabler-icons/icons/"}]},{"type":"model","name":"copy_to_clipboard1","properties":[{"name":"value","kind":"Any","default":null},{"name":"fill","kind":"Any","default":"none"}]},{"type":"model","name":"FastWrapper1","properties":[{"name":"object","kind":"Any","default":null},{"name":"style","kind":"Any","default":null}]},{"type":"model","name":"NotificationAreaBase1","properties":[{"name":"js_events","kind":"Any","default":{"type":"map"}},{"name":"position","kind":"Any","default":"bottom-right"},{"name":"_clear","kind":"Any","default":0}]},{"type":"model","name":"NotificationArea1","properties":[{"name":"js_events","kind":"Any","default":{"type":"map"}},{"name":"notifications","kind":"Any","default":[]},{"name":"position","kind":"Any","default":"bottom-right"},{"name":"_clear","kind":"Any","default":0},{"name":"types","kind":"Any","default":[{"type":"map","entries":[["type","warning"],["background","#ffc107"],["icon",{"type":"map","entries":[["className","fas fa-exclamation-triangle"],["tagName","i"],["color","white"]]}]]},{"type":"map","entries":[["type","info"],["background","#007bff"],["icon",{"type":"map","entries":[["className","fas fa-info-circle"],["tagName","i"],["color","white"]]}]]}]}]},{"type":"model","name":"Notification","properties":[{"name":"background","kind":"Any","default":null},{"name":"duration","kind":"Any","default":3000},{"name":"icon","kind":"Any","default":null},{"name":"message","kind":"Any","default":""},{"name":"notification_type","kind":"Any","default":null},{"name":"_destroyed","kind":"Any","default":false}]},{"type":"model","name":"TemplateActions1","properties":[{"name":"open_modal","kind":"Any","default":0},{"name":"close_modal","kind":"Any","default":0}]},{ ...
#   var render_items = [{"docid":"12e5ad7c-5833-4b43-93d2-137a9f4d6528","roots":{"p1002":"e8d4f8eb-0a37-427f-aef8-49694c895533"},"root_ids":["p1002"]}];
#   var docs = Object.values(docs_json)
#   if (!docs) {
#     return
#   }
#   const py_version = docs[0].version.replace('rc', '-rc.').replace('.dev', '-dev.')
#   function embed_document(root) {
#     var Bokeh = get_bokeh(root)
#     Bokeh.embed.embed_items_notebook(docs_json, render_items);
#     for (const render_item of render_items) {
#       for (const root_id of render_item.root_ids) {
# 	const id_el = document.getElementById(root_id)
# 	if (id_el.children.length && (id_el.children[0].className === 'bk-root')) {
# 	  const root_el = id_el.children[0]
# 	  root_el.id = root_el.id + '-rendered'
# 	}
#       }
#     }
#   }
#   function get_bokeh(root) {
#     if (root.Bokeh === undefined) {
#       return null
#     } else if (root.Bokeh.version !== py_version) {
#       if (root.Bokeh.versions === undefined || !root.Bokeh.versions.has(py_version)) {
# 	return null
#       }
#       return root.Bokeh.versions.get(py_version);
#     } else if (root.Bokeh.version === py_version) {
#       return root.Bokeh
#     }
#     return null
#   }
#   function is_loaded(root) {
#     var Bokeh = get_bokeh(root)
#     return (Bokeh != null && Bokeh.Panel !== undefined)
#   }
#   if (is_loaded(root)) {
#     embed_document(root);
#   } else {
#     var attempts = 0;
#     var timer = setInterval(function(root) {
#       if (is_loaded(root)) {
#         clearInterval(timer);
#         embed_document(root);
#       } else if (document.readyState == "complete") {
#         attempts++;
#         if (attempts > 200) {
#           clearInterval(timer);
# 	  var Bokeh = get_bokeh(root)
# 	  if (Bokeh == null || Bokeh.Panel == null) {
#             console.warn("Panel: ERROR: Unable to run Panel code because Bokeh or Panel library is missing");
# 	  } else {
# 	    console.warn("Panel: WARNING: Attempting to render but not all required libraries could be resolved.")
# 	    embed_document(root)
# 	  }
#         }
#       }
#     }, 25, root)
#   }
# })(window);</script>

# %%
# !tree --sort=mtime -L 1 data/Emory-4DCT
# Out:
# data/Emory-4DCT
# ├── metadata.tsv
# ├── Case8Deploy
# ├── Case8Pack -> data/Emory-4DCT/Case8Deploy/
# ├── Case1Pack
# ├── Case2Pack
# ├── Case3Pack
# ├── Case4Pack
# ├── Case5Pack
# ├── Case6Pack
# ├── Case7Pack
# ├── Case9Pack
# └── Case10Pack
#
# 10 directories, 2 files

# %%
# !tree --sort=mtime data/Emory-4DCT/Case1Pack
# Out:
# data/Emory-4DCT/Case1Pack
# ├── Sampled4D
# │   ├── case1_4D-75_T00.txt
# │   ├── case1_4D-75_T50.txt
# │   ├── case1_4D-75_T10.txt
# │   ├── case1_4D-75_T20.txt
# │   ├── case1_4D-75_T30.txt
# │   └── case1_4D-75_T40.txt
# ├── ExtremePhases
# │   ├── Case1_300_T00_xyz.txt
# │   └── Case1_300_T50_xyz.txt
# ├── Images
# │   ├── case1_T00_s.img
# │   ├── case1_T10_s.img
# │   ├── case1_T20_s.img
# │   ├── case1_T30_s.img
# │   ├── case1_T40_s.img
# │   ├── case1_T50_s.img
# │   ├── case1_T60_s.img
# │   ├── case1_T70_s.img
# │   ├── case1_T80_s.img
# │   └── case1_T90_s.img
# ├── NIFTI
# │   ├── case1_T00.nii.gz
# │   ├── case1_T10.nii.gz
# │   ├── case1_T20.nii.gz
# │   ├── case1_T30.nii.gz
# │   ├── case1_T40.nii.gz
# │   ├── case1_T50.nii.gz
# │   ├── case1_T60.nii.gz
# │   ├── case1_T70.nii.gz
# │   ├── case1_T80.nii.gz
# │   └── case1_T90.nii.gz
# └── TotalSegment
#     ├── case1_T00
#     │   ├── lung_lower_lobe_left.nii.gz
#     │   ├── lung_lower_lobe_right.nii.gz
#     │   ├── lung_middle_lobe_right.nii.gz
#     │   ├── lung_upper_lobe_left.nii.gz
#     │   ├── lung_upper_lobe_right.nii.gz
#     │   ├── lung_trachea_bronchia.nii.gz
#     │   ├── lung_vessels.nii.gz
#     │   └── lung_combined_mask.nii.gz
#     ├── case1_T10
#     │   ├── lung_lower_lobe_left.nii.gz
#     │   ├── lung_lower_lobe_right.nii.gz
#     │   ├── lung_middle_lobe_right.nii.gz
#     │   ├── lung_upper_lobe_left.nii.gz
#     │   ├── lung_upper_lobe_right.nii.gz
#     │   ├── lung_trachea_bronchia.nii.gz
#     │   ├── lung_vessels.nii.gz
#     │   └── lung_combined_mask.nii.gz
#     ├── case1_T20
#     │   ├── lung_lower_lobe_left.nii.gz
#     │   ├── lung_lower_lobe_right.nii.gz
#     │   ├── lung_middle_lobe_right.nii.gz
#     │   ├── lung_upper_lobe_left.nii.gz
#     │   ├── lung_upper_lobe_right.nii.gz
#     │   ├── lung_trachea_bronchia.nii.gz
#     │   ├── lung_vessels.nii.gz
#     │   └── lung_combined_mask.nii.gz
#     ├── case1_T30
#     │   ├── lung_lower_lobe_left.nii.gz
#     │   ├── lung_lower_lobe_right.nii.gz
#     │   ├── lung_middle_lobe_right.nii.gz
#     │   ├── lung_upper_lobe_left.nii.gz
#     │   ├── lung_upper_lobe_right.nii.gz
#     │   ├── lung_trachea_bronchia.nii.gz
#     │   ├── lung_vessels.nii.gz
#     │   └── lung_combined_mask.nii.gz
#     ├── case1_T40
#     │   ├── lung_lower_lobe_left.nii.gz
#     │   ├── lung_lower_lobe_right.nii.gz
#     │   ├── lung_middle_lobe_right.nii.gz
#     │   ├── lung_upper_lobe_left.nii.gz
#     │   ├── lung_upper_lobe_right.nii.gz
#     │   ├── lung_trachea_bronchia.nii.gz
#     │   ├── lung_vessels.nii.gz
#     │   └── lung_combined_mask.nii.gz
#     ├── case1_T60
#     │   ├── lung_lower_lobe_left.nii.gz
#     │   ├── lung_lower_lobe_right.nii.gz
#     │   ├── lung_middle_lobe_right.nii.gz
#     │   ├── lung_upper_lobe_left.nii.gz
#     │   ├── lung_upper_lobe_right.nii.gz
#     │   ├── lung_trachea_bronchia.nii.gz
#     │   ├── lung_vessels.nii.gz
#     │   └── lung_combined_mask.nii.gz
#     ├── case1_T70
#     │   ├── lung_lower_lobe_left.nii.gz
#     │   ├── lung_lower_lobe_right.nii.gz
#     │   ├── lung_middle_lobe_right.nii.gz
#     │   ├── lung_upper_lobe_left.nii.gz
#     │   ├── lung_upper_lobe_right.nii.gz
#     │   ├── lung_trachea_bronchia.nii.gz
#     │   ├── lung_vessels.nii.gz
#     │   └── lung_combined_mask.nii.gz
#     ├── case1_T80
#     │   ├── lung_lower_lobe_left.nii.gz
#     │   ├── lung_lower_lobe_right.nii.gz
#     │   ├── lung_middle_lobe_right.nii.gz
#     │   ├── lung_upper_lobe_left.nii.gz
#     │   ├── lung_upper_lobe_right.nii.gz
#     │   ├── lung_trachea_bronchia.nii.gz
#     │   ├── lung_vessels.nii.gz
#     │   └── lung_combined_mask.nii.gz
#     ├── case1_T90
#     │   ├── lung_lower_lobe_left.nii.gz
#     │   ├── lung_lower_lobe_right.nii.gz
#     │   ├── lung_middle_lobe_right.nii.gz
#     │   ├── lung_upper_lobe_left.nii.gz
#     │   ├── lung_upper_lobe_right.nii.gz
#     │   ├── lung_trachea_bronchia.nii.gz
#     │   ├── lung_vessels.nii.gz
#     │   └── lung_combined_mask.nii.gz
#     └── case1_T50
#         ├── preview_total.png
#         ├── lung_lower_lobe_left.nii.gz
#         ├── lung_lower_lobe_right.nii.gz
#         ├── lung_middle_lobe_right.nii.gz
#         ├── lung_upper_lobe_left.nii.gz
#         ├── lung_upper_lobe_right.nii.gz
#         ├── lung_trachea_bronchia.nii.gz
#         ├── lung_vessels.nii.gz
#         ├── preview_lung_vessels.png
#         ├── statistics.json
#         └── lung_combined_mask.nii.gz
#
# 15 directories, 111 files

# %%
# %autoreload
ds = data.Emory4DCTDataset('data/Emory-4DCT')
ds
# Out:
# Emory4DCTDataset([
#   Emory4DCTCase('data/Emory-4DCT', 'Case1Pack', 10 phases),
#   Emory4DCTCase('data/Emory-4DCT', 'Case2Pack', 10 phases),
#   Emory4DCTCase('data/Emory-4DCT', 'Case3Pack', 10 phases),
#   Emory4DCTCase('data/Emory-4DCT', 'Case4Pack', 10 phases),
#   Emory4DCTCase('data/Emory-4DCT', 'Case5Pack', 10 phases),
#   Emory4DCTCase('data/Emory-4DCT', 'Case6Pack', 10 phases),
#   Emory4DCTCase('data/Emory-4DCT', 'Case7Pack', 10 phases),
#   Emory4DCTCase('data/Emory-4DCT', 'Case8Deploy', 10 phases),
#   Emory4DCTCase('data/Emory-4DCT', 'Case9Pack', 10 phases),
#   Emory4DCTCase('data/Emory-4DCT', 'Case10Pack', 10 phases)
# ])

# %%
ds.load_images()
# Out:
# Loading data/Emory-4DCT/Case1Pack/Images/case1_T00_s.img
# Loading data/Emory-4DCT/Case1Pack/Images/case1_T10_s.img
# Loading data/Emory-4DCT/Case1Pack/Images/case1_T20_s.img
# Loading data/Emory-4DCT/Case1Pack/Images/case1_T30_s.img
# Loading data/Emory-4DCT/Case1Pack/Images/case1_T40_s.img
# Loading data/Emory-4DCT/Case1Pack/Images/case1_T50_s.img
# Loading data/Emory-4DCT/Case1Pack/Images/case1_T60_s.img
# Loading data/Emory-4DCT/Case1Pack/Images/case1_T70_s.img
# Loading data/Emory-4DCT/Case1Pack/Images/case1_T80_s.img
# Loading data/Emory-4DCT/Case1Pack/Images/case1_T90_s.img
# Loading data/Emory-4DCT/Case2Pack/Images/case2_T00-ssm.img
# Loading data/Emory-4DCT/Case2Pack/Images/case2_T10-ssm.img
# Loading data/Emory-4DCT/Case2Pack/Images/case2_T20-ssm.img
# Loading data/Emory-4DCT/Case2Pack/Images/case2_T30-ssm.img
# Loading data/Emory-4DCT/Case2Pack/Images/case2_T40-ssm.img
# Loading data/Emory-4DCT/Case2Pack/Images/case2_T50-ssm.img
# Loading data/Emory-4DCT/Case2Pack/Images/case2_T60-ssm.img
# Loading data/Emory-4DCT/Case2Pack/Images/case2_T70-ssm.img
# Loading data/Emory-4DCT/Case2Pack/Images/case2_T80-ssm.img
# Loading data/Emory-4DCT/Case2Pack/Images/case2_T90-ssm.img
# Loading data/Emory-4DCT/Case3Pack/Images/case3_T00-ssm.img
# Loading data/Emory-4DCT/Case3Pack/Images/case3_T10-ssm.img
# Loading data/Emory-4DCT/Case3Pack/Images/case3_T20-ssm.img
# Loading data/Emory-4DCT/Case3Pack/Images/case3_T30-ssm.img
# Loading data/Emory-4DCT/Case3Pack/Images/case3_T40-ssm.img
# Loading data/Emory-4DCT/Case3Pack/Images/case3_T50-ssm.img
# Loading data/Emory-4DCT/Case3Pack/Images/case3_T60-ssm.img
# Loading data/Emory-4DCT/Case3Pack/Images/case3_T70-ssm.img
# Loading data/Emory-4DCT/Case3Pack/Images/case3_T80-ssm.img
# Loading data/Emory-4DCT/Case3Pack/Images/case3_T90-ssm.img
# Loading data/Emory-4DCT/Case4Pack/Images/case4_T00-ssm.img
# Loading data/Emory-4DCT/Case4Pack/Images/case4_T10-ssm.img
# Loading data/Emory-4DCT/Case4Pack/Images/case4_T20-ssm.img
# Loading data/Emory-4DCT/Case4Pack/Images/case4_T30-ssm.img
# Loading data/Emory-4DCT/Case4Pack/Images/case4_T40-ssm.img
# Loading data/Emory-4DCT/Case4Pack/Images/case4_T50-ssm.img
# Loading data/Emory-4DCT/Case4Pack/Images/case4_T60-ssm.img
# Loading data/Emory-4DCT/Case4Pack/Images/case4_T70-ssm.img
# Loading data/Emory-4DCT/Case4Pack/Images/case4_T80-ssm.img
# Loading data/Emory-4DCT/Case4Pack/Images/case4_T90-ssm.img
# Loading data/Emory-4DCT/Case5Pack/Images/case5_T00-ssm.img
# Loading data/Emory-4DCT/Case5Pack/Images/case5_T10-ssm.img
# Loading data/Emory-4DCT/Case5Pack/Images/case5_T20-ssm.img
# Loading data/Emory-4DCT/Case5Pack/Images/case5_T30-ssm.img
# Loading data/Emory-4DCT/Case5Pack/Images/case5_T40-ssm.img
# Loading data/Emory-4DCT/Case5Pack/Images/case5_T50-ssm.img
# Loading data/Emory-4DCT/Case5Pack/Images/case5_T60-ssm.img
# Loading data/Emory-4DCT/Case5Pack/Images/case5_T70-ssm.img
# Loading data/Emory-4DCT/Case5Pack/Images/case5_T80-ssm.img
# Loading data/Emory-4DCT/Case5Pack/Images/case5_T90-ssm.img
# Loading data/Emory-4DCT/Case6Pack/Images/case6_T00.img
# Loading data/Emory-4DCT/Case6Pack/Images/case6_T10.img
# Loading data/Emory-4DCT/Case6Pack/Images/case6_T20.img
# Loading data/Emory-4DCT/Case6Pack/Images/case6_T30.img
# Loading data/Emory-4DCT/Case6Pack/Images/case6_T40.img
# Loading data/Emory-4DCT/Case6Pack/Images/case6_T50.img
# Loading data/Emory-4DCT/Case6Pack/Images/case6_T60.img
# Loading data/Emory-4DCT/Case6Pack/Images/case6_T70.img
# Loading data/Emory-4DCT/Case6Pack/Images/case6_T80.img
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 ds.load_images()
#
# File /ocean/projects/asc170022p/mtragoza/lung-project/data.py:57, in Emory4DCTDataset.load_images(self)
#      55 shape = (mdata.n_x, mdata.n_y, mdata.n_z)
#      56 resolution = (mdata.xres, mdata.yres, mdata.zres)
# ---> 57 case.load_images(shape, resolution)
#
# File /ocean/projects/asc170022p/mtragoza/lung-project/data.py:118, in Emory4DCTCase.load_images(self, shape, resolution)
#     116     img_glob = self.image_dir.glob(f'case{self.case_id}_T{phase:02d}*.img')
#     117     img_file = next(img_glob) # assumes exactly one match
# --> 118     image = load_img_file(img_file, shape, dtype=np.int16)
#     119     images.append(image)
#     121 self.shape = shape
#
# File /ocean/projects/asc170022p/mtragoza/lung-project/data.py:278, in load_img_file(img_file, shape, dtype, verbose)
#     272 itemsize = data.dtype.itemsize
#     273 data.strides = (
#     274     itemsize,
#     275     itemsize * shape[0],
#     276     itemsize * shape[0] * shape[1]
#     277 )
# --> 278 return data.copy()
#
# KeyboardInterrupt:

# %%
ds.describe()
# Out:
# 100%|██████████| 10/10 [01:36<00:00,  9.62s/it]
#               count        mean         std  min    25%    50%     75%  \
# case1    61603840.0  520.374532  477.174667  0.0   68.0  272.0  1036.0
# case2    73400320.0  607.311466  477.261704  0.0   98.0  625.0  1065.0
# case3    68157440.0  591.326527  480.551600  0.0   80.0  631.0  1049.0
# case4    64880640.0  724.414694  454.170298  0.0  214.0  938.0  1066.0
# case5    69468160.0  672.947766  448.181603  0.0  158.0  920.0  1042.0
# case6   335544320.0  346.283795  452.713270  0.0    0.0   65.0   894.0
# case7   356515840.0  328.356982  450.234232  0.0    0.0   53.0   885.0
# case8   335544320.0  322.715310  414.783162  0.0    6.0   97.0   835.0
# case9   335544320.0  296.519581  423.945823  0.0    0.0   41.0   861.0
# case10  314572800.0  295.370452  418.499223  0.0    0.0   51.0   855.0
#
#             max
# case1   14640.0
# case2    4474.0
# case3   17161.0
# case4    6410.0
# case5    4095.0
# case6    4095.0
# case7    4095.0
# case8    4095.0
# case9    4095.0
# case10   4095.0

# %%
ds.normalize(loc=1000, scale=1)
ds.describe()
# Out:
# 100%|██████████| 10/10 [02:09<00:00, 12.96s/it]
#               count        mean         std     min     25%    50%    75%  \
# case1    61603840.0 -479.625468  477.174667 -1000.0  -932.0 -728.0   36.0
# case2    73400320.0 -392.688534  477.261704 -1000.0  -902.0 -375.0   65.0
# case3    68157440.0 -408.673473  480.551600 -1000.0  -920.0 -369.0   49.0
# case4    64880640.0 -275.585306  454.170298 -1000.0  -786.0  -62.0   66.0
# case5    69468160.0 -327.052234  448.181603 -1000.0  -842.0  -80.0   42.0
# case6   335544320.0 -653.716205  452.713270 -1000.0 -1000.0 -935.0 -106.0
# case7   356515840.0 -671.643018  450.234232 -1000.0 -1000.0 -947.0 -115.0
# case8   335544320.0 -677.284690  414.783162 -1000.0  -994.0 -903.0 -165.0
# case9   335544320.0 -703.480419  423.945823 -1000.0 -1000.0 -959.0 -139.0
# case10  314572800.0 -704.629548  418.499223 -1000.0 -1000.0 -949.0 -145.0
#
#             max
# case1   13640.0
# case2    3474.0
# case3   16161.0
# case4    5410.0
# case5    3095.0
# case6    3095.0
# case7    3095.0
# case8    3095.0
# case9    3095.0
# case10   3095.0

# %%
ds.save_niftis()
# Out:
# Saving data/Emory-4DCT/Case1Pack/NIFTI/case1_T00.nii.gz
# Saving data/Emory-4DCT/Case1Pack/NIFTI/case1_T10.nii.gz
# Saving data/Emory-4DCT/Case1Pack/NIFTI/case1_T20.nii.gz
# Saving data/Emory-4DCT/Case1Pack/NIFTI/case1_T30.nii.gz
# Saving data/Emory-4DCT/Case1Pack/NIFTI/case1_T40.nii.gz
# Saving data/Emory-4DCT/Case1Pack/NIFTI/case1_T50.nii.gz
# Saving data/Emory-4DCT/Case1Pack/NIFTI/case1_T60.nii.gz
# Saving data/Emory-4DCT/Case1Pack/NIFTI/case1_T70.nii.gz
# Saving data/Emory-4DCT/Case1Pack/NIFTI/case1_T80.nii.gz
# Saving data/Emory-4DCT/Case1Pack/NIFTI/case1_T90.nii.gz
# Saving data/Emory-4DCT/Case2Pack/NIFTI/case2_T00.nii.gz
# Saving data/Emory-4DCT/Case2Pack/NIFTI/case2_T10.nii.gz
# Saving data/Emory-4DCT/Case2Pack/NIFTI/case2_T20.nii.gz
# Saving data/Emory-4DCT/Case2Pack/NIFTI/case2_T30.nii.gz
# Saving data/Emory-4DCT/Case2Pack/NIFTI/case2_T40.nii.gz
# Saving data/Emory-4DCT/Case2Pack/NIFTI/case2_T50.nii.gz
# Saving data/Emory-4DCT/Case2Pack/NIFTI/case2_T60.nii.gz
# Saving data/Emory-4DCT/Case2Pack/NIFTI/case2_T70.nii.gz
# Saving data/Emory-4DCT/Case2Pack/NIFTI/case2_T80.nii.gz
# Saving data/Emory-4DCT/Case2Pack/NIFTI/case2_T90.nii.gz
# Saving data/Emory-4DCT/Case3Pack/NIFTI/case3_T00.nii.gz
# Saving data/Emory-4DCT/Case3Pack/NIFTI/case3_T10.nii.gz
# Saving data/Emory-4DCT/Case3Pack/NIFTI/case3_T20.nii.gz
# Saving data/Emory-4DCT/Case3Pack/NIFTI/case3_T30.nii.gz
# Saving data/Emory-4DCT/Case3Pack/NIFTI/case3_T40.nii.gz
# Saving data/Emory-4DCT/Case3Pack/NIFTI/case3_T50.nii.gz
# Saving data/Emory-4DCT/Case3Pack/NIFTI/case3_T60.nii.gz
# Saving data/Emory-4DCT/Case3Pack/NIFTI/case3_T70.nii.gz
# Saving data/Emory-4DCT/Case3Pack/NIFTI/case3_T80.nii.gz
# Saving data/Emory-4DCT/Case3Pack/NIFTI/case3_T90.nii.gz
# Saving data/Emory-4DCT/Case4Pack/NIFTI/case4_T00.nii.gz
# Saving data/Emory-4DCT/Case4Pack/NIFTI/case4_T10.nii.gz
# Saving data/Emory-4DCT/Case4Pack/NIFTI/case4_T20.nii.gz
# Saving data/Emory-4DCT/Case4Pack/NIFTI/case4_T30.nii.gz
# Saving data/Emory-4DCT/Case4Pack/NIFTI/case4_T40.nii.gz
# Saving data/Emory-4DCT/Case4Pack/NIFTI/case4_T50.nii.gz
# Saving data/Emory-4DCT/Case4Pack/NIFTI/case4_T60.nii.gz
# Saving data/Emory-4DCT/Case4Pack/NIFTI/case4_T70.nii.gz
# Saving data/Emory-4DCT/Case4Pack/NIFTI/case4_T80.nii.gz
# Saving data/Emory-4DCT/Case4Pack/NIFTI/case4_T90.nii.gz
# Saving data/Emory-4DCT/Case5Pack/NIFTI/case5_T00.nii.gz
# Saving data/Emory-4DCT/Case5Pack/NIFTI/case5_T10.nii.gz
# Saving data/Emory-4DCT/Case5Pack/NIFTI/case5_T20.nii.gz
# Saving data/Emory-4DCT/Case5Pack/NIFTI/case5_T30.nii.gz
# Saving data/Emory-4DCT/Case5Pack/NIFTI/case5_T40.nii.gz
# Saving data/Emory-4DCT/Case5Pack/NIFTI/case5_T50.nii.gz
# Saving data/Emory-4DCT/Case5Pack/NIFTI/case5_T60.nii.gz
# Saving data/Emory-4DCT/Case5Pack/NIFTI/case5_T70.nii.gz
# Saving data/Emory-4DCT/Case5Pack/NIFTI/case5_T80.nii.gz
# Saving data/Emory-4DCT/Case5Pack/NIFTI/case5_T90.nii.gz
# Saving data/Emory-4DCT/Case6Pack/NIFTI/case6_T00.nii.gz
# Saving data/Emory-4DCT/Case6Pack/NIFTI/case6_T10.nii.gz
# Saving data/Emory-4DCT/Case6Pack/NIFTI/case6_T20.nii.gz
# Saving data/Emory-4DCT/Case6Pack/NIFTI/case6_T30.nii.gz
# Saving data/Emory-4DCT/Case6Pack/NIFTI/case6_T40.nii.gz
# Saving data/Emory-4DCT/Case6Pack/NIFTI/case6_T50.nii.gz
# Saving data/Emory-4DCT/Case6Pack/NIFTI/case6_T60.nii.gz
# Saving data/Emory-4DCT/Case6Pack/NIFTI/case6_T70.nii.gz
# Saving data/Emory-4DCT/Case6Pack/NIFTI/case6_T80.nii.gz
# Saving data/Emory-4DCT/Case6Pack/NIFTI/case6_T90.nii.gz
# Saving data/Emory-4DCT/Case7Pack/NIFTI/case7_T00.nii.gz
# Saving data/Emory-4DCT/Case7Pack/NIFTI/case7_T10.nii.gz
# Saving data/Emory-4DCT/Case7Pack/NIFTI/case7_T20.nii.gz
# Saving data/Emory-4DCT/Case7Pack/NIFTI/case7_T30.nii.gz
# Saving data/Emory-4DCT/Case7Pack/NIFTI/case7_T40.nii.gz
# Saving data/Emory-4DCT/Case7Pack/NIFTI/case7_T50.nii.gz
# Saving data/Emory-4DCT/Case7Pack/NIFTI/case7_T60.nii.gz
# Saving data/Emory-4DCT/Case7Pack/NIFTI/case7_T70.nii.gz
# Saving data/Emory-4DCT/Case7Pack/NIFTI/case7_T80.nii.gz
# Saving data/Emory-4DCT/Case7Pack/NIFTI/case7_T90.nii.gz
# Saving data/Emory-4DCT/Case8Deploy/NIFTI/case8_T00.nii.gz
# Saving data/Emory-4DCT/Case8Deploy/NIFTI/case8_T10.nii.gz
# Saving data/Emory-4DCT/Case8Deploy/NIFTI/case8_T20.nii.gz
# Saving data/Emory-4DCT/Case8Deploy/NIFTI/case8_T30.nii.gz
# Saving data/Emory-4DCT/Case8Deploy/NIFTI/case8_T40.nii.gz
# Saving data/Emory-4DCT/Case8Deploy/NIFTI/case8_T50.nii.gz
# Saving data/Emory-4DCT/Case8Deploy/NIFTI/case8_T60.nii.gz
# Saving data/Emory-4DCT/Case8Deploy/NIFTI/case8_T70.nii.gz
# Saving data/Emory-4DCT/Case8Deploy/NIFTI/case8_T80.nii.gz
# Saving data/Emory-4DCT/Case8Deploy/NIFTI/case8_T90.nii.gz
# Saving data/Emory-4DCT/Case9Pack/NIFTI/case9_T00.nii.gz
# Saving data/Emory-4DCT/Case9Pack/NIFTI/case9_T10.nii.gz
# Saving data/Emory-4DCT/Case9Pack/NIFTI/case9_T20.nii.gz
# Saving data/Emory-4DCT/Case9Pack/NIFTI/case9_T30.nii.gz
# Saving data/Emory-4DCT/Case9Pack/NIFTI/case9_T40.nii.gz
# Saving data/Emory-4DCT/Case9Pack/NIFTI/case9_T50.nii.gz
# Saving data/Emory-4DCT/Case9Pack/NIFTI/case9_T60.nii.gz
# Saving data/Emory-4DCT/Case9Pack/NIFTI/case9_T70.nii.gz
# Saving data/Emory-4DCT/Case9Pack/NIFTI/case9_T80.nii.gz
# Saving data/Emory-4DCT/Case9Pack/NIFTI/case9_T90.nii.gz
# Saving data/Emory-4DCT/Case10Pack/NIFTI/case10_T00.nii.gz
# Saving data/Emory-4DCT/Case10Pack/NIFTI/case10_T10.nii.gz
# Saving data/Emory-4DCT/Case10Pack/NIFTI/case10_T20.nii.gz
# Saving data/Emory-4DCT/Case10Pack/NIFTI/case10_T30.nii.gz
# Saving data/Emory-4DCT/Case10Pack/NIFTI/case10_T40.nii.gz
# Saving data/Emory-4DCT/Case10Pack/NIFTI/case10_T50.nii.gz
# Saving data/Emory-4DCT/Case10Pack/NIFTI/case10_T60.nii.gz
# Saving data/Emory-4DCT/Case10Pack/NIFTI/case10_T70.nii.gz
# Saving data/Emory-4DCT/Case10Pack/NIFTI/case10_T80.nii.gz
# Saving data/Emory-4DCT/Case10Pack/NIFTI/case10_T90.nii.gz

# %%
# %autoreload
ds.load_niftis()
# Out:
# Loading data/Emory-4DCT/Case1Pack/NIFTI/case1_T00.nii.gz
# Loading data/Emory-4DCT/Case1Pack/NIFTI/case1_T10.nii.gz
# Loading data/Emory-4DCT/Case1Pack/NIFTI/case1_T20.nii.gz
# Loading data/Emory-4DCT/Case1Pack/NIFTI/case1_T30.nii.gz
# Loading data/Emory-4DCT/Case1Pack/NIFTI/case1_T40.nii.gz
# Loading data/Emory-4DCT/Case1Pack/NIFTI/case1_T50.nii.gz
# Loading data/Emory-4DCT/Case1Pack/NIFTI/case1_T60.nii.gz
# Loading data/Emory-4DCT/Case1Pack/NIFTI/case1_T70.nii.gz
# Loading data/Emory-4DCT/Case1Pack/NIFTI/case1_T80.nii.gz
# Loading data/Emory-4DCT/Case1Pack/NIFTI/case1_T90.nii.gz
# Loading data/Emory-4DCT/Case2Pack/NIFTI/case2_T00.nii.gz
# Loading data/Emory-4DCT/Case2Pack/NIFTI/case2_T10.nii.gz
# Loading data/Emory-4DCT/Case2Pack/NIFTI/case2_T20.nii.gz
# Loading data/Emory-4DCT/Case2Pack/NIFTI/case2_T30.nii.gz
# Loading data/Emory-4DCT/Case2Pack/NIFTI/case2_T40.nii.gz
# Loading data/Emory-4DCT/Case2Pack/NIFTI/case2_T50.nii.gz
# Loading data/Emory-4DCT/Case2Pack/NIFTI/case2_T60.nii.gz
# Loading data/Emory-4DCT/Case2Pack/NIFTI/case2_T70.nii.gz
# Loading data/Emory-4DCT/Case2Pack/NIFTI/case2_T80.nii.gz
# Loading data/Emory-4DCT/Case2Pack/NIFTI/case2_T90.nii.gz
# Loading data/Emory-4DCT/Case3Pack/NIFTI/case3_T00.nii.gz
# Loading data/Emory-4DCT/Case3Pack/NIFTI/case3_T10.nii.gz
# Loading data/Emory-4DCT/Case3Pack/NIFTI/case3_T20.nii.gz
# Loading data/Emory-4DCT/Case3Pack/NIFTI/case3_T30.nii.gz
# Loading data/Emory-4DCT/Case3Pack/NIFTI/case3_T40.nii.gz
# Loading data/Emory-4DCT/Case3Pack/NIFTI/case3_T50.nii.gz
# Loading data/Emory-4DCT/Case3Pack/NIFTI/case3_T60.nii.gz
# Loading data/Emory-4DCT/Case3Pack/NIFTI/case3_T70.nii.gz
# Loading data/Emory-4DCT/Case3Pack/NIFTI/case3_T80.nii.gz
# Loading data/Emory-4DCT/Case3Pack/NIFTI/case3_T90.nii.gz
# Loading data/Emory-4DCT/Case4Pack/NIFTI/case4_T00.nii.gz
# Loading data/Emory-4DCT/Case4Pack/NIFTI/case4_T10.nii.gz
# Loading data/Emory-4DCT/Case4Pack/NIFTI/case4_T20.nii.gz
# Loading data/Emory-4DCT/Case4Pack/NIFTI/case4_T30.nii.gz
# Loading data/Emory-4DCT/Case4Pack/NIFTI/case4_T40.nii.gz
# Loading data/Emory-4DCT/Case4Pack/NIFTI/case4_T50.nii.gz
# Loading data/Emory-4DCT/Case4Pack/NIFTI/case4_T60.nii.gz
# Loading data/Emory-4DCT/Case4Pack/NIFTI/case4_T70.nii.gz
# Loading data/Emory-4DCT/Case4Pack/NIFTI/case4_T80.nii.gz
# Loading data/Emory-4DCT/Case4Pack/NIFTI/case4_T90.nii.gz
# Loading data/Emory-4DCT/Case5Pack/NIFTI/case5_T00.nii.gz
# Loading data/Emory-4DCT/Case5Pack/NIFTI/case5_T10.nii.gz
# Loading data/Emory-4DCT/Case5Pack/NIFTI/case5_T20.nii.gz
# Loading data/Emory-4DCT/Case5Pack/NIFTI/case5_T30.nii.gz
# Loading data/Emory-4DCT/Case5Pack/NIFTI/case5_T40.nii.gz
# Loading data/Emory-4DCT/Case5Pack/NIFTI/case5_T50.nii.gz
# Loading data/Emory-4DCT/Case5Pack/NIFTI/case5_T60.nii.gz
# Loading data/Emory-4DCT/Case5Pack/NIFTI/case5_T70.nii.gz
# Loading data/Emory-4DCT/Case5Pack/NIFTI/case5_T80.nii.gz
# Loading data/Emory-4DCT/Case5Pack/NIFTI/case5_T90.nii.gz
# Loading data/Emory-4DCT/Case6Pack/NIFTI/case6_T00.nii.gz
# Loading data/Emory-4DCT/Case6Pack/NIFTI/case6_T10.nii.gz
# Loading data/Emory-4DCT/Case6Pack/NIFTI/case6_T20.nii.gz
# Loading data/Emory-4DCT/Case6Pack/NIFTI/case6_T30.nii.gz
# Loading data/Emory-4DCT/Case6Pack/NIFTI/case6_T40.nii.gz
# Loading data/Emory-4DCT/Case6Pack/NIFTI/case6_T50.nii.gz
# Loading data/Emory-4DCT/Case6Pack/NIFTI/case6_T60.nii.gz
# Loading data/Emory-4DCT/Case6Pack/NIFTI/case6_T70.nii.gz
# Loading data/Emory-4DCT/Case6Pack/NIFTI/case6_T80.nii.gz
# Loading data/Emory-4DCT/Case6Pack/NIFTI/case6_T90.nii.gz
# Loading data/Emory-4DCT/Case7Pack/NIFTI/case7_T00.nii.gz
# Loading data/Emory-4DCT/Case7Pack/NIFTI/case7_T10.nii.gz
# Loading data/Emory-4DCT/Case7Pack/NIFTI/case7_T20.nii.gz
# Loading data/Emory-4DCT/Case7Pack/NIFTI/case7_T30.nii.gz
# Loading data/Emory-4DCT/Case7Pack/NIFTI/case7_T40.nii.gz
# Loading data/Emory-4DCT/Case7Pack/NIFTI/case7_T50.nii.gz
# Loading data/Emory-4DCT/Case7Pack/NIFTI/case7_T60.nii.gz
# Loading data/Emory-4DCT/Case7Pack/NIFTI/case7_T70.nii.gz
# Loading data/Emory-4DCT/Case7Pack/NIFTI/case7_T80.nii.gz
# Loading data/Emory-4DCT/Case7Pack/NIFTI/case7_T90.nii.gz
# Loading data/Emory-4DCT/Case8Deploy/NIFTI/case8_T00.nii.gz
# Loading data/Emory-4DCT/Case8Deploy/NIFTI/case8_T10.nii.gz
# Loading data/Emory-4DCT/Case8Deploy/NIFTI/case8_T20.nii.gz
# Loading data/Emory-4DCT/Case8Deploy/NIFTI/case8_T30.nii.gz
# Loading data/Emory-4DCT/Case8Deploy/NIFTI/case8_T40.nii.gz
# Loading data/Emory-4DCT/Case8Deploy/NIFTI/case8_T50.nii.gz
# Loading data/Emory-4DCT/Case8Deploy/NIFTI/case8_T60.nii.gz
# Loading data/Emory-4DCT/Case8Deploy/NIFTI/case8_T70.nii.gz
# Loading data/Emory-4DCT/Case8Deploy/NIFTI/case8_T80.nii.gz
# Loading data/Emory-4DCT/Case8Deploy/NIFTI/case8_T90.nii.gz
# Loading data/Emory-4DCT/Case9Pack/NIFTI/case9_T00.nii.gz
# Loading data/Emory-4DCT/Case9Pack/NIFTI/case9_T10.nii.gz
# Loading data/Emory-4DCT/Case9Pack/NIFTI/case9_T20.nii.gz
# Loading data/Emory-4DCT/Case9Pack/NIFTI/case9_T30.nii.gz
# Loading data/Emory-4DCT/Case9Pack/NIFTI/case9_T40.nii.gz
# Loading data/Emory-4DCT/Case9Pack/NIFTI/case9_T50.nii.gz
# Loading data/Emory-4DCT/Case9Pack/NIFTI/case9_T60.nii.gz
# Loading data/Emory-4DCT/Case9Pack/NIFTI/case9_T70.nii.gz
# Loading data/Emory-4DCT/Case9Pack/NIFTI/case9_T80.nii.gz
# Loading data/Emory-4DCT/Case9Pack/NIFTI/case9_T90.nii.gz
# Loading data/Emory-4DCT/Case10Pack/NIFTI/case10_T00.nii.gz
# Loading data/Emory-4DCT/Case10Pack/NIFTI/case10_T10.nii.gz
# Loading data/Emory-4DCT/Case10Pack/NIFTI/case10_T20.nii.gz
# Loading data/Emory-4DCT/Case10Pack/NIFTI/case10_T30.nii.gz
# Loading data/Emory-4DCT/Case10Pack/NIFTI/case10_T40.nii.gz
# Loading data/Emory-4DCT/Case10Pack/NIFTI/case10_T50.nii.gz
# Loading data/Emory-4DCT/Case10Pack/NIFTI/case10_T60.nii.gz
# Loading data/Emory-4DCT/Case10Pack/NIFTI/case10_T70.nii.gz
# Loading data/Emory-4DCT/Case10Pack/NIFTI/case10_T80.nii.gz
# Loading data/Emory-4DCT/Case10Pack/NIFTI/case10_T90.nii.gz

# %%
case = ds.cases[0]
case.view(groupby=['phase'], xlim=(-1000, 15000), ylim=(0, 4e6), bins=np.linspace(0, 15000, 20))
# Out:
# :DynamicMap   [phase]
#    :NdOverlay   [Element]
#       :Histogram   [CT]   (CT_count)

# %%
case.view(groupby=['phase', 'y'], x='x', y='z')
# Out:
# :DynamicMap   [phase,y]
#    :Image   [x,z]   (CT)

# %%
# %autoreload
case.select(y=120).view(groupby='phase', x='x', y='z', widget_type='scrubber', widget_location='bottom')
# Out:
# Column
#     [0] HoloViews(DynamicMap, sizing_mode='fixed', widget_location='bottom', widget_type='scrubber')
#     [1] WidgetBox(align=('center', 'end'))
#         [0] Player(end=9, width=550)
