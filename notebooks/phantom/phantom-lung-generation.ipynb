# %%
# %matplotlib notebook
# %load_ext autoreload

# %%
import sys, os
os.environ['PKG_CONFIG_PATH'] = '/ocean/projects/asc170022p/mtragoza/mambaforge/envs/lung-project/lib/pkgconfig'

import numpy as np
import xarray as xr

sys.path.append('..')
import project
# Out:
# <script type="esms-options">{"shimMode": true}</script><style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>
# <div id='p1002'>
#   <div id="ffa757e2-50b1-4c98-ba88-c93116ce717d" data-root-id="p1002" style="display: contents;"></div>
# </div>
# <script type="application/javascript">(function(root) {
#   var docs_json = {"39d9bc19-1343-4736-b31e-56a02b61b3a3":{"version":"3.6.0","title":"Bokeh Application","roots":[{"type":"object","name":"panel.models.browser.BrowserInfo","id":"p1002"},{"type":"object","name":"panel.models.comm_manager.CommManager","id":"p1003","attributes":{"plot_id":"p1002","comm_id":"2a7f0289ba0143fe986a78c9fff69035","client_comm_id":"ba995682dee04e8b9606089c7e4a7af8"}}],"defs":[{"type":"model","name":"ReactiveHTML1"},{"type":"model","name":"FlexBox1","properties":[{"name":"align_content","kind":"Any","default":"flex-start"},{"name":"align_items","kind":"Any","default":"flex-start"},{"name":"flex_direction","kind":"Any","default":"row"},{"name":"flex_wrap","kind":"Any","default":"wrap"},{"name":"gap","kind":"Any","default":""},{"name":"justify_content","kind":"Any","default":"flex-start"}]},{"type":"model","name":"FloatPanel1","properties":[{"name":"config","kind":"Any","default":{"type":"map"}},{"name":"contained","kind":"Any","default":true},{"name":"position","kind":"Any","default":"right-top"},{"name":"offsetx","kind":"Any","default":null},{"name":"offsety","kind":"Any","default":null},{"name":"theme","kind":"Any","default":"primary"},{"name":"status","kind":"Any","default":"normalized"}]},{"type":"model","name":"GridStack1","properties":[{"name":"mode","kind":"Any","default":"warn"},{"name":"ncols","kind":"Any","default":null},{"name":"nrows","kind":"Any","default":null},{"name":"allow_resize","kind":"Any","default":true},{"name":"allow_drag","kind":"Any","default":true},{"name":"state","kind":"Any","default":[]}]},{"type":"model","name":"drag1","properties":[{"name":"slider_width","kind":"Any","default":5},{"name":"slider_color","kind":"Any","default":"black"},{"name":"value","kind":"Any","default":50}]},{"type":"model","name":"click1","properties":[{"name":"terminal_output","kind":"Any","default":""},{"name":"debug_name","kind":"Any","default":""},{"name":"clears","kind":"Any","default":0}]},{"type":"model","name":"FastWrapper1","properties":[{"name":"object","kind":"Any","default":null},{"name":"style","kind":"Any","default":null}]},{"type":"model","name":"NotificationAreaBase1","properties":[{"name":"js_events","kind":"Any","default":{"type":"map"}},{"name":"position","kind":"Any","default":"bottom-right"},{"name":"_clear","kind":"Any","default":0}]},{"type":"model","name":"NotificationArea1","properties":[{"name":"js_events","kind":"Any","default":{"type":"map"}},{"name":"notifications","kind":"Any","default":[]},{"name":"position","kind":"Any","default":"bottom-right"},{"name":"_clear","kind":"Any","default":0},{"name":"types","kind":"Any","default":[{"type":"map","entries":[["type","warning"],["background","#ffc107"],["icon",{"type":"map","entries":[["className","fas fa-exclamation-triangle"],["tagName","i"],["color","white"]]}]]},{"type":"map","entries":[["type","info"],["background","#007bff"],["icon",{"type":"map","entries":[["className","fas fa-info-circle"],["tagName","i"],["color","white"]]}]]}]}]},{"type":"model","name":"Notification","properties":[{"name":"background","kind":"Any","default":null},{"name":"duration","kind":"Any","default":3000},{"name":"icon","kind":"Any","default":null},{"name":"message","kind":"Any","default":""},{"name":"notification_type","kind":"Any","default":null},{"name":"_destroyed","kind":"Any","default":false}]},{"type":"model","name":"TemplateActions1","properties":[{"name":"open_modal","kind":"Any","default":0},{"name":"close_modal","kind":"Any","default":0}]},{"type":"model","name":"BootstrapTemplateActions1","properties":[{"name":"open_modal","kind":"Any","default":0},{"name":"close_modal","kind":"Any","default":0}]},{"type":"model","name":"TemplateEditor1","properties":[{"name":"layout","kind":"Any","default":[]}]},{"type":"model","name":"MaterialTemplateActions1","properties":[{"name":"open_modal","kind":"Any","default":0},{"name":"close_modal","kind":"Any","default":0}]},{"type":"model","name":"ReactiveESM1"},{"type":"model","name":"JSComponent1"},{"ty ...
#   var render_items = [{"docid":"39d9bc19-1343-4736-b31e-56a02b61b3a3","roots":{"p1002":"ffa757e2-50b1-4c98-ba88-c93116ce717d"},"root_ids":["p1002"]}];
#   var docs = Object.values(docs_json)
#   if (!docs) {
#     return
#   }
#   const py_version = docs[0].version.replace('rc', '-rc.').replace('.dev', '-dev.')
#   async function embed_document(root) {
#     var Bokeh = get_bokeh(root)
#     await Bokeh.embed.embed_items_notebook(docs_json, render_items);
#     for (const render_item of render_items) {
#       for (const root_id of render_item.root_ids) {
# 	const id_el = document.getElementById(root_id)
# 	if (id_el.children.length && id_el.children[0].hasAttribute('data-root-id')) {
# 	  const root_el = id_el.children[0]
# 	  root_el.id = root_el.id + '-rendered'
# 	  for (const child of root_el.children) {
#             // Ensure JupyterLab does not capture keyboard shortcuts
#             // see: https://jupyterlab.readthedocs.io/en/4.1.x/extension/notebook.html#keyboard-interaction-model
# 	    child.setAttribute('data-lm-suppress-shortcuts', 'true')
# 	  }
# 	}
#       }
#     }
#   }
#   function get_bokeh(root) {
#     if (root.Bokeh === undefined) {
#       return null
#     } else if (root.Bokeh.version !== py_version) {
#       if (root.Bokeh.versions === undefined || !root.Bokeh.versions.has(py_version)) {
# 	return null
#       }
#       return root.Bokeh.versions.get(py_version);
#     } else if (root.Bokeh.version === py_version) {
#       return root.Bokeh
#     }
#     return null
#   }
#   function is_loaded(root) {
#     var Bokeh = get_bokeh(root)
#     return (Bokeh != null && Bokeh.Panel !== undefined)
#   }
#   if (is_loaded(root)) {
#     embed_document(root);
#   } else {
#     var attempts = 0;
#     var timer = setInterval(function(root) {
#       if (is_loaded(root)) {
#         clearInterval(timer);
#         embed_document(root);
#       } else if (document.readyState == "complete") {
#         attempts++;
#         if (attempts > 200) {
#           clearInterval(timer);
# 	  var Bokeh = get_bokeh(root)
# 	  if (Bokeh == null || Bokeh.Panel == null) {
#             console.warn("Panel: ERROR: Unable to run Panel code because Bokeh or Panel library is missing");
# 	  } else {
# 	    console.warn("Panel: WARNING: Attempting to render but not all required libraries could be resolved.")
# 	    embed_document(root)
# 	  }
#         }
#       }
#     }, 25, root)
#   }
# })(window);</script>

# %%
# %%time
# %autoreload
for bias_range in [125, 0, 375, 500]:
    for dummy_targets in [True, False]:
        print(f'GENERATING PHANTOMS WITH BIAS RANGE {bias_range} {dummy_targets}')
        ps = project.phantom.PhantomSet(
            data_root=f'../data/phantom_lung3_{bias_range}_{dummy_targets:d}',
            phantom_ids=list(range(100))
        )
        ps.generate(
            mask_file='../data/Emory-4DCT/Case1Pack/TotalSegment/case1_T00/lung_regions.nii.gz',
            mesh_version=10,
            bias_range=bias_range,
            dummy_targets=dummy_targets
        )
# Out:
# GENERATING PHANTOMS WITH BIAS RANGE 125 True
# Setting random seed to 0
# Defining spatial domain...
# 5 14
# Sampling latent variables...
# Generating stiffness map..
# Generating anatomical image...
# Generating displacement BC...
# Generating mesh...
# Loading ../data/phantom_lung3_125_1/phantom0/phantom0_mesh10.xdmf... 5064
# Interpolating FEM coefficients...
# Solving FEM model...
# Converting displacement field to image...
# torch.Size([256, 256, 94]) torch.Size([256, 256, 94]) torch.Size([256, 256, 94, 3]) torch.Size([256, 256, 94, 3]) (256, 256, 94)
# Saving ../data/phantom_lung3_125_1/phantom0/phantom0_elast.nii.gz
# Saving ../data/phantom_lung3_125_1/phantom0/phantom0_anat.nii.gz
# Saving ../data/phantom_lung3_125_1/phantom0/phantom0_disp.nii.gz
# Saving ../data/phantom_lung3_125_1/phantom0/phantom0_mask.nii.gz
# Setting random seed to 1
# Defining spatial domain...
# 4 50
# Sampling latent variables...
# Generating stiffness map..
# Generating anatomical image...
# Generating displacement BC...
# Generating mesh...
# Loading ../data/phantom_lung3_125_1/phantom1/phantom1_mesh10.xdmf... 5160
# Interpolating FEM coefficients...
# Solving FEM model...
# Converting displacement field to image...
# torch.Size([256, 256, 94]) torch.Size([256, 256, 94]) torch.Size([256, 256, 94, 3]) torch.Size([256, 256, 94, 3]) (256, 256, 94)
# Saving ../data/phantom_lung3_125_1/phantom1/phantom1_elast.nii.gz
# Saving ../data/phantom_lung3_125_1/phantom1/phantom1_anat.nii.gz
# Saving ../data/phantom_lung3_125_1/phantom1/phantom1_disp.nii.gz
# Saving ../data/phantom_lung3_125_1/phantom1/phantom1_mask.nii.gz
# Setting random seed to 2
# Defining spatial domain...
# 5 27
# Sampling latent variables...
# Generating stiffness map..
# Generating anatomical image...
# Generating displacement BC...
# Generating mesh...
# Loading ../data/phantom_lung3_125_1/phantom2/phantom2_mesh10.xdmf... 5164
# Interpolating FEM coefficients...
# Solving FEM model...
# Converting displacement field to image...
# torch.Size([256, 256, 94]) torch.Size([256, 256, 94]) torch.Size([256, 256, 94, 3]) torch.Size([256, 256, 94, 3]) (256, 256, 94)
# Saving ../data/phantom_lung3_125_1/phantom2/phantom2_elast.nii.gz
# Saving ../data/phantom_lung3_125_1/phantom2/phantom2_anat.nii.gz
# Saving ../data/phantom_lung3_125_1/phantom2/phantom2_disp.nii.gz
# Saving ../data/phantom_lung3_125_1/phantom2/phantom2_mask.nii.gz
# Setting random seed to 3
# Defining spatial domain...
# 5 22
# Sampling latent variables...
# Generating stiffness map..
# Generating anatomical image...
# Generating displacement BC...
# Generating mesh...
# Loading ../data/phantom_lung3_125_1/phantom3/phantom3_mesh10.xdmf... 5151
# Interpolating FEM coefficients...
# Solving FEM model...
# Converting displacement field to image...
# torch.Size([256, 256, 94]) torch.Size([256, 256, 94]) torch.Size([256, 256, 94, 3]) torch.Size([256, 256, 94, 3]) (256, 256, 94)
# Saving ../data/phantom_lung3_125_1/phantom3/phantom3_elast.nii.gz
# Saving ../data/phantom_lung3_125_1/phantom3/phantom3_anat.nii.gz
# Saving ../data/phantom_lung3_125_1/phantom3/phantom3_disp.nii.gz
# Saving ../data/phantom_lung3_125_1/phantom3/phantom3_mask.nii.gz
# Setting random seed to 4
# Defining spatial domain...
# 3 50
# Sampling latent variables...
# Generating stiffness map..
# Generating anatomical image...
# Generating displacement BC...
# Generating mesh...
# Loading ../data/phantom_lung3_125_1/phantom4/phantom4_mesh10.xdmf... 5111
# Interpolating FEM coefficients...
# Solving FEM model...
# Converting displacement field to image...
# torch.Size([256, 256, 94]) torch.Size([256, 256, 94]) torch.Size([256, 256, 94, 3]) torch.Size([256, 256, 94, 3]) (256, 256, 94)
# Saving ../data/phantom_lung3_125_1/phantom4/phantom4_elast.nii.gz
# Saving ../data/phantom_lung3_125_1/phantom4/phantom4_anat.nii.gz
# Saving ../data/phantom_lung3_125_1/phantom4/phantom4_disp.nii.gz
# Saving ../data/phantom_lung3_125_1/phantom4/phantom4_mask.nii.gz
# Setting random seed to 5
# Defining spatial domain...
# 5 15
# Sampling latent variables...
# Generating stiffness map..
# Generating anatomical image...
# Generating displacement BC...
# Generating mesh...
# Loading ../data/phantom_lung3_125_1/phantom5/phantom5_mesh10.xdmf... 5070
# Interpolating FEM coefficients...
# Solving FEM model...
# Converting displacement field to image...
# torch.Size([256, 256, 94]) torch.Size([256, 256, 94]) torch.Size([256, 256, 94, 3]) torch.Size([256, 256, 94, 3]) (256, 256, 94)
# Saving ../data/phantom_lung3_125_1/phantom5/phantom5_elast.nii.gz
# Saving ../data/phantom_lung3_125_1/phantom5/phantom5_anat.nii.gz
# Saving ../data/phantom_lung3_125_1/phantom5/phantom5_disp.nii.gz
# Saving ../data/phantom_lung3_125_1/phantom5/phantom5_mask.nii.gz
# Setting random seed to 6
# Defining spatial domain...
# 5 13
# Sampling latent variables...
# Generating stiffness map..
# Generating anatomical image...
# Generating displacement BC...
# Generating mesh...
# Loading ../data/phantom_lung3_125_1/phantom6/phantom6_mesh10.xdmf... 5193
# Interpolating FEM coefficients...
# Solving FEM model...
# Converting displacement field to image...
# torch.Size([256, 256, 94]) torch.Size([256, 256, 94]) torch.Size([256, 256, 94, 3]) torch.Size([256, 256, 94, 3]) (256, 256, 94)
# Saving ../data/phantom_lung3_125_1/phantom6/phantom6_elast.nii.gz
# Saving ../data/phantom_lung3_125_1/phantom6/phantom6_anat.nii.gz
# Saving ../data/phantom_lung3_125_1/phantom6/phantom6_disp.nii.gz
# Saving ../data/phantom_lung3_125_1/phantom6/phantom6_mask.nii.gz
# Setting random seed to 7
# Defining spatial domain...
# 5 41
# Sampling latent variables...
# Generating stiffness map..
# Generating anatomical image...
# Generating displacement BC...
# Generating mesh...
# Loading ../data/phantom_lung3_125_1/phantom7/phantom7_mesh10.xdmf... 5324
# Interpolating FEM coefficients...
# Solving FEM model...
# Converting displacement field to image...
# torch.Size([256, 256, 94]) torch.Size([256, 256, 94]) torch.Size([256, 256, 94, 3]) torch.Size([256, 256, 94, 3]) (256, 256, 94)
# Saving ../data/phantom_lung3_125_1/phantom7/phantom7_elast.nii.gz
# Saving ../data/phantom_lung3_125_1/phantom7/phantom7_anat.nii.gz
# Saving ../data/phantom_lung3_125_1/phantom7/phantom7_disp.nii.gz
# Saving ../data/phantom_lung3_125_1/phantom7/phantom7_mask.nii.gz
# Setting random seed to 8
# Defining spatial domain...
# 5 39
# Sampling latent variables...
# Generating stiffness map..
# Generating anatomical image...
# Generating displacement BC...
# Generating mesh...
# Loading ../data/phantom_lung3_125_1/phantom8/phantom8_mesh10.xdmf... 5454
# Interpolating FEM coefficients...
# Solving FEM model...
# Converting displacement field to image...
# torch.Size([256, 256, 94]) torch.Size([256, 256, 94]) torch.Size([256, 256, 94, 3]) torch.Size([256, 256, 94, 3]) (256, 256, 94)
# Saving ../data/phantom_lung3_125_1/phantom8/phantom8_elast.nii.gz
# Saving ../data/phantom_lung3_125_1/phantom8/phantom8_anat.nii.gz
# Saving ../data/phantom_lung3_125_1/phantom8/phantom8_disp.nii.gz
# Saving ../data/phantom_lung3_125_1/phantom8/phantom8_mask.nii.gz
# Setting random seed to 9
# Defining spatial domain...
# 5 25
# Sampling latent variables...
# Generating stiffness map..
# Generating anatomical image...
# Generating displacement BC...
# Generating mesh...
# Loading ../data/phantom_lung3_125_1/phantom9/phantom9_mesh10.xdmf... 5266
# Interpolating FEM coefficients...
# Solving FEM model...
# Converting displacement field to image...
# torch.Size([256, 256, 94]) torch.Size([256, 256, 94]) torch.Size([256, 256, 94, 3]) torch.Size([256, 256, 94, 3]) (256, 256, 94)
# Saving ../data/phantom_lung3_125_1/phantom9/phantom9_elast.nii.gz
# Saving ../data/phantom_lung3_125_1/phantom9/phantom9_anat.nii.gz
# Saving ../data/phantom_lung3_125_1/phantom9/phantom9_disp.nii.gz
# Saving ../data/phantom_lung3_125_1/phantom9/phantom9_mask.nii.gz
# Setting random seed to 10
# Defining spatial domain...
# 4 50
# Sampling latent variables...
# Generating stiffness map..
# Generating anatomical image...
# Generating displacement BC...
# Generating mesh...
# Loading ../data/phantom_lung3_125_1/phantom10/phantom10_mesh10.xdmf... 5105
# Interpolating FEM coefficients...
# Solving FEM model...
# Converting displacement field to image...
# torch.Size([256, 256, 94]) torch.Size([256, 256, 94]) torch.Size([256, 256, 94, 3]) torch.Size([256, 256, 94, 3]) (256, 256, 94)
# Saving ../data/phantom_lung3_125_1/phantom10/phantom10_elast.nii.gz
# Saving ../data/phantom_lung3_125_1/phantom10/phantom10_anat.nii.gz
# Saving ../data/phantom_lung3_125_1/phantom10/phantom10_disp.nii.gz
# Saving ../data/phantom_lung3_125_1/phantom10/phantom10_mask.nii.gz
# Setting random seed to 11
# Defining spatial domain...
# 5 46
# Sampling latent variables...
# Generating stiffness map..
# Generating anatomical image...
# Generating displacement BC...
# Generating mesh...
# Loading ../data/phantom_lung3_125_1/phantom11/phantom11_mesh10.xdmf... 5108
# Interpolating FEM coefficients...
# Solving FEM model...
# Converting displacement field to image...
# torch.Size([256, 256, 94]) torch.Size([256, 256, 94]) torch.Size([256, 256, 94, 3]) torch.Size([256, 256, 94, 3]) (256, 256, 94)
# Saving ../data/phantom_lung3_125_1/phantom11/phantom11_elast.nii.gz
# Saving ../data/phantom_lung3_125_1/phantom11/phantom11_anat.nii.gz
# Saving ../data/phantom_lung3_125_1/phantom11/phantom11_disp.nii.gz
# Saving ../data/phantom_lung3_125_1/phantom11/phantom11_mask.nii.gz
# Setting random seed to 12
# Defining spatial domain...
# 5 34
# Sampling latent variables...
# Generating stiffness map..
# Generating anatomical image...
# Generating displacement BC...
# Generating mesh...
# Loading ../data/phantom_lung3_125_1/phantom12/phantom12_mesh10.xdmf... 5247
# Interpolating FEM coefficients...
# Solving FEM model...
# Converting displacement field to image...
# torch.Size([256, 256, 94]) torch.Size([256, 256, 94]) torch.Size([256, 256, 94, 3]) torch.Size([256, 256, 94, 3]) (256, 256, 94)
# Saving ../data/phantom_lung3_125_1/phantom12/phantom12_elast.nii.gz
# Saving ../data/phantom_lung3_125_1/phantom12/phantom12_anat.nii.gz
# Saving ../data/phantom_lung3_125_1/phantom12/phantom12_disp.nii.gz
# Saving ../data/phantom_lung3_125_1/phantom12/phantom12_mask.nii.gz
# Setting random seed to 13
# Defining spatial domain...
# 5 48
# Sampling latent variables...
# Generating stiffness map..
# Generating anatomical image...
# Generating displacement BC...
# Generating mesh...
# Loading ../data/phantom_lung3_125_1/phantom13/phantom13_mesh10.xdmf... 5197
# Interpolating FEM coefficients...
# Solving FEM model...
# Converting displacement field to image...
# torch.Size([256, 256, 94]) torch.Size([256, 256, 94]) torch.Size([256, 256, 94, 3]) torch.Size([256, 256, 94, 3]) (256, 256, 94)
# Saving ../data/phantom_lung3_125_1/phantom13/phantom13_elast.nii.gz
# Saving ../data/phantom_lung3_125_1/phantom13/phantom13_anat.nii.gz
# Saving ../data/phantom_lung3_125_1/phantom13/phantom13_disp.nii.gz
# Saving ../data/phantom_lung3_125_1/phantom13/phantom13_mask.nii.gz
# Setting random seed to 14
# Defining spatial domain...
# 5 35
# Sampling latent variables...
# Generating stiffness map..
# Generating anatomical image...
# Generating displacement BC...
# Generating mesh...
# Loading ../data/phantom_lung3_125_1/phantom14/phantom14_mesh10.xdmf... 5225
# Interpolating FEM coefficients...
# Solving FEM model...
# Converting displacement field to image...
# torch.Size([256, 256, 94]) torch.Size([256, 256, 94]) torch.Size([256, 256, 94, 3]) torch.Size([256, 256, 94, 3]) (256, 256, 94)
# Saving ../data/phantom_lung3_125_1/phantom14/phantom14_elast.nii.gz
# Saving ../data/phantom_lung3_125_1/phantom14/phantom14_anat.nii.gz
# Saving ../data/phantom_lung3_125_1/phantom14/phantom14_disp.nii.gz
# Saving ../data/phantom_lung3_125_1/phantom14/phantom14_mask.nii.gz
# Setting random seed to 15
# Defining spatial domain...
# 5 49
# Sampling latent variables...
# Generating stiffness map..
# Generating anatomical image...
# Generating displacement BC...
# Generating mesh...
# Loading ../data/phantom_lung3_125_1/phantom15/phantom15_mesh10.xdmf... 5252
# Interpolating FEM coefficients...
# Solving FEM model...
# Converting displacement field to image...
# torch.Size([256, 256, 94]) torch.Size([256, 256, 94]) torch.Size([256, 256, 94, 3]) torch.Size([256, 256, 94, 3]) (256, 256, 94)
# Saving ../data/phantom_lung3_125_1/phantom15/phantom15_elast.nii.gz
# Saving ../data/phantom_lung3_125_1/phantom15/phantom15_anat.nii.gz
# Saving ../data/phantom_lung3_125_1/phantom15/phantom15_disp.nii.gz
# Saving ../data/phantom_lung3_125_1/phantom15/phantom15_mask.nii.gz
# Setting random seed to 16
# Defining spatial domain...
# 5 25
# Sampling latent variables...
# Generating stiffness map..
# Generating anatomical image...
# Generating displacement BC...
# Generating mesh...
# Loading ../data/phantom_lung3_125_1/phantom16/phantom16_mesh10.xdmf... 4979
# Interpolating FEM coefficients...
# Solving FEM model...
# Converting displacement field to image...
# torch.Size([256, 256, 94]) torch.Size([256, 256, 94]) torch.Size([256, 256, 94, 3]) torch.Size([256, 256, 94, 3]) (256, 256, 94)
# Saving ../data/phantom_lung3_125_1/phantom16/phantom16_elast.nii.gz
# Saving ../data/phantom_lung3_125_1/phantom16/phantom16_anat.nii.gz
# Saving ../data/phantom_lung3_125_1/phantom16/phantom16_disp.nii.gz
# Saving ../data/phantom_lung3_125_1/phantom16/phantom16_mask.nii.gz
# Setting random seed to 17
# Defining spatial domain...
# 5 34
# Sampling latent variables...
# Generating stiffness map..
# Generating anatomical image...
# Generating displacement BC...
# Generating mesh...
# Loading ../data/phantom_lung3_125_1/phantom17/phantom17_mesh10.xdmf... 5118
# Interpolating FEM coefficients...
# Solving FEM model...
# Converting displacement field to image...
# torch.Size([256, 256, 94]) torch.Size([256, 256, 94]) torch.Size([256, 256, 94, 3]) torch.Size([256, 256, 94, 3]) (256, 256, 94)
# Saving ../data/phantom_lung3_125_1/phantom17/phantom17_elast.nii.gz
# Saving ../data/phantom_lung3_125_1/phantom17/phantom17_anat.nii.gz
# Saving ../data/phantom_lung3_125_1/phantom17/phantom17_disp.nii.gz
# Saving ../data/phantom_lung3_125_1/phantom17/phantom17_mask.nii.gz
# Setting random seed to 18
# Defining spatial domain...
# 5 42
# Sampling latent variables...
# Generating stiffness map..
# Generating anatomical image...
# Generating displacement BC...
# Generating mesh...
# Loading ../data/phantom_lung3_125_1/phantom18/phantom18_mesh10.xdmf... 5097
# Interpolating FEM coefficients...
# Solving FEM model...
# Converting displacement field to image...
# torch.Size([256, 256, 94]) torch.Size([256, 256, 94]) torch.Size([256, 256, 94, 3]) torch.Size([256, 256, 94, 3]) (256, 256, 94)
# Saving ../data/phantom_lung3_125_1/phantom18/phantom18_elast.nii.gz
# Saving ../data/phantom_lung3_125_1/phantom18/phantom18_anat.nii.gz
# Saving ../data/phantom_lung3_125_1/phantom18/phantom18_disp.nii.gz
# Saving ../data/phantom_lung3_125_1/phantom18/phantom18_mask.nii.gz
# Setting random seed to 19
# Defining spatial domain...
# 3 50
# Sampling latent variables...
# Generating stiffness map..
# Generating anatomical image...
# Generating displacement BC...
# Generating mesh...
# Loading ../data/phantom_lung3_125_1/phantom19/phantom19_mesh10.xdmf... 4998
# Interpolating FEM coefficients...
# Solving FEM model...
# Converting displacement field to image...
# torch.Size([256, 256, 94]) torch.Size([256, 256, 94]) torch.Size([256, 256, 94, 3]) torch.Size([256, 256, 94, 3]) (256, 256, 94)
# Saving ../data/phantom_lung3_125_1/phantom19/phantom19_elast.nii.gz
# Saving ../data/phantom_lung3_125_1/phantom19/phantom19_anat.nii.gz
# Saving ../data/phantom_lung3_125_1/phantom19/phantom19_disp.nii.gz
# Saving ../data/phantom_lung3_125_1/phantom19/phantom19_mask.nii.gz
# Setting random seed to 20
# Defining spatial domain...
# 5 27
# Sampling latent variables...
# Generating stiffness map..
# Generating anatomical image...
# Generating displacement BC...
# Generating mesh...
# Loading ../data/phantom_lung3_125_1/phantom20/phantom20_mesh10.xdmf... 5283
# Interpolating FEM coefficients...
# Solving FEM model...
# Converting displacement field to image...
# torch.Size([256, 256, 94]) torch.Size([256, 256, 94]) torch.Size([256, 256, 94, 3]) torch.Size([256, 256, 94, 3]) (256, 256, 94)
# Saving ../data/phantom_lung3_125_1/phantom20/phantom20_elast.nii.gz
# Saving ../data/phantom_lung3_125_1/phantom20/phantom20_anat.nii.gz
# Saving ../data/phantom_lung3_125_1/phantom20/phantom20_disp.nii.gz
# Saving ../data/phantom_lung3_125_1/phantom20/phantom20_mask.nii.gz
# Setting random seed to 21
# Defining spatial domain...
# 5 36
# Sampling latent variables...
# Generating stiffness map..
# Generating anatomical image...
# Generating displacement BC...
# Generating mesh...
# Loading ../data/phantom_lung3_125_1/phantom21/phantom21_mesh10.xdmf... 5281
# Interpolating FEM coefficients...
# Solving FEM model...
# Converting displacement field to image...
# torch.Size([256, 256, 94]) torch.Size([256, 256, 94]) torch.Size([256, 256, 94, 3]) torch.Size([256, 256, 94, 3]) (256, 256, 94)
# Saving ../data/phantom_lung3_125_1/phantom21/phantom21_elast.nii.gz
# Saving ../data/phantom_lung3_125_1/phantom21/phantom21_anat.nii.gz
# Saving ../data/phantom_lung3_125_1/phantom21/phantom21_disp.nii.gz
# Saving ../data/phantom_lung3_125_1/phantom21/phantom21_mask.nii.gz
# Setting random seed to 22
# Defining spatial domain...
# 5 48
# Sampling latent variables...
# Generating stiffness map..
# Generating anatomical image...
# Generating displacement BC...
# Generating mesh...
# Loading ../data/phantom_lung3_125_1/phantom22/phantom22_mesh10.xdmf... 5404
# Interpolating FEM coefficients...
# Solving FEM model...
# Converting displacement field to image...
# torch.Size([256, 256, 94]) torch.Size([256, 256, 94]) torch.Size([256, 256, 94, 3]) torch.Size([256, 256, 94, 3]) (256, 256, 94)
# Saving ../data/phantom_lung3_125_1/phantom22/phantom22_elast.nii.gz
# Saving ../data/phantom_lung3_125_1/phantom22/phantom22_anat.nii.gz
# Saving ../data/phantom_lung3_125_1/phantom22/phantom22_disp.nii.gz
# Saving ../data/phantom_lung3_125_1/phantom22/phantom22_mask.nii.gz
# Setting random seed to 23
# Defining spatial domain...
# 5 41
# Sampling latent variables...
# Generating stiffness map..
# Generating anatomical image...
# Generating displacement BC...
# Generating mesh...
# Loading ../data/phantom_lung3_125_1/phantom23/phantom23_mesh10.xdmf... 5128
# Interpolating FEM coefficients...
# Solving FEM model...
# Converting displacement field to image...
# torch.Size([256, 256, 94]) torch.Size([256, 256, 94]) torch.Size([256, 256, 94, 3]) torch.Size([256, 256, 94, 3]) (256, 256, 94)
# Saving ../data/phantom_lung3_125_1/phantom23/phantom23_elast.nii.gz
# Saving ../data/phantom_lung3_125_1/phantom23/phantom23_anat.nii.gz
# Saving ../data/phantom_lung3_125_1/phantom23/phantom23_disp.nii.gz
# Saving ../data/phantom_lung3_125_1/phantom23/phantom23_mask.nii.gz
# Setting random seed to 24
# Defining spatial domain...
# 5 31
# Sampling latent variables...
# Generating stiffness map..
# Generating anatomical image...
# Generating displacement BC...
# Generating mesh...
# Loading ../data/phantom_lung3_125_1/phantom24/phantom24_mesh10.xdmf... 5217
# Interpolating FEM coefficients...
# Solving FEM model...
# Converting displacement field to image...
# torch.Size([256, 256, 94]) torch.Size([256, 256, 94]) torch.Size([256, 256, 94, 3]) torch.Size([256, 256, 94, 3]) (256, 256, 94)
# Saving ../data/phantom_lung3_125_1/phantom24/phantom24_elast.nii.gz
# Saving ../data/phantom_lung3_125_1/phantom24/phantom24_anat.nii.gz
# Saving ../data/phantom_lung3_125_1/phantom24/phantom24_disp.nii.gz
# Saving ../data/phantom_lung3_125_1/phantom24/phantom24_mask.nii.gz
# Setting random seed to 25
# Defining spatial domain...
# 5 25
# Sampling latent variables...
# Generating stiffness map..
# Generating anatomical image...
# Generating displacement BC...
# Generating mesh...
# Loading ../data/phantom_lung3_125_1/phantom25/phantom25_mesh10.xdmf... 5404
# Interpolating FEM coefficients...
# Solving FEM model...
# Converting displacement field to image...
# torch.Size([256, 256, 94]) torch.Size([256, 256, 94]) torch.Size([256, 256, 94, 3]) torch.Size([256, 256, 94, 3]) (256, 256, 94)
# Saving ../data/phantom_lung3_125_1/phantom25/phantom25_elast.nii.gz
# Saving ../data/phantom_lung3_125_1/phantom25/phantom25_anat.nii.gz
# Saving ../data/phantom_lung3_125_1/phantom25/phantom25_disp.nii.gz
# Saving ../data/phantom_lung3_125_1/phantom25/phantom25_mask.nii.gz
# Setting random seed to 26
# Defining spatial domain...
# 4 50
# Sampling latent variables...
# Generating stiffness map..
# Generating anatomical image...
# Generating displacement BC...
# Generating mesh...
# Loading ../data/phantom_lung3_125_1/phantom26/phantom26_mesh10.xdmf... 5219
# Interpolating FEM coefficients...
# Solving FEM model...
# Converting displacement field to image...
# torch.Size([256, 256, 94]) torch.Size([256, 256, 94]) torch.Size([256, 256, 94, 3]) torch.Size([256, 256, 94, 3]) (256, 256, 94)
# Saving ../data/phantom_lung3_125_1/phantom26/phantom26_elast.nii.gz
# Saving ../data/phantom_lung3_125_1/phantom26/phantom26_anat.nii.gz
# Saving ../data/phantom_lung3_125_1/phantom26/phantom26_disp.nii.gz
# Saving ../data/phantom_lung3_125_1/phantom26/phantom26_mask.nii.gz
# Setting random seed to 27
# Defining spatial domain...
# 5 39
# Sampling latent variables...
# Generating stiffness map..
# Generating anatomical image...
# Generating displacement BC...
# Generating mesh...
# Loading ../data/phantom_lung3_125_1/phantom27/phantom27_mesh10.xdmf... 5137
# Interpolating FEM coefficients...
# Solving FEM model...
# Converting displacement field to image...
# torch.Size([256, 256, 94]) torch.Size([256, 256, 94]) torch.Size([256, 256, 94, 3]) torch.Size([256, 256, 94, 3]) (256, 256, 94)
# Saving ../data/phantom_lung3_125_1/phantom27/phantom27_elast.nii.gz
# Saving ../data/phantom_lung3_125_1/phantom27/phantom27_anat.nii.gz
# Saving ../data/phantom_lung3_125_1/phantom27/phantom27_disp.nii.gz
# Saving ../data/phantom_lung3_125_1/phantom27/phantom27_mask.nii.gz
# Setting random seed to 28
# Defining spatial domain...
# 5 26
# Sampling latent variables...
# Generating stiffness map..
# Generating anatomical image...
# Generating displacement BC...
# Generating mesh...
# Loading ../data/phantom_lung3_125_1/phantom28/phantom28_mesh10.xdmf... 5152
# Interpolating FEM coefficients...
# Solving FEM model...
# Converting displacement field to image...
# torch.Size([256, 256, 94]) torch.Size([256, 256, 94]) torch.Size([256, 256, 94, 3]) torch.Size([256, 256, 94, 3]) (256, 256, 94)
# Saving ../data/phantom_lung3_125_1/phantom28/phantom28_elast.nii.gz
# Saving ../data/phantom_lung3_125_1/phantom28/phantom28_anat.nii.gz
# Saving ../data/phantom_lung3_125_1/phantom28/phantom28_disp.nii.gz
# Saving ../data/phantom_lung3_125_1/phantom28/phantom28_mask.nii.gz
# Setting random seed to 29
# Defining spatial domain...
# 3 50
# Sampling latent variables...
# Generating stiffness map..
# Generating anatomical image...
# Generating displacement BC...
# Generating mesh...
# Loading ../data/phantom_lung3_125_1/phantom29/phantom29_mesh10.xdmf... 4968
# Interpolating FEM coefficients...
# Solving FEM model...
# Converting displacement field to image...
# torch.Size([256, 256, 94]) torch.Size([256, 256, 94]) torch.Size([256, 256, 94, 3]) torch.Size([256, 256, 94, 3]) (256, 256, 94)
# Saving ../data/phantom_lung3_125_1/phantom29/phantom29_elast.nii.gz
# Saving ../data/phantom_lung3_125_1/phantom29/phantom29_anat.nii.gz
# Saving ../data/phantom_lung3_125_1/phantom29/phantom29_disp.nii.gz
# Saving ../data/phantom_lung3_125_1/phantom29/phantom29_mask.nii.gz
# Setting random seed to 30
# Defining spatial domain...
# 5 24
# Sampling latent variables...
# Generating stiffness map..
# Generating anatomical image...
# Generating displacement BC...
# Generating mesh...
# Loading ../data/phantom_lung3_125_1/phantom30/phantom30_mesh10.xdmf... 5107
# Interpolating FEM coefficients...
# Solving FEM model...
# Converting displacement field to image...
# torch.Size([256, 256, 94]) torch.Size([256, 256, 94]) torch.Size([256, 256, 94, 3]) torch.Size([256, 256, 94, 3]) (256, 256, 94)
# Saving ../data/phantom_lung3_125_1/phantom30/phantom30_elast.nii.gz
# Saving ../data/phantom_lung3_125_1/phantom30/phantom30_anat.nii.gz
# Saving ../data/phantom_lung3_125_1/phantom30/phantom30_disp.nii.gz
# Saving ../data/phantom_lung3_125_1/phantom30/phantom30_mask.nii.gz
# Setting random seed to 31
# Defining spatial domain...
# 5 23
# Sampling latent variables...
# Generating stiffness map..
# Generating anatomical image...
# Generating displacement BC...
# Generating mesh...
# Loading ../data/phantom_lung3_125_1/phantom31/phantom31_mesh10.xdmf... 5276
# Interpolating FEM coefficients...
# Solving FEM model...
# Converting displacement field to image...
# torch.Size([256, 256, 94]) torch.Size([256, 256, 94]) torch.Size([256, 256, 94, 3]) torch.Size([256, 256, 94, 3]) (256, 256, 94)
# Saving ../data/phantom_lung3_125_1/phantom31/phantom31_elast.nii.gz
# Saving ../data/phantom_lung3_125_1/phantom31/phantom31_anat.nii.gz
# Saving ../data/phantom_lung3_125_1/phantom31/phantom31_disp.nii.gz
# Saving ../data/phantom_lung3_125_1/phantom31/phantom31_mask.nii.gz
# Setting random seed to 32
# Defining spatial domain...
# 2 50
# Sampling latent variables...
# Generating stiffness map..
# Generating anatomical image...
# Generating displacement BC...
# Generating mesh...
# Loading ../data/phantom_lung3_125_1/phantom32/phantom32_mesh10.xdmf... 5206
# Interpolating FEM coefficients...
# Solving FEM model...
# Converting displacement field to image...
# torch.Size([256, 256, 94]) torch.Size([256, 256, 94]) torch.Size([256, 256, 94, 3]) torch.Size([256, 256, 94, 3]) (256, 256, 94)
# Saving ../data/phantom_lung3_125_1/phantom32/phantom32_elast.nii.gz
# Saving ../data/phantom_lung3_125_1/phantom32/phantom32_anat.nii.gz
# Saving ../data/phantom_lung3_125_1/phantom32/phantom32_disp.nii.gz
# Saving ../data/phantom_lung3_125_1/phantom32/phantom32_mask.nii.gz
# Setting random seed to 33
# Defining spatial domain...
# 4 50
# Sampling latent variables...
# Generating stiffness map..
# Generating anatomical image...
# Generating displacement BC...
# Generating mesh...
# Loading ../data/phantom_lung3_125_1/phantom33/phantom33_mesh10.xdmf... 5045
# Interpolating FEM coefficients...
# Solving FEM model...
# Converting displacement field to image...
# torch.Size([256, 256, 94]) torch.Size([256, 256, 94]) torch.Size([256, 256, 94, 3]) torch.Size([256, 256, 94, 3]) (256, 256, 94)
# Saving ../data/phantom_lung3_125_1/phantom33/phantom33_elast.nii.gz
# Saving ../data/phantom_lung3_125_1/phantom33/phantom33_anat.nii.gz
# Saving ../data/phantom_lung3_125_1/phantom33/phantom33_disp.nii.gz
# Saving ../data/phantom_lung3_125_1/phantom33/phantom33_mask.nii.gz
# Setting random seed to 34
# Defining spatial domain...
# 5 30
# Sampling latent variables...
# Generating stiffness map..
# Generating anatomical image...
# Generating displacement BC...
# Generating mesh...
# Loading ../data/phantom_lung3_125_1/phantom34/phantom34_mesh10.xdmf... 5163
# Interpolating FEM coefficients...
# Solving FEM model...
# Converting displacement field to image...
# torch.Size([256, 256, 94]) torch.Size([256, 256, 94]) torch.Size([256, 256, 94, 3]) torch.Size([256, 256, 94, 3]) (256, 256, 94)
# Saving ../data/phantom_lung3_125_1/phantom34/phantom34_elast.nii.gz
# Saving ../data/phantom_lung3_125_1/phantom34/phantom34_anat.nii.gz
# Saving ../data/phantom_lung3_125_1/phantom34/phantom34_disp.nii.gz
# Saving ../data/phantom_lung3_125_1/phantom34/phantom34_mask.nii.gz
# Setting random seed to 35
# Defining spatial domain...
# 4 50
# Sampling latent variables...
# Generating stiffness map..
# Generating anatomical image...
# Generating displacement BC...
# Generating mesh...
# Loading ../data/phantom_lung3_125_1/phantom35/phantom35_mesh10.xdmf... 5232
# Interpolating FEM coefficients...
# Solving FEM model...
# Converting displacement field to image...
# torch.Size([256, 256, 94]) torch.Size([256, 256, 94]) torch.Size([256, 256, 94, 3]) torch.Size([256, 256, 94, 3]) (256, 256, 94)
# Saving ../data/phantom_lung3_125_1/phantom35/phantom35_elast.nii.gz
# Saving ../data/phantom_lung3_125_1/phantom35/phantom35_anat.nii.gz
# Saving ../data/phantom_lung3_125_1/phantom35/phantom35_disp.nii.gz
# Saving ../data/phantom_lung3_125_1/phantom35/phantom35_mask.nii.gz
# Setting random seed to 36
# Defining spatial domain...
# 5 48
# Sampling latent variables...
# Generating stiffness map..
# Generating anatomical image...
# Generating displacement BC...
# Generating mesh...
# Loading ../data/phantom_lung3_125_1/phantom36/phantom36_mesh10.xdmf... 5405
# Interpolating FEM coefficients...
# Solving FEM model...
# Converting displacement field to image...
# torch.Size([256, 256, 94]) torch.Size([256, 256, 94]) torch.Size([256, 256, 94, 3]) torch.Size([256, 256, 94, 3]) (256, 256, 94)
# Saving ../data/phantom_lung3_125_1/phantom36/phantom36_elast.nii.gz
# Saving ../data/phantom_lung3_125_1/phantom36/phantom36_anat.nii.gz
# Saving ../data/phantom_lung3_125_1/phantom36/phantom36_disp.nii.gz
# Saving ../data/phantom_lung3_125_1/phantom36/phantom36_mask.nii.gz
# Setting random seed to 37
# Defining spatial domain...
# 5 41
# Sampling latent variables...
# Generating stiffness map..
# Generating anatomical image...
# Generating displacement BC...
# Generating mesh...
# Loading ../data/phantom_lung3_125_1/phantom37/phantom37_mesh10.xdmf... 5327
# Interpolating FEM coefficients...
# Solving FEM model...
# Converting displacement field to image...
# torch.Size([256, 256, 94]) torch.Size([256, 256, 94]) torch.Size([256, 256, 94, 3]) torch.Size([256, 256, 94, 3]) (256, 256, 94)
# Saving ../data/phantom_lung3_125_1/phantom37/phantom37_elast.nii.gz
# Saving ../data/phantom_lung3_125_1/phantom37/phantom37_anat.nii.gz
# Saving ../data/phantom_lung3_125_1/phantom37/phantom37_disp.nii.gz
# Saving ../data/phantom_lung3_125_1/phantom37/phantom37_mask.nii.gz
# Setting random seed to 38
# Defining spatial domain...
# 5 41
# Sampling latent variables...
# Generating stiffness map..
# Generating anatomical image...
# Generating displacement BC...
# Generating mesh...
# Loading ../data/phantom_lung3_125_1/phantom38/phantom38_mesh10.xdmf... 5244
# Interpolating FEM coefficients...
# Solving FEM model...
# Converting displacement field to image...
# torch.Size([256, 256, 94]) torch.Size([256, 256, 94]) torch.Size([256, 256, 94, 3]) torch.Size([256, 256, 94, 3]) (256, 256, 94)
# Saving ../data/phantom_lung3_125_1/phantom38/phantom38_elast.nii.gz
# Saving ../data/phantom_lung3_125_1/phantom38/phantom38_anat.nii.gz
# Saving ../data/phantom_lung3_125_1/phantom38/phantom38_disp.nii.gz
# Saving ../data/phantom_lung3_125_1/phantom38/phantom38_mask.nii.gz
# Setting random seed to 39
# Defining spatial domain...
# 4 50
# Sampling latent variables...
# Generating stiffness map..
# Generating anatomical image...
# Generating displacement BC...
# Generating mesh...
# Loading ../data/phantom_lung3_125_1/phantom39/phantom39_mesh10.xdmf... 5134
# Interpolating FEM coefficients...
# Solving FEM model...
# Converting displacement field to image...
# torch.Size([256, 256, 94]) torch.Size([256, 256, 94]) torch.Size([256, 256, 94, 3]) torch.Size([256, 256, 94, 3]) (256, 256, 94)
# Saving ../data/phantom_lung3_125_1/phantom39/phantom39_elast.nii.gz
# Saving ../data/phantom_lung3_125_1/phantom39/phantom39_anat.nii.gz
# Saving ../data/phantom_lung3_125_1/phantom39/phantom39_disp.nii.gz
# Saving ../data/phantom_lung3_125_1/phantom39/phantom39_mask.nii.gz
# Setting random seed to 40
# Defining spatial domain...
# 5 27
# Sampling latent variables...
# Generating stiffness map..
# Generating anatomical image...
# Generating displacement BC...
# Generating mesh...
# Loading ../data/phantom_lung3_125_1/phantom40/phantom40_mesh10.xdmf... 5338
# Interpolating FEM coefficients...
# Solving FEM model...
# Converting displacement field to image...
# torch.Size([256, 256, 94]) torch.Size([256, 256, 94]) torch.Size([256, 256, 94, 3]) torch.Size([256, 256, 94, 3]) (256, 256, 94)
# Saving ../data/phantom_lung3_125_1/phantom40/phantom40_elast.nii.gz
# Saving ../data/phantom_lung3_125_1/phantom40/phantom40_anat.nii.gz
# Saving ../data/phantom_lung3_125_1/phantom40/phantom40_disp.nii.gz
# Saving ../data/phantom_lung3_125_1/phantom40/phantom40_mask.nii.gz
# Setting random seed to 41
# Defining spatial domain...
# 4 50
# Sampling latent variables...
# Generating stiffness map..
# Generating anatomical image...
# Generating displacement BC...
# Generating mesh...
# Loading ../data/phantom_lung3_125_1/phantom41/phantom41_mesh10.xdmf... 5329
# Interpolating FEM coefficients...
# Solving FEM model...
# Converting displacement field to image...
# torch.Size([256, 256, 94]) torch.Size([256, 256, 94]) torch.Size([256, 256, 94, 3]) torch.Size([256, 256, 94, 3]) (256, 256, 94)
# Saving ../data/phantom_lung3_125_1/phantom41/phantom41_elast.nii.gz
# Saving ../data/phantom_lung3_125_1/phantom41/phantom41_anat.nii.gz
# Saving ../data/phantom_lung3_125_1/phantom41/phantom41_disp.nii.gz
# Saving ../data/phantom_lung3_125_1/phantom41/phantom41_mask.nii.gz
# Setting random seed to 42
# Defining spatial domain...
# 5 19
# Sampling latent variables...
# Generating stiffness map..
# Generating anatomical image...
# Generating displacement BC...
# Generating mesh...
# Loading ../data/phantom_lung3_125_1/phantom42/phantom42_mesh10.xdmf... 4961
# Interpolating FEM coefficients...
# Solving FEM model...
# Converting displacement field to image...
# torch.Size([256, 256, 94]) torch.Size([256, 256, 94]) torch.Size([256, 256, 94, 3]) torch.Size([256, 256, 94, 3]) (256, 256, 94)
# Saving ../data/phantom_lung3_125_1/phantom42/phantom42_elast.nii.gz
# Saving ../data/phantom_lung3_125_1/phantom42/phantom42_anat.nii.gz
# Saving ../data/phantom_lung3_125_1/phantom42/phantom42_disp.nii.gz
# Saving ../data/phantom_lung3_125_1/phantom42/phantom42_mask.nii.gz
# Setting random seed to 43
# Defining spatial domain...
# 5 50
# Sampling latent variables...
# Generating stiffness map..
# Generating anatomical image...
# Generating displacement BC...
# Generating mesh...
# Loading ../data/phantom_lung3_125_1/phantom43/phantom43_mesh10.xdmf... 5159
# Interpolating FEM coefficients...
# Solving FEM model...
# Converting displacement field to image...
# torch.Size([256, 256, 94]) torch.Size([256, 256, 94]) torch.Size([256, 256, 94, 3]) torch.Size([256, 256, 94, 3]) (256, 256, 94)
# Saving ../data/phantom_lung3_125_1/phantom43/phantom43_elast.nii.gz
# Saving ../data/phantom_lung3_125_1/phantom43/phantom43_anat.nii.gz
# Saving ../data/phantom_lung3_125_1/phantom43/phantom43_disp.nii.gz
# Saving ../data/phantom_lung3_125_1/phantom43/phantom43_mask.nii.gz
# Setting random seed to 44
# Defining spatial domain...
# 4 50
# Sampling latent variables...
# Generating stiffness map..
# Generating anatomical image...
# Generating displacement BC...
# Generating mesh...
# Loading ../data/phantom_lung3_125_1/phantom44/phantom44_mesh10.xdmf... 5277
# Interpolating FEM coefficients...
# Solving FEM model...
# Converting displacement field to image...
# torch.Size([256, 256, 94]) torch.Size([256, 256, 94]) torch.Size([256, 256, 94, 3]) torch.Size([256, 256, 94, 3]) (256, 256, 94)
# Saving ../data/phantom_lung3_125_1/phantom44/phantom44_elast.nii.gz
# Saving ../data/phantom_lung3_125_1/phantom44/phantom44_anat.nii.gz
# Saving ../data/phantom_lung3_125_1/phantom44/phantom44_disp.nii.gz
# Saving ../data/phantom_lung3_125_1/phantom44/phantom44_mask.nii.gz
# Setting random seed to 45
# Defining spatial domain...
# 5 40
# Sampling latent variables...
# Generating stiffness map..
# Generating anatomical image...
# Generating displacement BC...
# Generating mesh...
# Loading ../data/phantom_lung3_125_1/phantom45/phantom45_mesh10.xdmf... 5294
# Interpolating FEM coefficients...
# Solving FEM model...
# Converting displacement field to image...
# torch.Size([256, 256, 94]) torch.Size([256, 256, 94]) torch.Size([256, 256, 94, 3]) torch.Size([256, 256, 94, 3]) (256, 256, 94)
# Saving ../data/phantom_lung3_125_1/phantom45/phantom45_elast.nii.gz
# Saving ../data/phantom_lung3_125_1/phantom45/phantom45_anat.nii.gz
# Saving ../data/phantom_lung3_125_1/phantom45/phantom45_disp.nii.gz
# Saving ../data/phantom_lung3_125_1/phantom45/phantom45_mask.nii.gz
# Setting random seed to 46
# Defining spatial domain...
# 5 27
# Sampling latent variables...
# Generating stiffness map..
# Generating anatomical image...
# Generating displacement BC...
# Generating mesh...
# Loading ../data/phantom_lung3_125_1/phantom46/phantom46_mesh10.xdmf... 5293
# Interpolating FEM coefficients...
# Solving FEM model...
# Converting displacement field to image...
# torch.Size([256, 256, 94]) torch.Size([256, 256, 94]) torch.Size([256, 256, 94, 3]) torch.Size([256, 256, 94, 3]) (256, 256, 94)
# Saving ../data/phantom_lung3_125_1/phantom46/phantom46_elast.nii.gz
# Saving ../data/phantom_lung3_125_1/phantom46/phantom46_anat.nii.gz
# Saving ../data/phantom_lung3_125_1/phantom46/phantom46_disp.nii.gz
# Saving ../data/phantom_lung3_125_1/phantom46/phantom46_mask.nii.gz
# Setting random seed to 47
# Defining spatial domain...
# 3 50
# Sampling latent variables...
# Generating stiffness map..
# Generating anatomical image...
# Generating displacement BC...
# Generating mesh...
# Loading ../data/phantom_lung3_125_1/phantom47/phantom47_mesh10.xdmf... 5156
# Interpolating FEM coefficients...
# Solving FEM model...
# Converting displacement field to image...
# torch.Size([256, 256, 94]) torch.Size([256, 256, 94]) torch.Size([256, 256, 94, 3]) torch.Size([256, 256, 94, 3]) (256, 256, 94)
# Saving ../data/phantom_lung3_125_1/phantom47/phantom47_elast.nii.gz
# Saving ../data/phantom_lung3_125_1/phantom47/phantom47_anat.nii.gz
# Saving ../data/phantom_lung3_125_1/phantom47/phantom47_disp.nii.gz
# Saving ../data/phantom_lung3_125_1/phantom47/phantom47_mask.nii.gz
# Setting random seed to 48
# Defining spatial domain...
# 5 35
# Sampling latent variables...
# Generating stiffness map..
# Generating anatomical image...
# Generating displacement BC...
# Generating mesh...
# Loading ../data/phantom_lung3_125_1/phantom48/phantom48_mesh10.xdmf... 5260
# Interpolating FEM coefficients...
# Solving FEM model...
# Converting displacement field to image...
# torch.Size([256, 256, 94]) torch.Size([256, 256, 94]) torch.Size([256, 256, 94, 3]) torch.Size([256, 256, 94, 3]) (256, 256, 94)
# Saving ../data/phantom_lung3_125_1/phantom48/phantom48_elast.nii.gz
# Saving ../data/phantom_lung3_125_1/phantom48/phantom48_anat.nii.gz
# Saving ../data/phantom_lung3_125_1/phantom48/phantom48_disp.nii.gz
# Saving ../data/phantom_lung3_125_1/phantom48/phantom48_mask.nii.gz
# Setting random seed to 49
# Defining spatial domain...
# 5 48
# Sampling latent variables...
# Generating stiffness map..
# Generating anatomical image...
# Generating displacement BC...
# Generating mesh...
# Loading ../data/phantom_lung3_125_1/phantom49/phantom49_mesh10.xdmf... 5183
# Interpolating FEM coefficients...
# Solving FEM model...
# Converting displacement field to image...
# torch.Size([256, 256, 94]) torch.Size([256, 256, 94]) torch.Size([256, 256, 94, 3]) torch.Size([256, 256, 94, 3]) (256, 256, 94)
# Saving ../data/phantom_lung3_125_1/phantom49/phantom49_elast.nii.gz
# Saving ../data/phantom_lung3_125_1/phantom49/phantom49_anat.nii.gz
# Saving ../data/phantom_lung3_125_1/phantom49/phantom49_disp.nii.gz
# Saving ../data/phantom_lung3_125_1/phantom49/phantom49_mask.nii.gz
# Setting random seed to 50
# Defining spatial domain...
# 5 27
# Sampling latent variables...
# Generating stiffness map..
# Generating anatomical image...
# Generating displacement BC...
# Generating mesh...
# Loading ../data/phantom_lung3_125_1/phantom50/phantom50_mesh10.xdmf... 5219
# Interpolating FEM coefficients...
# Solving FEM model...
# Converting displacement field to image...
# torch.Size([256, 256, 94]) torch.Size([256, 256, 94]) torch.Size([256, 256, 94, 3]) torch.Size([256, 256, 94, 3]) (256, 256, 94)
# Saving ../data/phantom_lung3_125_1/phantom50/phantom50_elast.nii.gz
# Saving ../data/phantom_lung3_125_1/phantom50/phantom50_anat.nii.gz
# Saving ../data/phantom_lung3_125_1/phantom50/phantom50_disp.nii.gz
# Saving ../data/phantom_lung3_125_1/phantom50/phantom50_mask.nii.gz
# Setting random seed to 51
# Defining spatial domain...
# 5 27
# Sampling latent variables...
# Generating stiffness map..
# Generating anatomical image...
# Generating displacement BC...
# Generating mesh...
# Loading ../data/phantom_lung3_125_1/phantom51/phantom51_mesh10.xdmf... 5275
# Interpolating FEM coefficients...
# Solving FEM model...
# Converting displacement field to image...
# torch.Size([256, 256, 94]) torch.Size([256, 256, 94]) torch.Size([256, 256, 94, 3]) torch.Size([256, 256, 94, 3]) (256, 256, 94)
# Saving ../data/phantom_lung3_125_1/phantom51/phantom51_elast.nii.gz
# Saving ../data/phantom_lung3_125_1/phantom51/phantom51_anat.nii.gz
# Saving ../data/phantom_lung3_125_1/phantom51/phantom51_disp.nii.gz
# Saving ../data/phantom_lung3_125_1/phantom51/phantom51_mask.nii.gz
# Setting random seed to 52
# Defining spatial domain...
# 5 35
# Sampling latent variables...
# Generating stiffness map..
# Generating anatomical image...
# Generating displacement BC...
# Generating mesh...
# Loading ../data/phantom_lung3_125_1/phantom52/phantom52_mesh10.xdmf... 5135
# Interpolating FEM coefficients...
# Solving FEM model...
# Converting displacement field to image...
# torch.Size([256, 256, 94]) torch.Size([256, 256, 94]) torch.Size([256, 256, 94, 3]) torch.Size([256, 256, 94, 3]) (256, 256, 94)
# Saving ../data/phantom_lung3_125_1/phantom52/phantom52_elast.nii.gz
# Saving ../data/phantom_lung3_125_1/phantom52/phantom52_anat.nii.gz
# Saving ../data/phantom_lung3_125_1/phantom52/phantom52_disp.nii.gz
# Saving ../data/phantom_lung3_125_1/phantom52/phantom52_mask.nii.gz
# Setting random seed to 53
# Defining spatial domain...
# 5 36
# Sampling latent variables...
# Generating stiffness map..
# Generating anatomical image...
# Generating displacement BC...
# Generating mesh...
# Loading ../data/phantom_lung3_125_1/phantom53/phantom53_mesh10.xdmf... 5426
# Interpolating FEM coefficients...
# Solving FEM model...
# Converting displacement field to image...
# torch.Size([256, 256, 94]) torch.Size([256, 256, 94]) torch.Size([256, 256, 94, 3]) torch.Size([256, 256, 94, 3]) (256, 256, 94)
# Saving ../data/phantom_lung3_125_1/phantom53/phantom53_elast.nii.gz
# Saving ../data/phantom_lung3_125_1/phantom53/phantom53_anat.nii.gz
# Saving ../data/phantom_lung3_125_1/phantom53/phantom53_disp.nii.gz
# Saving ../data/phantom_lung3_125_1/phantom53/phantom53_mask.nii.gz
# Setting random seed to 54
# Defining spatial domain...
# 5 22
# Sampling latent variables...
# Generating stiffness map..
# Generating anatomical image...
# Generating displacement BC...
# Generating mesh...
# Loading ../data/phantom_lung3_125_1/phantom54/phantom54_mesh10.xdmf... 5278
# Interpolating FEM coefficients...
# Solving FEM model...
# Converting displacement field to image...
# torch.Size([256, 256, 94]) torch.Size([256, 256, 94]) torch.Size([256, 256, 94, 3]) torch.Size([256, 256, 94, 3]) (256, 256, 94)
# Saving ../data/phantom_lung3_125_1/phantom54/phantom54_elast.nii.gz
# Saving ../data/phantom_lung3_125_1/phantom54/phantom54_anat.nii.gz
# Saving ../data/phantom_lung3_125_1/phantom54/phantom54_disp.nii.gz
# Saving ../data/phantom_lung3_125_1/phantom54/phantom54_mask.nii.gz
# Setting random seed to 55
# Defining spatial domain...
# 5 28
# Sampling latent variables...
# Generating stiffness map..
# Generating anatomical image...
# Generating displacement BC...
# Generating mesh...
# Loading ../data/phantom_lung3_125_1/phantom55/phantom55_mesh10.xdmf... 5252
# Interpolating FEM coefficients...
# Solving FEM model...
# Converting displacement field to image...
# torch.Size([256, 256, 94]) torch.Size([256, 256, 94]) torch.Size([256, 256, 94, 3]) torch.Size([256, 256, 94, 3]) (256, 256, 94)
# Saving ../data/phantom_lung3_125_1/phantom55/phantom55_elast.nii.gz
# Saving ../data/phantom_lung3_125_1/phantom55/phantom55_anat.nii.gz
# Saving ../data/phantom_lung3_125_1/phantom55/phantom55_disp.nii.gz
# Saving ../data/phantom_lung3_125_1/phantom55/phantom55_mask.nii.gz
# Setting random seed to 56
# Defining spatial domain...
# 5 42
# Sampling latent variables...
# Generating stiffness map..
# Generating anatomical image...
# Generating displacement BC...
# Generating mesh...
# Loading ../data/phantom_lung3_125_1/phantom56/phantom56_mesh10.xdmf... 5217
# Interpolating FEM coefficients...
# Solving FEM model...
# Converting displacement field to image...
# torch.Size([256, 256, 94]) torch.Size([256, 256, 94]) torch.Size([256, 256, 94, 3]) torch.Size([256, 256, 94, 3]) (256, 256, 94)
# Saving ../data/phantom_lung3_125_1/phantom56/phantom56_elast.nii.gz
# Saving ../data/phantom_lung3_125_1/phantom56/phantom56_anat.nii.gz
# Saving ../data/phantom_lung3_125_1/phantom56/phantom56_disp.nii.gz
# Saving ../data/phantom_lung3_125_1/phantom56/phantom56_mask.nii.gz
# Setting random seed to 57
# Defining spatial domain...
# 5 28
# Sampling latent variables...
# Generating stiffness map..
# Generating anatomical image...
# Generating displacement BC...
# Generating mesh...
# Loading ../data/phantom_lung3_125_1/phantom57/phantom57_mesh10.xdmf... 5219
# Interpolating FEM coefficients...
# Solving FEM model...
# Converting displacement field to image...
# torch.Size([256, 256, 94]) torch.Size([256, 256, 94]) torch.Size([256, 256, 94, 3]) torch.Size([256, 256, 94, 3]) (256, 256, 94)
# Saving ../data/phantom_lung3_125_1/phantom57/phantom57_elast.nii.gz
# Saving ../data/phantom_lung3_125_1/phantom57/phantom57_anat.nii.gz
# Saving ../data/phantom_lung3_125_1/phantom57/phantom57_disp.nii.gz
# Saving ../data/phantom_lung3_125_1/phantom57/phantom57_mask.nii.gz
# Setting random seed to 58
# Defining spatial domain...
# 5 47
# Sampling latent variables...
# Generating stiffness map..
# Generating anatomical image...
# Generating displacement BC...
# Generating mesh...
# Loading ../data/phantom_lung3_125_1/phantom58/phantom58_mesh10.xdmf... 5149
# Interpolating FEM coefficients...
# Solving FEM model...
# Converting displacement field to image...
# torch.Size([256, 256, 94]) torch.Size([256, 256, 94]) torch.Size([256, 256, 94, 3]) torch.Size([256, 256, 94, 3]) (256, 256, 94)
# Saving ../data/phantom_lung3_125_1/phantom58/phantom58_elast.nii.gz
# Saving ../data/phantom_lung3_125_1/phantom58/phantom58_anat.nii.gz
# Saving ../data/phantom_lung3_125_1/phantom58/phantom58_disp.nii.gz
# Saving ../data/phantom_lung3_125_1/phantom58/phantom58_mask.nii.gz
# Setting random seed to 59
# Defining spatial domain...
# 5 33
# Sampling latent variables...
# Generating stiffness map..
# Generating anatomical image...
# Generating displacement BC...
# Generating mesh...
# Loading ../data/phantom_lung3_125_1/phantom59/phantom59_mesh10.xdmf... 5408
# Interpolating FEM coefficients...
# Solving FEM model...
# Converting displacement field to image...
# torch.Size([256, 256, 94]) torch.Size([256, 256, 94]) torch.Size([256, 256, 94, 3]) torch.Size([256, 256, 94, 3]) (256, 256, 94)
# Saving ../data/phantom_lung3_125_1/phantom59/phantom59_elast.nii.gz
# Saving ../data/phantom_lung3_125_1/phantom59/phantom59_anat.nii.gz
# Saving ../data/phantom_lung3_125_1/phantom59/phantom59_disp.nii.gz
# Saving ../data/phantom_lung3_125_1/phantom59/phantom59_mask.nii.gz
# Setting random seed to 60
# Defining spatial domain...
# 5 44
# Sampling latent variables...
# Generating stiffness map..
# Generating anatomical image...
# Generating displacement BC...
# Generating mesh...
# Loading ../data/phantom_lung3_125_1/phantom60/phantom60_mesh10.xdmf... 5257
# Interpolating FEM coefficients...
# Solving FEM model...
# Converting displacement field to image...
# torch.Size([256, 256, 94]) torch.Size([256, 256, 94]) torch.Size([256, 256, 94, 3]) torch.Size([256, 256, 94, 3]) (256, 256, 94)
# Saving ../data/phantom_lung3_125_1/phantom60/phantom60_elast.nii.gz
# Saving ../data/phantom_lung3_125_1/phantom60/phantom60_anat.nii.gz
# Saving ../data/phantom_lung3_125_1/phantom60/phantom60_disp.nii.gz
# Saving ../data/phantom_lung3_125_1/phantom60/phantom60_mask.nii.gz
# Setting random seed to 61
# Defining spatial domain...
# 5 27
# Sampling latent variables...
# Generating stiffness map..
# Generating anatomical image...
# Generating displacement BC...
# Generating mesh...
# Loading ../data/phantom_lung3_125_1/phantom61/phantom61_mesh10.xdmf... 5019
# Interpolating FEM coefficients...
# Solving FEM model...
# Converting displacement field to image...
# torch.Size([256, 256, 94]) torch.Size([256, 256, 94]) torch.Size([256, 256, 94, 3]) torch.Size([256, 256, 94, 3]) (256, 256, 94)
# Saving ../data/phantom_lung3_125_1/phantom61/phantom61_elast.nii.gz
# Saving ../data/phantom_lung3_125_1/phantom61/phantom61_anat.nii.gz
# Saving ../data/phantom_lung3_125_1/phantom61/phantom61_disp.nii.gz
# Saving ../data/phantom_lung3_125_1/phantom61/phantom61_mask.nii.gz
# Setting random seed to 62
# Defining spatial domain...
# 4 50
# Sampling latent variables...
# Generating stiffness map..
# Generating anatomical image...
# Generating displacement BC...
# Generating mesh...
# Loading ../data/phantom_lung3_125_1/phantom62/phantom62_mesh10.xdmf... 5213
# Interpolating FEM coefficients...
# Solving FEM model...
# Converting displacement field to image...
# torch.Size([256, 256, 94]) torch.Size([256, 256, 94]) torch.Size([256, 256, 94, 3]) torch.Size([256, 256, 94, 3]) (256, 256, 94)
# Saving ../data/phantom_lung3_125_1/phantom62/phantom62_elast.nii.gz
# Saving ../data/phantom_lung3_125_1/phantom62/phantom62_anat.nii.gz
# ...
# Generating stiffness map..
# Generating anatomical image...
# Generating displacement BC...
# Generating mesh...
# Loading ../data/phantom_lung3_125_0/phantom7/phantom7_mesh10.xdmf... 5324
# Interpolating FEM coefficients...
# Solving FEM model...
# Converting displacement field to image...
# torch.Size([256, 256, 94]) torch.Size([256, 256, 94]) torch.Size([256, 256, 94, 3]) torch.Size([256, 256, 94, 3]) (256, 256, 94)
# Saving ../data/phantom_lung3_125_0/phantom7/phantom7_elast.nii.gz
# Saving ../data/phantom_lung3_125_0/phantom7/phantom7_anat.nii.gz
# Saving ../data/phantom_lung3_125_0/phantom7/phantom7_disp.nii.gz
# Saving ../data/phantom_lung3_125_0/phantom7/phantom7_mask.nii.gz
# Setting random seed to 8
# Defining spatial domain...
# 5 39
# Sampling latent variables...
# Generating stiffness map..
# Generating anatomical image...
# Generating displacement BC...
# Generating mesh...
# Loading ../data/phantom_lung3_125_0/phantom8/phantom8_mesh10.xdmf... 5454
# Interpolating FEM coefficients...
# Solving FEM model...
# Converting displacement field to image...
# torch.Size([256, 256, 94]) torch.Size([256, 256, 94]) torch.Size([256, 256, 94, 3]) torch.Size([256, 256, 94, 3]) (256, 256, 94)
# Saving ../data/phantom_lung3_125_0/phantom8/phantom8_elast.nii.gz
# Saving ../data/phantom_lung3_125_0/phantom8/phantom8_anat.nii.gz
# Saving ../data/phantom_lung3_125_0/phantom8/phantom8_disp.nii.gz
# Saving ../data/phantom_lung3_125_0/phantom8/phantom8_mask.nii.gz
# Setting random seed to 9
# Defining spatial domain...
# 5 25
# Sampling latent variables...
# Generating stiffness map..
# Generating anatomical image...
# Generating displacement BC...
# Generating mesh...
# Loading ../data/phantom_lung3_125_0/phantom9/phantom9_mesh10.xdmf... 5266
# Interpolating FEM coefficients...
# Solving FEM model...
# Converting displacement field to image...
# torch.Size([256, 256, 94]) torch.Size([256, 256, 94]) torch.Size([256, 256, 94, 3]) torch.Size([256, 256, 94, 3]) (256, 256, 94)
# Saving ../data/phantom_lung3_125_0/phantom9/phantom9_elast.nii.gz
# Saving ../data/phantom_lung3_125_0/phantom9/phantom9_anat.nii.gz
# Saving ../data/phantom_lung3_125_0/phantom9/phantom9_disp.nii.gz
# Saving ../data/phantom_lung3_125_0/phantom9/phantom9_mask.nii.gz
# Setting random seed to 10
# Defining spatial domain...
# 4 50
# Sampling latent variables...
# Generating stiffness map..
# Generating anatomical image...
# Generating displacement BC...
# Generating mesh...
# Loading ../data/phantom_lung3_125_0/phantom10/phantom10_mesh10.xdmf... 5105
# Interpolating FEM coefficients...
# Solving FEM model...
# Converting displacement field to image...
# torch.Size([256, 256, 94]) torch.Size([256, 256, 94]) torch.Size([256, 256, 94, 3]) torch.Size([256, 256, 94, 3]) (256, 256, 94)
# Saving ../data/phantom_lung3_125_0/phantom10/phantom10_elast.nii.gz
# Saving ../data/phantom_lung3_125_0/phantom10/phantom10_anat.nii.gz
# Saving ../data/phantom_lung3_125_0/phantom10/phantom10_disp.nii.gz
# Saving ../data/phantom_lung3_125_0/phantom10/phantom10_mask.nii.gz
# Setting random seed to 11
# Defining spatial domain...
# 5 46
# Sampling latent variables...
# Generating stiffness map..
# Generating anatomical image...
# Generating displacement BC...
# Generating mesh...
# Loading ../data/phantom_lung3_125_0/phantom11/phantom11_mesh10.xdmf... 5108
# Interpolating FEM coefficients...
# Solving FEM model...
# Converting displacement field to image...
# torch.Size([256, 256, 94]) torch.Size([256, 256, 94]) torch.Size([256, 256, 94, 3]) torch.Size([256, 256, 94, 3]) (256, 256, 94)
# Saving ../data/phantom_lung3_125_0/phantom11/phantom11_elast.nii.gz
# Saving ../data/phantom_lung3_125_0/phantom11/phantom11_anat.nii.gz
# Saving ../data/phantom_lung3_125_0/phantom11/phantom11_disp.nii.gz
# Saving ../data/phantom_lung3_125_0/phantom11/phantom11_mask.nii.gz
# Setting random seed to 12
# Defining spatial domain...
# 5 34
# Sampling latent variables...
# Generating stiffness map..
# Generating anatomical image...
# Generating displacement BC...
# Generating mesh...
# Loading ../data/phantom_lung3_125_0/phantom12/phantom12_mesh10.xdmf... 5247
# Interpolating FEM coefficients...
# Solving FEM model...
# Converting displacement field to image...
# torch.Size([256, 256, 94]) torch.Size([256, 256, 94]) torch.Size([256, 256, 94, 3]) torch.Size([256, 256, 94, 3]) (256, 256, 94)
# Saving ../data/phantom_lung3_125_0/phantom12/phantom12_elast.nii.gz
# Saving ../data/phantom_lung3_125_0/phantom12/phantom12_anat.nii.gz
# Saving ../data/phantom_lung3_125_0/phantom12/phantom12_disp.nii.gz
# Saving ../data/phantom_lung3_125_0/phantom12/phantom12_mask.nii.gz
# Setting random seed to 13
# Defining spatial domain...
# 5 48
# Sampling latent variables...
# Generating stiffness map..
# Generating anatomical image...
# Generating displacement BC...
# Generating mesh...
# Loading ../data/phantom_lung3_125_0/phantom13/phantom13_mesh10.xdmf... 5197
# Interpolating FEM coefficients...
# Solving FEM model...
# Converting displacement field to image...
# torch.Size([256, 256, 94]) torch.Size([256, 256, 94]) torch.Size([256, 256, 94, 3]) torch.Size([256, 256, 94, 3]) (256, 256, 94)
# Saving ../data/phantom_lung3_125_0/phantom13/phantom13_elast.nii.gz
# Saving ../data/phantom_lung3_125_0/phantom13/phantom13_anat.nii.gz
# Saving ../data/phantom_lung3_125_0/phantom13/phantom13_disp.nii.gz
# Saving ../data/phantom_lung3_125_0/phantom13/phantom13_mask.nii.gz
# Setting random seed to 14
# Defining spatial domain...
# 5 35
# Sampling latent variables...
# Generating stiffness map..
# Generating anatomical image...
# Generating displacement BC...
# Generating mesh...
# Loading ../data/phantom_lung3_125_0/phantom14/phantom14_mesh10.xdmf... 5225
# Interpolating FEM coefficients...
# Solving FEM model...
# Converting displacement field to image...
# torch.Size([256, 256, 94]) torch.Size([256, 256, 94]) torch.Size([256, 256, 94, 3]) torch.Size([256, 256, 94, 3]) (256, 256, 94)
# Saving ../data/phantom_lung3_125_0/phantom14/phantom14_elast.nii.gz
# Saving ../data/phantom_lung3_125_0/phantom14/phantom14_anat.nii.gz
# Saving ../data/phantom_lung3_125_0/phantom14/phantom14_disp.nii.gz
# Saving ../data/phantom_lung3_125_0/phantom14/phantom14_mask.nii.gz
# Setting random seed to 15
# Defining spatial domain...
# 5 49
# Sampling latent variables...
# Generating stiffness map..
# Generating anatomical image...
# Generating displacement BC...
# Generating mesh...
# Loading ../data/phantom_lung3_125_0/phantom15/phantom15_mesh10.xdmf... 5252
# Interpolating FEM coefficients...
# Solving FEM model...
# Converting displacement field to image...
# torch.Size([256, 256, 94]) torch.Size([256, 256, 94]) torch.Size([256, 256, 94, 3]) torch.Size([256, 256, 94, 3]) (256, 256, 94)
# Saving ../data/phantom_lung3_125_0/phantom15/phantom15_elast.nii.gz
# Saving ../data/phantom_lung3_125_0/phantom15/phantom15_anat.nii.gz
# Saving ../data/phantom_lung3_125_0/phantom15/phantom15_disp.nii.gz
# Saving ../data/phantom_lung3_125_0/phantom15/phantom15_mask.nii.gz
# Setting random seed to 16
# Defining spatial domain...
# 5 25
# Sampling latent variables...
# Generating stiffness map..
# Generating anatomical image...
# Generating displacement BC...
# Generating mesh...
# Loading ../data/phantom_lung3_125_0/phantom16/phantom16_mesh10.xdmf... 4979
# Interpolating FEM coefficients...
# Solving FEM model...
# Converting displacement field to image...
# torch.Size([256, 256, 94]) torch.Size([256, 256, 94]) torch.Size([256, 256, 94, 3]) torch.Size([256, 256, 94, 3]) (256, 256, 94)
# Saving ../data/phantom_lung3_125_0/phantom16/phantom16_elast.nii.gz
# Saving ../data/phantom_lung3_125_0/phantom16/phantom16_anat.nii.gz
# Saving ../data/phantom_lung3_125_0/phantom16/phantom16_disp.nii.gz
# Saving ../data/phantom_lung3_125_0/phantom16/phantom16_mask.nii.gz
# Setting random seed to 17
# Defining spatial domain...
# 5 34
# Sampling latent variables...
# Generating stiffness map..
# Generating anatomical image...
# Generating displacement BC...
# Generating mesh...
# Loading ../data/phantom_lung3_125_0/phantom17/phantom17_mesh10.xdmf... 5118
# Interpolating FEM coefficients...
# Solving FEM model...
# Converting displacement field to image...
# torch.Size([256, 256, 94]) torch.Size([256, 256, 94]) torch.Size([256, 256, 94, 3]) torch.Size([256, 256, 94, 3]) (256, 256, 94)
# Saving ../data/phantom_lung3_125_0/phantom17/phantom17_elast.nii.gz
# Saving ../data/phantom_lung3_125_0/phantom17/phantom17_anat.nii.gz
# Saving ../data/phantom_lung3_125_0/phantom17/phantom17_disp.nii.gz
# Saving ../data/phantom_lung3_125_0/phantom17/phantom17_mask.nii.gz
# Setting random seed to 18
# Defining spatial domain...
# 5 42
# Sampling latent variables...
# Generating stiffness map..
# Generating anatomical image...
# Generating displacement BC...
# Generating mesh...
# Loading ../data/phantom_lung3_125_0/phantom18/phantom18_mesh10.xdmf... 5097
# Interpolating FEM coefficients...
# Solving FEM model...
# Converting displacement field to image...
# torch.Size([256, 256, 94]) torch.Size([256, 256, 94]) torch.Size([256, 256, 94, 3]) torch.Size([256, 256, 94, 3]) (256, 256, 94)
# Saving ../data/phantom_lung3_125_0/phantom18/phantom18_elast.nii.gz
# Saving ../data/phantom_lung3_125_0/phantom18/phantom18_anat.nii.gz
# Saving ../data/phantom_lung3_125_0/phantom18/phantom18_disp.nii.gz
# Saving ../data/phantom_lung3_125_0/phantom18/phantom18_mask.nii.gz
# Setting random seed to 19
# Defining spatial domain...
# 3 50
# Sampling latent variables...
# Generating stiffness map..
# Generating anatomical image...
# Generating displacement BC...
# Generating mesh...
# Loading ../data/phantom_lung3_125_0/phantom19/phantom19_mesh10.xdmf... 4998
# Interpolating FEM coefficients...
# Solving FEM model...
# Converting displacement field to image...
# torch.Size([256, 256, 94]) torch.Size([256, 256, 94]) torch.Size([256, 256, 94, 3]) torch.Size([256, 256, 94, 3]) (256, 256, 94)
# Saving ../data/phantom_lung3_125_0/phantom19/phantom19_elast.nii.gz
# Saving ../data/phantom_lung3_125_0/phantom19/phantom19_anat.nii.gz
# Saving ../data/phantom_lung3_125_0/phantom19/phantom19_disp.nii.gz
# Saving ../data/phantom_lung3_125_0/phantom19/phantom19_mask.nii.gz
# Setting random seed to 20
# Defining spatial domain...
# 5 27
# Sampling latent variables...
# Generating stiffness map..
# Generating anatomical image...
# Generating displacement BC...
# Generating mesh...
# Loading ../data/phantom_lung3_125_0/phantom20/phantom20_mesh10.xdmf... 5283
# Interpolating FEM coefficients...
# Solving FEM model...
# Converting displacement field to image...
# torch.Size([256, 256, 94]) torch.Size([256, 256, 94]) torch.Size([256, 256, 94, 3]) torch.Size([256, 256, 94, 3]) (256, 256, 94)
# Saving ../data/phantom_lung3_125_0/phantom20/phantom20_elast.nii.gz
# Saving ../data/phantom_lung3_125_0/phantom20/phantom20_anat.nii.gz
# Saving ../data/phantom_lung3_125_0/phantom20/phantom20_disp.nii.gz
# Saving ../data/phantom_lung3_125_0/phantom20/phantom20_mask.nii.gz
# Setting random seed to 21
# Defining spatial domain...
# 5 36
# Sampling latent variables...
# Generating stiffness map..
# Generating anatomical image...
# Generating displacement BC...
# Generating mesh...
# Loading ../data/phantom_lung3_125_0/phantom21/phantom21_mesh10.xdmf... 5281
# Interpolating FEM coefficients...
# Solving FEM model...
# Converting displacement field to image...
# torch.Size([256, 256, 94]) torch.Size([256, 256, 94]) torch.Size([256, 256, 94, 3]) torch.Size([256, 256, 94, 3]) (256, 256, 94)
# Saving ../data/phantom_lung3_125_0/phantom21/phantom21_elast.nii.gz
# Saving ../data/phantom_lung3_125_0/phantom21/phantom21_anat.nii.gz
# Saving ../data/phantom_lung3_125_0/phantom21/phantom21_disp.nii.gz
# Saving ../data/phantom_lung3_125_0/phantom21/phantom21_mask.nii.gz
# Setting random seed to 22
# Defining spatial domain...
# 5 48
# Sampling latent variables...
# Generating stiffness map..
# Generating anatomical image...
# Generating displacement BC...
# Generating mesh...
# Loading ../data/phantom_lung3_125_0/phantom22/phantom22_mesh10.xdmf... 5404
# Interpolating FEM coefficients...
# Solving FEM model...
# Converting displacement field to image...
# torch.Size([256, 256, 94]) torch.Size([256, 256, 94]) torch.Size([256, 256, 94, 3]) torch.Size([256, 256, 94, 3]) (256, 256, 94)
# Saving ../data/phantom_lung3_125_0/phantom22/phantom22_elast.nii.gz
# Saving ../data/phantom_lung3_125_0/phantom22/phantom22_anat.nii.gz
# Saving ../data/phantom_lung3_125_0/phantom22/phantom22_disp.nii.gz
# Saving ../data/phantom_lung3_125_0/phantom22/phantom22_mask.nii.gz
# Setting random seed to 23
# Defining spatial domain...
# 5 41
# Sampling latent variables...
# Generating stiffness map..
# Generating anatomical image...
# Generating displacement BC...
# Generating mesh...
# Loading ../data/phantom_lung3_125_0/phantom23/phantom23_mesh10.xdmf... 5128
# Interpolating FEM coefficients...
# Solving FEM model...
# Converting displacement field to image...
# torch.Size([256, 256, 94]) torch.Size([256, 256, 94]) torch.Size([256, 256, 94, 3]) torch.Size([256, 256, 94, 3]) (256, 256, 94)
# Saving ../data/phantom_lung3_125_0/phantom23/phantom23_elast.nii.gz
# Saving ../data/phantom_lung3_125_0/phantom23/phantom23_anat.nii.gz
# Saving ../data/phantom_lung3_125_0/phantom23/phantom23_disp.nii.gz
# Saving ../data/phantom_lung3_125_0/phantom23/phantom23_mask.nii.gz
# Setting random seed to 24
# Defining spatial domain...
# 5 31
# Sampling latent variables...
# Generating stiffness map..
# Generating anatomical image...
# Generating displacement BC...
# Generating mesh...
# Loading ../data/phantom_lung3_125_0/phantom24/phantom24_mesh10.xdmf... 5217
# Interpolating FEM coefficients...
# Solving FEM model...
# Converting displacement field to image...
# torch.Size([256, 256, 94]) torch.Size([256, 256, 94]) torch.Size([256, 256, 94, 3]) torch.Size([256, 256, 94, 3]) (256, 256, 94)
# Saving ../data/phantom_lung3_125_0/phantom24/phantom24_elast.nii.gz
# Saving ../data/phantom_lung3_125_0/phantom24/phantom24_anat.nii.gz
# Saving ../data/phantom_lung3_125_0/phantom24/phantom24_disp.nii.gz
# Saving ../data/phantom_lung3_125_0/phantom24/phantom24_mask.nii.gz
# Setting random seed to 25
# Defining spatial domain...
# 5 25
# Sampling latent variables...
# Generating stiffness map..
# Generating anatomical image...
# Generating displacement BC...
# Generating mesh...
# Loading ../data/phantom_lung3_125_0/phantom25/phantom25_mesh10.xdmf... 5404
# Interpolating FEM coefficients...
# Solving FEM model...
# Converting displacement field to image...
# torch.Size([256, 256, 94]) torch.Size([256, 256, 94]) torch.Size([256, 256, 94, 3]) torch.Size([256, 256, 94, 3]) (256, 256, 94)
# Saving ../data/phantom_lung3_125_0/phantom25/phantom25_elast.nii.gz
# Saving ../data/phantom_lung3_125_0/phantom25/phantom25_anat.nii.gz
# Saving ../data/phantom_lung3_125_0/phantom25/phantom25_disp.nii.gz
# Saving ../data/phantom_lung3_125_0/phantom25/phantom25_mask.nii.gz
# Setting random seed to 26
# Defining spatial domain...
# 4 50
# Sampling latent variables...
# Generating stiffness map..
# Generating anatomical image...
# Generating displacement BC...
# Generating mesh...
# Loading ../data/phantom_lung3_125_0/phantom26/phantom26_mesh10.xdmf... 5219
# Interpolating FEM coefficients...
# Solving FEM model...
# Converting displacement field to image...
# torch.Size([256, 256, 94]) torch.Size([256, 256, 94]) torch.Size([256, 256, 94, 3]) torch.Size([256, 256, 94, 3]) (256, 256, 94)
# Saving ../data/phantom_lung3_125_0/phantom26/phantom26_elast.nii.gz
# Saving ../data/phantom_lung3_125_0/phantom26/phantom26_anat.nii.gz
# Saving ../data/phantom_lung3_125_0/phantom26/phantom26_disp.nii.gz
# Saving ../data/phantom_lung3_125_0/phantom26/phantom26_mask.nii.gz
# Setting random seed to 27
# Defining spatial domain...
# 5 39
# Sampling latent variables...
# Generating stiffness map..
# Generating anatomical image...
# Generating displacement BC...
# Generating mesh...
# Loading ../data/phantom_lung3_125_0/phantom27/phantom27_mesh10.xdmf... 5137
# Interpolating FEM coefficients...
# Solving FEM model...
# Converting displacement field to image...
# torch.Size([256, 256, 94]) torch.Size([256, 256, 94]) torch.Size([256, 256, 94, 3]) torch.Size([256, 256, 94, 3]) (256, 256, 94)
# Saving ../data/phantom_lung3_125_0/phantom27/phantom27_elast.nii.gz
# Saving ../data/phantom_lung3_125_0/phantom27/phantom27_anat.nii.gz
# Saving ../data/phantom_lung3_125_0/phantom27/phantom27_disp.nii.gz
# Saving ../data/phantom_lung3_125_0/phantom27/phantom27_mask.nii.gz
# Setting random seed to 28
# Defining spatial domain...

# %%
ps = project.phantom.PhantomSet(
    data_root=f'../data/phantom_lung3_250_1',
    phantom_ids=list(range(100))
)

# %%
p = ps.phantoms[0]
p.load_niftis()
p.load_mesh(mesh_version=10)
project.visual.XArrayViewer(p.anat)
project.visual.XArrayViewer(p.elast)

disp = p.disp * (p.mask > 0)
disp.name = 'disp'
project.visual.XArrayViewer(disp)
p.mesh
