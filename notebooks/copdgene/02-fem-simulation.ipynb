# %%
# %load_ext autoreload
# %autoreload 2
# %matplotlib widget

# %%
import sys, os, pathlib
os.environ['PKG_CONFIG_PATH'] = '/ocean/projects/asc170022p/mtragoza/mambaforge/envs/lung-project/lib/pkgconfig'

import numpy as np
import pandas as pd
import nibabel as nib
import torch

sys.path.append('../..')
import project

torch.cuda.is_available()
# Out:
# /ocean/projects/asc170022p/mtragoza/mambaforge/envs/warp/lib/python3.11/site-packages/ufl/__init__.py:250: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
#   import pkg_resources
# True

# %%
# nb configuration
data_root = pathlib.Path('/ocean/projects/asc170022p/mtragoza/lung-project/data/COPDGene')
data_file = data_root / 'sample1000_2025-07-22.csv'
example_idx = 0
source_state = 'INSP'
target_state = 'EXP'

# %%
df = pd.read_csv(data_file, sep='\t', low_memory=False)
dataset = project.copdgene.COPDGeneDataset(df, data_root)
row, visit = dataset[example_idx]
row
# Out:
# sid               16514P
# ccenter              TEM
# kernel               STD
# Emphysema              0
# pctEmph           0.3373
# pctEmph_Slicer    0.3147
# FEV1pp_utah         77.6
# FVCpp_utah          88.9
# FEV1_FVC_utah       0.71
# finalGold           -1.0
# catEmph           normal
# Name: 0, dtype: object

# %%
source_image = visit.load_image(variant='ISO', state=source_state, recon='STD')
target_image = visit.load_image(variant='ISO', state=target_state, recon='STD')
s_mask_image = visit.load_mask(variant='ISO', state=source_state, recon='STD', mask_name='lung_regions')
t_mask_image = visit.load_mask(variant='ISO', state=target_state, recon='STD', mask_name='lung_regions')
disp_image  = visit.load_displacement_field(variant='ISO', target_state=target_state, source_state=source_state, recon='STD')

source_mesh = visit.load_mesh(variant='ISO', state=source_state, recon='STD', mask_name='lung_regions', mesh_tag='volume')
target_mesh = visit.load_mesh(variant='ISO', state=target_state, recon='STD', mask_name='lung_regions', mesh_tag='volume')

# %%
source_array = source_image.get_fdata()
target_array = target_image.get_fdata()
s_mask_array = s_mask_image.get_fdata()
t_mask_array = t_mask_image.get_fdata()
disp_array = disp_image.get_fdata()

# %%
# %autoreload
density_array = project.segmentation.compute_density_map(target_array)

# %%
import pyvista as pv

pv_grid = pv.ImageData(
    dimensions=target_image.shape,
    spacing=np.linalg.norm(target_image.affine[:3,:3], axis=1)
)
pv_grid.point_data['CT'] = target_array.flatten(order='F')
pv_grid.point_data['density'] = density_array.flatten(order='F')
pv_grid
# Out:
# ImageData (0x14d83ee1eb60)
#   N Cells:      36096652
#   N Points:     36429056
#   X Bounds:     0.000e+00, 3.670e+02
#   Y Bounds:     0.000e+00, 3.670e+02
#   Z Bounds:     0.000e+00, 2.680e+02
#   Dimensions:   368, 368, 269
#   Spacing:      1.000e+00, 1.000e+00, 1.000e+00
#   N Arrays:     2

# %%
def get_opacity_values(vmin, vmax, center, width, low=0.0, high=1.0, n=201):
    x = np.linspace(vmin, vmax, n)
    a = low + (high - low) * sigmoid((x - center) / width)
    return a.tolist()

def sigmoid(x):
    return 1.0 / (1.0 + np.exp(-x))

def gaussian(x):
    return np.exp(-x**2)

get_opacity_values(-1000, 1000, 0, 100, n=11)
# Out:
# [4.5397868702434395e-05,
#  0.0003353501304664781,
#  0.0024726231566347743,
#  0.01798620996209156,
#  0.11920292202211755,
#  0.5,
#  0.8807970779778823,
#  0.9820137900379085,
#  0.9975273768433653,
#  0.9996646498695336,
#  0.9999546021312976]

# %%
vmin, vmax = (-1000, 3000)
cmap = 'jet'

center  = (vmin + vmax) / 2
width   = (center - vmin) / 8
opacity = get_opacity_values(vmin, vmax, center, width)

p = pv.Plotter()
p.add_volume(pv_grid, name='vol', scalars='CT', cmap=cmap, clim=(vmin, vmax), opacity=opacity)

def update_opacity(center):
    width = (center - vmin) / 8
    opacity = get_opacity_values(vmin, vmax, center, width)
    p.remove_actor('vol', render=False)
    p.add_volume(pv_grid, name='vol', scalars='CT', cmap=cmap, clim=(vmin, vmax), opacity=opacity)

p.add_slider_widget(update_opacity, rng=(vmin, vmax), value=center)
p.show()
# Out:
# 2025-10-10 10:45:41.686 (  23.710s) [    14D977182200]vtkXOpenGLRenderWindow.:1416  WARN| bad X server connection. DISPLAY=
# Widget(value='<iframe id="pyvista-jupyter_trame__template_P_0x14d7eebf3a10_0" src="https://ondemand.bridges2.p…

# %%
def voxel_to_world_coords(points, affine):
    assert points.ndim == 2 and points.shape[1] == 3
    assert affine.shape == (4, 4) and np.allclose(affine[3], [0,0,0,1])
    points_h = np.c_[points, np.ones(points.shape[0])]
    return (affine @ points_h.T).T[:,:3]

def world_to_voxel_coords(points, affine):
    assert points.ndim == 2 and points.shape[1] == 3
    assert affine.shape == (4, 4) and np.allclose(affine[3], [0,0,0,1])
    points_h = np.c_[points, np.ones(points.shape[0])]
    return np.linalg.solve(affine, points_h.T).T[:,:3]

points_array = world_to_voxel_coords(target_mesh.points, target_image.affine)
points_array
# Out:
# array([[132.67303467, 101.42856598, 109.7533493 ],
#        [129.50520325, 247.43318176, 160.07617188],
#        [132.0176239 , 241.45373535, 174.35232544],
#        ...,
#        [ 75.49620056, 210.52752686, 100.24464417],
#        [ 83.56447601, 213.04563904,  96.55213165],
#        [124.33358002, 221.4677887 , 154.52536011]], shape=(17314, 3))

# %%
def print_tensor_info(*args, **kwargs):
    for i, v in enumerate(args):
        print(f'{i}: {v.shape} {v.dtype} {v.device}')
    for k, v in kwargs.items():
        print(f'{k}: {v.shape} {v.dtype} {v.device}')

device = 'cuda'

image_tensor   = torch.as_tensor(target_array,  dtype=torch.float32, device=device).unsqueeze(-1)
mask_tensor    = torch.as_tensor(t_mask_array,  dtype=torch.int32,   device=device).unsqueeze(-1)
density_tensor = torch.as_tensor(density_array, dtype=torch.float32, device=device).unsqueeze(-1)
disp_tensor    = torch.as_tensor(disp_array,    dtype=torch.float32, device=device)
points_tensor  = torch.as_tensor(points_array,  dtype=torch.float32, device=device)

print_tensor_info(image_tensor, mask_tensor, density_tensor, disp_tensor, points_tensor)
# Out:
# 0: torch.Size([368, 368, 269, 1]) torch.float32 cuda:0
# 1: torch.Size([368, 368, 269, 1]) torch.int32 cuda:0
# 2: torch.Size([368, 368, 269, 1]) torch.float32 cuda:0
# 3: torch.Size([368, 368, 269, 3]) torch.float32 cuda:0
# 4: torch.Size([17314, 3]) torch.float32 cuda:0

# %%
import corrfield
import torch.nn.functional as F

def interpolate_image(image, points, mode='bilinear'):
    '''
    Args:
        image:  (X, Y, Z, C) input image tensor
        points: (N, 3) tensor of voxel indices (ijk)
    Returns:
        (N, C) tensor of interpolated values
    '''
    points_pt = corrfield.utils.kpts_pt(points, image.shape[:3], align_corners=True)
    return F.grid_sample(
        input=image.permute(3, 0, 1, 2).unsqueeze(0),
        grid=points_pt.unsqueeze(0).unsqueeze(0).unsqueeze(0),
        mode=mode,
        padding_mode='border',
        align_corners=True
    ).permute(0, 2, 3, 4, 1).squeeze(0).squeeze(0).squeeze(0)

mm_to_m = 1e-3

ct_values    = interpolate_image(image_tensor, points_tensor, mode='bilinear')
rho_values   = interpolate_image(density_tensor, points_tensor, mode='bilinear')
u_obs_values = interpolate_image(disp_tensor, points_tensor, mode='bilinear') * mm_to_m

mask_values  = interpolate_image(mask_tensor.float(), points_tensor, mode='nearest').int()

print_tensor_info(ct_values, mask_values, rho_values, u_obs_values)
# Out:
# 0: torch.Size([17314, 1]) torch.float32 cuda:0
# 1: torch.Size([17314, 1]) torch.int32 cuda:0
# 2: torch.Size([17314, 1]) torch.float32 cuda:0
# 3: torch.Size([17314, 3]) torch.float32 cuda:0

# %%
def compute_lame_parameters(E, nu):
    '''
    Convert (E, nu) -> (mu, lambda).
    '''
    mu  = E / (2*(1 + nu))
    lam = E * nu / ((1 + nu)*(1 - 2*nu))
    return mu, lam

E_values = torch.ones_like(rho_values) * 3e3 # kPa
E_values.requires_grad = True

mu_values, lam_values = compute_lame_parameters(E_values, nu=0.4)

print_tensor_info(E_values, mu_values, lam_values)
# Out:
# 0: torch.Size([17314, 1]) torch.float32 cuda:0
# 1: torch.Size([17314, 1]) torch.float32 cuda:0
# 2: torch.Size([17314, 1]) torch.float32 cuda:0

# %%
pv_mesh = pv.from_meshio(target_mesh)
pv_mesh.point_data['CT']         = ct_values.detach().cpu().numpy()
pv_mesh.point_data['rho']        = rho_values.detach().cpu().numpy()
pv_mesh.point_data['u_obs']      = u_obs_values.detach().cpu().numpy()
pv_mesh.point_data['u_obs_norm'] = np.linalg.norm(pv_mesh.point_data['u_obs'], axis=1)
pv_mesh
# Out:
# UnstructuredGrid (0x14d77cb0d660)
#   N Cells:    88042
#   N Points:   17314
#   X Bounds:   -1.421e+02, 9.507e+01
#   Y Bounds:   7.690e+01, 2.581e+02
#   Z Bounds:   -2.651e+02, -5.242e+01
#   N Arrays:   5

# %%
p = pv.Plotter()
p.add_mesh(
    pv_mesh.threshold((1, 5), scalars='label'),
    scalars='label',
    cmap='Set1',
    clim=(0, 8),
    opacity=0.5,
)
p.add_mesh(
    pv_mesh.threshold((6, 7), scalars='label'),
    scalars='label',
    cmap='Set1',
    clim=(0, 8),
    opacity=1.0
)
p.enable_depth_peeling(10)
p.show()
# Out:
# Widget(value='<iframe id="pyvista-jupyter_trame__template_P_0x14d77cac7190_1" src="https://ondemand.bridges2.p…

# %%
import matplotlib.colors

cmap = matplotlib.colors.LinearSegmentedColormap.from_list(
    name='density',
    colors=[(1,1,1), (0,0,1), (0,0,0)]
)

p = pv.Plotter()
p.add_volume(
    pv_mesh,
    scalars='rho',
    opacity=[0.0, 1/8, 1/2],
    cmap=cmap,
    clim=(0, 2000)
)
p.show()
# Out:
# Widget(value='<iframe id="pyvista-jupyter_trame__template_P_0x14d77d7d14d0_2" src="https://ondemand.bridges2.p…

# %%
p = pv.Plotter()
arrows = pv_mesh.glyph(scale='u_obs', orient='u_obs', factor=1e3)
p.add_mesh(arrows, scalars='u_obs_norm', cmap='jet', clim=(0, 0.05))
p.show()
# Out:
# Widget(value='<iframe id="pyvista-jupyter_trame__template_P_0x14d77ca95550_3" src="https://ondemand.bridges2.p…

# %% [markdown]
# # NVIDIA warp.fem

# %%
import warp as wp
import warp.fem
import warp.optim.linear
wp.init()

# %%
geometry = wp.fem.Tetmesh(
    wp.array(target_mesh.cells_dict['tetra'], dtype=wp.int32),
    wp.array(target_mesh.points * mm_to_m,    dtype=wp.vec3f)
)

# integration domains
domain = wp.fem.Cells(geometry)
boundary = wp.fem.BoundarySides(geometry)

# function spaces
S = wp.fem.make_polynomial_space(geometry, degree=1, dtype=wp.float32)
V = wp.fem.make_polynomial_space(geometry, degree=1, dtype=wp.vec3f)

# trial and test functions
u_trial = wp.fem.make_trial(V, domain=domain)
v_test  = wp.fem.make_test(V, domain=domain)

ub_trial = wp.fem.make_trial(V, domain=boundary)
vb_test  = wp.fem.make_test(V, domain=boundary)

# %% [markdown]
# Physical model:
# \begin{align}
#     \nabla \cdot \sigma + \rho \mathbf{g} &= 0 \\
#     \sigma &= 2 \mu \epsilon + \lambda \operatorname{tr}(\epsilon) \mathbf{I} \\
#     \epsilon &= \tfrac{1}{2} \left( \nabla \mathbf{u} + \nabla \mathbf{u}^\top \right)
# \end{align}
# Where:
# \begin{align}
#     \sigma: \Omega &\to \mathbb{R}^{3 \times 3} & \rho: \Omega &\to \mathbb{R} & \mathbf{g} &\in \mathbb{R}^3 \\
#     \epsilon: \Omega &\to \mathbb{R}^{3 \times 3} & \mu: \Omega &\to \mathbb{R} & \lambda: \Omega &\to \mathbb{R} \\
#     \mathbf{u}: \Omega &\to \mathbb{R}^3 \\
# \end{align}

# %%
# physical fields and constants
u_obs_field = V.make_field()
u_sim_field = V.make_field()
r_field     = V.make_field()

mu_field  = S.make_field()
lam_field = S.make_field()
rho_field = S.make_field()

g = wp.vec3f([0, 0, -9.81])
I = wp.diag(wp.vec3f(1.0))

# %%
# assign dof values
mu_field.dof_values    = wp.from_torch(mu_values.contiguous(), dtype=wp.float32, requires_grad=True)
lam_field.dof_values   = wp.from_torch(lam_values.contiguous(), dtype=wp.float32, requires_grad=True)

rho_field.dof_values   = wp.from_torch(rho_values.contiguous(), dtype=wp.float32, requires_grad=True)
u_obs_field.dof_values = wp.from_torch(u_obs_values.contiguous(), dtype=wp.vec3f, requires_grad=True)

u_sim_field.dof_values.zero_()
u_sim_field.dof_values.requires_grad = True

r_field.dof_values.zero_()
r_field.dof_values.requires_grad = True
# Out:
# /ocean/projects/asc170022p/mtragoza/mambaforge/envs/warp/lib/python3.11/site-packages/warp/torch.py:262: UserWarning: The .grad attribute of a Tensor that is not a leaf Tensor is being accessed. Its .grad attribute won't be populated during autograd.backward(). If you indeed want the .grad field to be populated for a non-leaf Tensor, use .retain_grad() on the non-leaf Tensor. If you access the non-leaf Tensor by mistake, make sure you access the leaf Tensor instead. See github.com/pytorch/pytorch/pull/30531 for more informations. (Triggered internally at /opt/conda/conda-bld/pytorch_1720538435607/work/build/aten/src/ATen/core/TensorBody.h:489.)
#   if t.grad is not None:

# %% [markdown]
# Weak formulation:
# \begin{align}
#     \nabla \cdot \sigma + \rho \mathbf{g} &= 0 \\
#     -\int_\Omega \left( \nabla \cdot \sigma \right) \cdot \mathbf{v} \ d\mathbf{x} &= \int_\Omega \rho \mathbf{g} \cdot \mathbf{v} \ d\mathbf{x} \\
#     \int_\Omega \sigma(\mathbf{u}) : \nabla \mathbf{v} \ d\mathbf{x} &= \int_\Omega \rho \mathbf{g}\cdot \mathbf{v} \ d\mathbf{x} + \int_{\partial \Omega} \left(\sigma \cdot \mathbf{n} \right) \cdot \mathbf{v} \ d\mathbf{s} \\
#     \int_\Omega \sigma(\mathbf{u}) : \epsilon(\mathbf{v}) \ d\mathbf{x} &= \int_\Omega \rho \mathbf{g}\cdot \mathbf{v} \ d\mathbf{x} + \int_{\partial \Omega} \mathbf{t} \cdot \mathbf{v} \ d\mathbf{s} \\
#     \int_\Omega a(\mathbf{u},\mathbf{v}) \ d\mathbf{x} &= \int_\Omega L(\mathbf{v}) \ d\mathbf{x} \\
#     \ldots \\
#     \mathbf{K} \mathbf{u} &= \mathbf{f}
# \end{align}

# %%
@wp.fem.integrand
def pde_bilinear_form(
    s: wp.fem.Sample,
    u: wp.fem.Field,
    v: wp.fem.Field,
    mu: wp.fem.Field,
    lam: wp.fem.Field
):
    eps_u = wp.fem.D(u, s) # symmetric gradient
    eps_v = wp.fem.D(v, s)
    div_u = wp.fem.div(u, s)
    sigma_u = 2.0*mu(s)*eps_u + lam(s)*div_u*I
    return wp.ddot(sigma_u, eps_v)

@wp.fem.integrand
def pde_linear_form(
    s: wp.fem.Sample,
    v: wp.fem.Field,
    rho: wp.fem.Field,
    g: wp.vec3
):
    return rho(s) * wp.dot(g, v(s))

# %%
# %%time
# assemble linear system
K = wp.fem.integrate(
    pde_bilinear_form,
    fields={'u': u_trial, 'v': v_test, 'mu': mu_field, 'lam': lam_field},
    domain=domain,
    output_dtype=wp.float32
)
f = wp.fem.integrate(
    pde_linear_form,
    fields={'v': v_test, 'rho': rho_field},
    values={'g': g},
    domain=domain,
    output_dtype=wp.vec3f
)
K, f
# Out:
# Module __main__.pde_bilinear_form__itg_f4f8_uTrialFieldTetmesh_T_39b2334d c0290b1 load on device 'cuda:0' took 2.99 ms  (cached)
# Module warp.fem.field.virtual.dyn.dispatch_bilinear_kernel_fn_TrialFieldTetmesh_Tet_P1_Tet_P1__e0684a98 0ef8876 load on device 'cuda:0' took 6.09 ms  (cached)
# Module warp.sparse fec1336 load on device 'cuda:0' took 2.97 ms  (cached)
# Module __main__.pde_linear_form__itg_f4f8_vTestFieldTetmesh_Te_a4f0b61c eee9421 load on device 'cuda:0' took 2.70 ms  (cached)
# Module warp.fem.field.virtual.dyn.dispatch_linear_kernel_fn_TestFieldTetmesh_Tet_P1_Tet_P1_v_3827beed e9d3cb7 load on device 'cuda:0' took 2.70 ms  (cached)
# CPU times: user 97.3 ms, sys: 14.2 ms, total: 112 ms
# Wall time: 198 ms
# (BsrMatrix_float32_3_3(
#  	nrow=17314,
#  	ncol=17314,
#  	nnz=1408672,
#  	offsets=array(shape=(17315,), dtype=int32),
#  	columns=array(shape=(1408672,), dtype=int32),
#  	values=array(shape=(1408672,), dtype=mat33(f)),
#  ),
#  array(shape=(17314,), dtype=vec3f))

# %%
@wp.fem.integrand
def dbc_form(s: wp.fem.Sample, u: wp.fem.Field, v: wp.fem.Field, alpha: float):
    return alpha * wp.dot(u(s), v(s))

# %%
# %%time
# apply boundary conditions
alpha = 1e6

wp.fem.integrate(
    dbc_form,
    fields={'u': ub_trial, 'v': vb_test},
    values={'alpha': alpha},
    domain=boundary,
    output=K,
    add=True
)
wp.fem.integrate(
    dbc_form,
    fields={'u': u_obs_field.trace(), 'v': vb_test},
    values={'alpha': alpha},
    domain=boundary,
    output=f,
    add=True
)
K, f
# Out:
# Module __main__.dbc_form__itg_f4f8_uTrialFieldTetmesh_T_6c12eb67 215eaae load on device 'cuda:0' took 3.10 ms  (cached)
# Module warp.fem.field.virtual.dyn.dispatch_bilinear_kernel_fn_TrialFieldTetmesh_Tet_P1_Tet_P1__6b9704c0 46a0144 load on device 'cuda:0' took 3.04 ms  (cached)
# Module warp.sparse 78297c8 load on device 'cuda:0' took 2.69 ms  (cached)
# Module __main__.dbc_form__itg_f4f8_uNodalFieldTrace_Te_b398abbc 2d3caea load on device 'cuda:0' took 2.73 ms  (cached)
# Module warp.fem.field.virtual.dyn.dispatch_linear_kernel_fn_TestFieldTetmesh_Tet_P1_Tet_P1_v_79ccaa80 0a3d5e7 load on device 'cuda:0' took 2.73 ms  (cached)
# CPU times: user 315 ms, sys: 13.1 ms, total: 328 ms
# Wall time: 334 ms
# (BsrMatrix_float32_3_3(
#  	nrow=17314,
#  	ncol=17314,
#  	nnz=2175136,
#  	offsets=array(shape=(17315,), dtype=int32),
#  	columns=array(shape=(2175136,), dtype=int32),
#  	values=array(shape=(2175136,), dtype=mat33(f)),
#  ),
#  array(shape=(17314,), dtype=vec3f))

# %%
# %%time
# solve linear system
warp.optim.linear.cg(
    A=K,
    b=f,
    x=u_sim_field.dof_values,
    M=warp.optim.linear.preconditioner(K, ptype='diag'),
    tol=1e-4
)
# Out:
# Module warp.optim.linear 5c44d62 load on device 'cuda:0' took 3.30 ms  (cached)
# CPU times: user 5.99 ms, sys: 20.8 ms, total: 26.8 ms
# Wall time: 27.4 ms
# (0, 0.0052820605194991025, 0.005571819810573425)

# %%
@wp.fem.integrand
def error_form(s: wp.fem.Sample, y_pred: wp.fem.Field, y_true: wp.fem.Field):
    error = y_pred(s) - y_true(s)
    return wp.dot(error, error)

@wp.fem.integrand
def norm_form(s: wp.fem.Sample, y_true: wp.fem.Field):
    y_s = y_true(s)
    return wp.dot(y_s, y_s)

@wp.fem.integrand
def volume_form(s: wp.fem.Sample):
    return 1.0

# %%
# %%time
# compute domain error

error = wp.fem.integrate(
    error_form,
    fields={'y_pred': u_sim_field, 'y_true': u_obs_field},
    domain=domain
)
norm = wp.fem.integrate(
    norm_form,
    fields={'y_true': u_obs_field},
    domain=domain
)
vol = wp.fem.integrate(volume_form, domain=domain)

eps = 1e-12

rms_error = wp.sqrt(error / (vol + eps))
rel_error = wp.sqrt(error / (norm + eps))

print(rms_error / mm_to_m, 'mm')
print(rel_error * 100, '%')
# Out:
# Module __main__.error_form__itg_f8f8_y_predNodalField_Tet_5500e500 4d44c8b load on device 'cuda:0' took 2.93 ms  (cached)
# Module __main__.norm_form__itg_f8f8_y_trueNodalField_Tet_a4e1d7eb 02ba242 load on device 'cuda:0' took 3.10 ms  (cached)
# Module __main__.volume_form__itg_f8f8_RegularQuadrature_Te_bccf3f8a e39acea load on device 'cuda:0' took 3.02 ms  (cached)
# 2.2916406668152423 mm
# 12.734242210346828 %
# CPU times: user 25.2 ms, sys: 8.7 ms, total: 33.9 ms
# Wall time: 37.6 ms

# %%
# compute boundary error

error_b = wp.fem.integrate(
    error_form,
    fields={'y_pred': u_sim_field.trace(), 'y_true': u_obs_field.trace()},
    domain=boundary
)
norm_b = wp.fem.integrate(
    norm_form,
    fields={'y_true': u_obs_field.trace()},
    domain=boundary
)
vol_b = wp.fem.integrate(volume_form, domain=boundary)

rms_error_b = wp.sqrt(error_b / (vol_b + eps))
rel_error_b = wp.sqrt(error_b / (norm_b + eps))

print(rms_error_b / mm_to_m, 'mm')
print(rel_error_b * 100, '%')
# Out:
# Module __main__.error_form__itg_f8f8_y_predNodalFieldTra_29f0cf49 abd8076 load on device 'cuda:0' took 3.03 ms  (cached)
# Module __main__.norm_form__itg_f8f8_y_trueNodalFieldTra_2613b841 0a77733 load on device 'cuda:0' took 2.72 ms  (cached)
# Module __main__.volume_form__itg_f8f8_RegularQuadrature_Te_28285060 2422843 load on device 'cuda:0' took 2.78 ms  (cached)
# 1.444328928974238 mm
# 7.6163842055649065 %

# %%
pv_mesh.point_data['u_sim']      = u_sim_field.dof_values.numpy()
pv_mesh.point_data['u_sim_norm'] = np.linalg.norm(pv_mesh.point_data['u_sim'], axis=1)

pv_mesh.point_data['u_err']      = pv_mesh.point_data['u_obs'] - pv_mesh.point_data['u_sim']
pv_mesh.point_data['u_err_norm'] = np.linalg.norm(pv_mesh.point_data['u_err'], axis=1)

pv_mesh
# Out:
# UnstructuredGrid (0x14d77cb0d660)
#   N Cells:    88042
#   N Points:   17314
#   X Bounds:   -1.421e+02, 9.507e+01
#   Y Bounds:   7.690e+01, 2.581e+02
#   Z Bounds:   -2.651e+02, -5.242e+01
#   N Arrays:   9

# %%
p = pv.Plotter()
arrows = pv_mesh.glyph(scale='u_sim', orient='u_sim', factor=1e3)
p.add_mesh(arrows, scalars='u_sim_norm', cmap='jet', clim=(0, 0.05))
p.show()
# Out:
# Widget(value='<iframe id="pyvista-jupyter_trame__template_P_0x14d75f575310_4" src="https://ondemand.bridges2.p…

# %%
p = pv.Plotter()
arrows = pv_mesh.glyph(scale='u_err', orient='u_err', factor=1e3)
p.add_mesh(arrows, scalars='u_err_norm', cmap='jet', clim=(0, 0.05))
p.show()
# Out:
# Widget(value='<iframe id="pyvista-jupyter_trame__template_P_0x14d75e79c310_5" src="https://ondemand.bridges2.p…

# %% [markdown]
# # Inverse problem
#
# PDE constraint:
# $$
# \begin{align}
#     \mathbf{K}(\theta) \mathbf{u} &= \mathbf{f}(\theta) \\
#     \mathbf{r}(\mathbf{u}, \theta) &= \mathbf{f}(\theta) - \mathbf{K}(\theta)\mathbf{u} \\
#     \mathbf{r}(\mathbf{u}, \theta) &= 0
# \end{align}
# $$
#
# Implicit differentiation:
# $$
# \begin{align}
#     \frac{\partial \bf r}{\partial \bf u} \frac{d \bf u}{d \theta} + \frac{\partial \bf r}{\partial \theta} &= 0 \\
#     \frac{d \bf u}{d \theta} &= -\left( \frac{\partial \bf r}{\partial \bf u} \right)^{-1}\frac{\partial \bf r}{\partial \theta}
# \end{align}
# $$
#
# Loss gradient:
# $$
# \begin{align}
#     \frac{\partial L}{\partial \theta} &= \frac{\partial L}{\partial \bf u} \frac{d \bf u}{d \theta} \\
#     \frac{\partial L}{\partial \theta} &= -\frac{\partial L}{\partial \bf u} \left( \frac{\partial \bf r}{\partial \bf u} \right)^{-1}\frac{\partial \bf r}{\partial \theta} \\
#     \frac{\partial L}{\partial \theta} &= \frac{\partial L}{\partial \bf r} \frac{\partial \bf r}{\partial \theta} \\
# \end{align}
# $$
#
# Adjoint method:
# $$
# \begin{align}
#     \frac{\partial L}{\partial \bf r} &= -\frac{\partial L}{\partial \bf u} \left( \frac{\partial \bf r}{\partial \bf u} \right)^{-1} \\
#     \frac{\partial L}{\partial \bf r} \left( \frac{\partial \bf r}{\partial \bf u} \right) &= -\frac{\partial L}{\partial \bf u} \\
#     \left( \frac{\partial \bf r}{\partial \bf u} \right)^\top \frac{\partial L}{\partial \bf r}  &= -\frac{\partial L}{\partial \bf u} \\
#     \mathbf{K}^\top \Psi &= \frac{d L}{d \bf u}
# \end{align}
# $$

# %%
@wp.fem.integrand
def pde_residual_form(
    s: wp.fem.Sample,
    u: wp.fem.Field,
    v: wp.fem.Field,
    mu: wp.fem.Field,
    lam: wp.fem.Field,
    rho: wp.fem.Field,
    g: wp.vec3
):
    lhs = pde_bilinear_form(s, u, v, mu, lam)
    rhs = pde_linear_form(s, v, rho, g)
    return rhs - lhs

@wp.fem.integrand
def dbc_residual_form(
    s: wp.fem.Sample,
    u_sim: wp.fem.Field,
    u_obs: wp.fem.Field,
    v: wp.fem.Field,
    alpha: float
):
    lhs = dbc_form(s, u_sim, v, alpha)
    rhs = dbc_form(s, u_obs, v, alpha)
    return rhs - lhs

# %%
# %%time
tape = wp.Tape()

r_field.dof_values.zero_()
r_field.dof_values.requires_grad = True

with tape:
    wp.fem.integrate(
        pde_residual_form,
        fields={
            'u': u_sim_field,
            'v': v_test,
            'mu': mu_field,
            'lam': lam_field,
            'rho': rho_field
        },
        values={'g': g},
        domain=domain,
        output=r_field.dof_values
    )
    wp.fem.integrate(
        dbc_residual_form,
        fields={
            'u_sim': u_sim_field.trace(),
            'u_obs': u_obs_field.trace(),
            'v': vb_test
        },
        values={'alpha': alpha},
        domain=boundary,
        output=r_field.dof_values,
        add=True
    )

def solve_adjoint_system():
    return wp.optim.linear.cg(
        A=K,
        b=u_sim_field.dof_values.grad,
        x=r_field.dof_values.grad,
        M=warp.optim.linear.preconditioner(K, ptype='diag'),
        tol=1e-4
    )
    
tape.record_func(
    backward=solve_adjoint_system,
    arrays=[r_field.dof_values, u_sim_field.dof_values]
)

numer = wp.empty(1, dtype=wp.float32, requires_grad=True)
denom = wp.empty(1, dtype=wp.float32, requires_grad=True)

with tape:
    wp.fem.integrate(
        error_form,
        fields={'y_pred': u_sim_field, 'y_true': u_obs_field},
        domain=domain,
        output=numer
    )
    wp.fem.integrate(
        norm_form,
        fields={'y_true': u_obs_field},
        domain=domain,
        output=denom
    )
    rmse = (numer / (denom + eps))**0.5

rmse.grad = wp.ones(1, dtype=wp.float32)
tape.backward()

wp.to_torch(mu_field.dof_values.grad).norm()
# Out:
# Module __main__.pde_residual_form__itg_f4f8_uNodalField_Tetmesh__6f525958 45551bf load on device 'cuda:0' took 3.32 ms  (cached)
# Module warp.fem.field.virtual.dyn.dispatch_linear_kernel_fn_TestFieldTetmesh_Tet_P1_Tet_P1_v_62372c9f 6a2088d load on device 'cuda:0' took 3.42 ms  (cached)
# Module __main__.dbc_residual_form__itg_f4f8_u_simNodalFieldTrac_0848140d 004b428 load on device 'cuda:0' took 3.13 ms  (cached)
# Module warp.fem.field.virtual.dyn.dispatch_linear_kernel_fn_TestFieldTetmesh_Tet_P1_Tet_P1_v_ff8cd726 b22b522 load on device 'cuda:0' took 2.90 ms  (cached)
# Module __main__.error_form__itg_f4f8_y_predNodalField_Tet_be3a9c9d e37768c load on device 'cuda:0' took 2.79 ms  (cached)
# Module warp.utils 5e751fc load on device 'cuda:0' took 2.67 ms  (cached)
# Module __main__.norm_form__itg_f4f8_y_trueNodalField_Tet_c8e884cb 20877cc load on device 'cuda:0' took 2.96 ms  (cached)
# Module map_add 11f3678 load on device 'cuda:0' took 2.39 ms  (cached)
# Module map_div 97723a9 load on device 'cuda:0' took 2.53 ms  (cached)
# Module map_pow d8ffd09 load on device 'cuda:0' took 2.63 ms  (cached)
# CPU times: user 116 ms, sys: 43 ms, total: 159 ms
# Wall time: 537 ms
# tensor(9.3631e-07, device='cuda:0')

# %%
tape.zero()

# %%
class WarpFEMCore:

    def __init__(self, geometry, alpha=1e6, tol=1e-4, eps=1e-12):
        self.geometry = geometry
    
        # integration domains
        self.domain = wp.fem.Cells(geometry)
        self.boundary = wp.fem.BoundarySides(geometry)

        # function spaces
        self.S = wp.fem.make_polynomial_space(geometry, degree=1, dtype=wp.float32)
        self.V = wp.fem.make_polynomial_space(geometry, degree=1, dtype=wp.vec3f)

        # trial and test functions
        self.u_trial = wp.fem.make_trial(self.V, domain=self.domain)
        self.v_test  = wp.fem.make_test(self.V, domain=self.domain)

        self.ub_trial = wp.fem.make_trial(self.V, domain=self.boundary)
        self.vb_test  = wp.fem.make_test(self.V, domain=self.boundary)

        # physical fields and constants
        self.u_obs_field = self.V.make_field()
        self.u_sim_field = self.V.make_field()
        self.u_sim_field.dof_values.requires_grad = True

        self.r_field = self.V.make_field()
        self.r_field.dof_values.requires_grad = True

        self.mu_field  = self.S.make_field()
        self.lam_field = self.S.make_field()
        self.rho_field = self.S.make_field()

        self.g = wp.vec3f([0, 0, -9.81])
        self.I = wp.diag(wp.vec3f(1.0))

        # hyperparameters
        self.alpha = alpha
        self.tol = tol
        self.eps = eps

    def assign_fixed_values(self, rho, u_obs):
        self.rho_field.dof_values   = as_warp_array(rho, dtype=wp.float32, requires_grad=True)
        self.u_obs_field.dof_values = as_warp_array(u_obs, dtype=wp.vec3f, requires_grad=True)

    def assign_param_values(self, mu, lam):
        self.mu_field.dof_values  = as_warp_array(mu, dtype=wp.float32, requires_grad=True)
        self.lam_field.dof_values = as_warp_array(lam, dtype=wp.float32, requires_grad=True)

    def assemble_pde_operator(self):
        self.K_pde = wp.fem.integrate(
            pde_bilinear_form,
            fields={
                'u': self.u_trial,
                'v': self.v_test,
                'mu': self.mu_field,
                'lam': self.lam_field
            },
            domain=self.domain,
            output_dtype=wp.float32
        )

    def assemble_pde_rhs(self):
        self.f_pde = wp.fem.integrate(
            pde_linear_form,
            fields={'v': self.v_test, 'rho': self.rho_field},
            values={'g': self.g},
            domain=self.domain,
            output_dtype=wp.vec3f
        )

    def assemble_dbc_operator(self):
        self.K_bc = wp.fem.integrate(
            dbc_form,
            fields={'u': self.ub_trial, 'v': self.vb_test},
            values={'alpha': self.alpha},
            domain=self.boundary,
            output_dtype=wp.float32
        )

    def assemble_dbc_rhs(self):
        self.f_bc = wp.fem.integrate(
            dbc_form,
            fields={'u': self.u_obs_field.trace(), 'v': self.vb_test},
            values={'alpha': self.alpha},
            domain=self.boundary,
            output_dtype=wp.vec3f
        )

    def apply_boundary_condition(self):
        self.K = self.K_pde + self.K_bc
        self.f = self.f_pde + self.f_bc
        self.M = wp.optim.linear.preconditioner(self.K, ptype='diag')

    def solve_forward_system(self):
        return wp.optim.linear.cg(
            A=self.K,
            b=self.f,
            x=self.u_sim_field.dof_values,
            M=self.M,
            tol=self.tol
        )

    def solve_adjoint_system(self):
        return wp.optim.linear.cg(
            A=self.K,
            b=self.u_sim_field.dof_values.grad,
            x=self.r_field.dof_values.grad,
            M=self.M,
            tol=self.tol
        )

    def compute_residual(self):
        wp.fem.integrate(
            pde_residual_form,
            fields={
                'u': self.u_sim_field,
                'v': self.v_test,
                'mu': self.mu_field,
                'lam': self.lam_field,
                'rho': self.rho_field
            },
            values={'g': self.g},
            domain=self.domain,
            output=self.r_field.dof_values
        )
        wp.fem.integrate(
            dbc_residual_form,
            fields={
                'u_sim': self.u_sim_field.trace(),
                'u_obs': self.u_obs_field.trace(),
                'v': self.vb_test
            },
            values={'alpha': self.alpha},
            domain=self.boundary,
            output=self.r_field.dof_values,
            add=True
        )

    def compute_error(self, relative=False):
        numer = wp.empty(1, dtype=wp.float32, requires_grad=True)
        denom = wp.empty(1, dtype=wp.float32, requires_grad=True)

        wp.fem.integrate(
            error_form,
            fields={'y_pred': self.u_sim_field, 'y_true': self.u_obs_field},
            domain=self.domain,
            output=numer
        )
        if relative:
            wp.fem.integrate(
                norm_form,
                fields={'y_true': self.u_obs_field},
                domain=self.domain,
                output=denom
            )
        else:
            wp.fem.integrate(
                volume_form,
                domain=self.domain,
                output=denom
            )

        return numer / (denom + self.eps)

def as_warp_array(t, **kwargs):
    return wp.from_torch(t.contiguous().detach(), **kwargs)

# %%
class WarpFEMModule(torch.nn.Module):

    def __init__(self, geometry, rho, u_obs, **kwargs):
        super().__init__()
        self.core = WarpFEMCore(geometry, **kwargs)
        self.core.assign_fixed_values(rho, u_obs)
        self.core.assemble_dbc_operator()
        self.core.assemble_dbc_rhs()
        self.core.assemble_pde_rhs()

    def forward(self, mu, lam):
        return WarpFEMFn.apply(self.core, mu, lam)


class WarpFEMFn(torch.autograd.Function):

    @staticmethod
    def forward(ctx, core, mu, lam):
        ctx.core = core
        core.assign_param_values(mu, lam)
        core.assemble_pde_operator()
        core.apply_boundary_condition()
        core.solve_forward_system()

        ctx.tape = wp.Tape()
        with ctx.tape:
            core.compute_residual()

        ctx.tape.record_func(
            backward=core.solve_adjoint_system,
            arrays=[
                core.r_field.dof_values,
                core.u_sim_field.dof_values
            ]
        )
        with ctx.tape:
            ctx.error = core.compute_error()

        return wp.to_torch(ctx.error)

    @staticmethod
    def backward(ctx, grad_out):
        ctx.error.grad = wp.from_torch(grad_out.detach())
        ctx.tape.backward()
        mu_grad  = wp.to_torch(ctx.core.mu_field.dof_values.grad)
        lam_grad = wp.to_torch(ctx.core.lam_field.dof_values.grad)
        return (None, mu_grad, lam_grad)


fem = WarpFEMModule(geometry, rho_values, u_obs_values, alpha=1e6, tol=1e-6)
fem
# Out:
# WarpFEMModule()

# %%
rho_values = interpolate_image(density_tensor, points_tensor, mode='bilinear')
u_obs_values = interpolate_image(disp_tensor, points_tensor, mode='bilinear') * mm_to_m

E0 = 3e3
theta = torch.zeros_like(rho_values, requires_grad=True) 
optim = torch.optim.Adam([theta], lr=1e-3)

# %%
# %%time
wp.config.quiet = True

for i in range(1000):
    optim.zero_grad()
    E_values = E0 * torch.exp(theta)
    loss = fem.forward(*compute_lame_parameters(E_values, nu=0.4))**0.5 / mm_to_m
    loss.backward()
    optim.step()
    grad_norm = theta.grad.norm()
    print(f'iteration {i} | loss={loss.item()**0.5:.8f} | grad_norm={grad_norm.item():.8e}')
    assert grad_norm > 0
# Out:
# iteration 0 | loss=0.87536290 | grad_norm=8.15776456e-03
# iteration 1 | loss=0.87523393 | grad_norm=8.15249700e-03
# iteration 2 | loss=0.87510595 | grad_norm=8.14736541e-03
# iteration 3 | loss=0.87497728 | grad_norm=8.14212486e-03
# iteration 4 | loss=0.87484982 | grad_norm=8.13707057e-03
# iteration 5 | loss=0.87472114 | grad_norm=8.13181233e-03
# iteration 6 | loss=0.87459350 | grad_norm=8.12661275e-03
# iteration 7 | loss=0.87446486 | grad_norm=8.12141225e-03
# iteration 8 | loss=0.87433763 | grad_norm=8.11632443e-03
# iteration 9 | loss=0.87420993 | grad_norm=8.11118167e-03
# iteration 10 | loss=0.87408164 | grad_norm=8.10598303e-03
# iteration 11 | loss=0.87395425 | grad_norm=8.10092501e-03
# iteration 12 | loss=0.87382667 | grad_norm=8.09576735e-03
# iteration 13 | loss=0.87369853 | grad_norm=8.09059292e-03
# iteration 14 | loss=0.87357149 | grad_norm=8.08551349e-03
# iteration 15 | loss=0.87344293 | grad_norm=8.08033440e-03
# iteration 16 | loss=0.87331634 | grad_norm=8.07529222e-03
# iteration 17 | loss=0.87318795 | grad_norm=8.07006750e-03
# iteration 18 | loss=0.87306152 | grad_norm=8.06494802e-03
# iteration 19 | loss=0.87293367 | grad_norm=8.05982947e-03
# iteration 20 | loss=0.87280714 | grad_norm=8.05471744e-03
# iteration 21 | loss=0.87267908 | grad_norm=8.04964174e-03
# iteration 22 | loss=0.87255258 | grad_norm=8.04459490e-03
# iteration 23 | loss=0.87242511 | grad_norm=8.03944189e-03
# iteration 24 | loss=0.87229870 | grad_norm=8.03434290e-03
# iteration 25 | loss=0.87217174 | grad_norm=8.02930817e-03
# iteration 26 | loss=0.87204444 | grad_norm=8.02417751e-03
# iteration 27 | loss=0.87191771 | grad_norm=8.01907945e-03
# iteration 28 | loss=0.87179113 | grad_norm=8.01398139e-03
# iteration 29 | loss=0.87166433 | grad_norm=8.00894294e-03
# iteration 30 | loss=0.87153710 | grad_norm=8.00383557e-03
# iteration 31 | loss=0.87141136 | grad_norm=7.99884647e-03
# iteration 32 | loss=0.87128470 | grad_norm=7.99383223e-03
# iteration 33 | loss=0.87115735 | grad_norm=7.98865594e-03
# iteration 34 | loss=0.87103193 | grad_norm=7.98361283e-03
# iteration 35 | loss=0.87090529 | grad_norm=7.97859393e-03
# iteration 36 | loss=0.87077894 | grad_norm=7.97359645e-03
# iteration 37 | loss=0.87065213 | grad_norm=7.96848442e-03
# iteration 38 | loss=0.87052683 | grad_norm=7.96349905e-03
# iteration 39 | loss=0.87040053 | grad_norm=7.95845315e-03
# iteration 40 | loss=0.87027367 | grad_norm=7.95327593e-03
# iteration 41 | loss=0.87014921 | grad_norm=7.94841908e-03
# iteration 42 | loss=0.87002262 | grad_norm=7.94331916e-03
# iteration 43 | loss=0.86989597 | grad_norm=7.93822668e-03
# iteration 44 | loss=0.86977074 | grad_norm=7.93334842e-03
# iteration 45 | loss=0.86964481 | grad_norm=7.92829599e-03
# iteration 46 | loss=0.86951920 | grad_norm=7.92335253e-03
# iteration 47 | loss=0.86939272 | grad_norm=7.91826472e-03
# iteration 48 | loss=0.86926893 | grad_norm=7.91341532e-03
# iteration 49 | loss=0.86914241 | grad_norm=7.90840201e-03
# iteration 50 | loss=0.86901676 | grad_norm=7.90335424e-03
# iteration 51 | loss=0.86889062 | grad_norm=7.89831206e-03
# iteration 52 | loss=0.86876706 | grad_norm=7.89340772e-03
# iteration 53 | loss=0.86863975 | grad_norm=7.88830593e-03
# iteration 54 | loss=0.86851568 | grad_norm=7.88341742e-03
# iteration 55 | loss=0.86839029 | grad_norm=7.87844695e-03
# iteration 56 | loss=0.86826508 | grad_norm=7.87346717e-03
# iteration 57 | loss=0.86813914 | grad_norm=7.86843337e-03
# iteration 58 | loss=0.86801489 | grad_norm=7.86363613e-03
# iteration 59 | loss=0.86788994 | grad_norm=7.85858743e-03
# iteration 60 | loss=0.86776484 | grad_norm=7.85359461e-03
# iteration 61 | loss=0.86764027 | grad_norm=7.84870610e-03
# iteration 62 | loss=0.86751530 | grad_norm=7.84371421e-03
# iteration 63 | loss=0.86739065 | grad_norm=7.83881173e-03
# iteration 64 | loss=0.86726530 | grad_norm=7.83381797e-03
# iteration 65 | loss=0.86714093 | grad_norm=7.82892946e-03
# iteration 66 | loss=0.86701651 | grad_norm=7.82396086e-03
# iteration 67 | loss=0.86689224 | grad_norm=7.81910308e-03
# iteration 68 | loss=0.86676788 | grad_norm=7.81413540e-03
# iteration 69 | loss=0.86664306 | grad_norm=7.80922268e-03
# iteration 70 | loss=0.86651922 | grad_norm=7.80433323e-03
# iteration 71 | loss=0.86639468 | grad_norm=7.79943541e-03
# iteration 72 | loss=0.86626922 | grad_norm=7.79438764e-03
# iteration 73 | loss=0.86614704 | grad_norm=7.78964302e-03
# iteration 74 | loss=0.86602207 | grad_norm=7.78474286e-03
# iteration 75 | loss=0.86589759 | grad_norm=7.77980080e-03
# iteration 76 | loss=0.86577412 | grad_norm=7.77500775e-03
# iteration 77 | loss=0.86565002 | grad_norm=7.77007360e-03
# iteration 78 | loss=0.86552603 | grad_norm=7.76516739e-03
# iteration 79 | loss=0.86540327 | grad_norm=7.76042556e-03
# iteration 80 | loss=0.86527753 | grad_norm=7.75536895e-03
# iteration 81 | loss=0.86515563 | grad_norm=7.75061175e-03
# iteration 82 | loss=0.86503113 | grad_norm=7.74565851e-03
# iteration 83 | loss=0.86490720 | grad_norm=7.74072111e-03
# iteration 84 | loss=0.86478411 | grad_norm=7.73599232e-03
# iteration 85 | loss=0.86465993 | grad_norm=7.73107726e-03
# iteration 86 | loss=0.86453698 | grad_norm=7.72625487e-03
# iteration 87 | loss=0.86441370 | grad_norm=7.72141898e-03
# iteration 88 | loss=0.86429023 | grad_norm=7.71651976e-03
# iteration 89 | loss=0.86416691 | grad_norm=7.71170063e-03
# iteration 90 | loss=0.86404368 | grad_norm=7.70691643e-03
# iteration 91 | loss=0.86392016 | grad_norm=7.70195434e-03
# iteration 92 | loss=0.86379731 | grad_norm=7.69728003e-03
# iteration 93 | loss=0.86367440 | grad_norm=7.69243948e-03
# iteration 94 | loss=0.86355124 | grad_norm=7.68762035e-03
# iteration 95 | loss=0.86342806 | grad_norm=7.68276257e-03
# iteration 96 | loss=0.86330542 | grad_norm=7.67796626e-03
# iteration 97 | loss=0.86318248 | grad_norm=7.67312478e-03
# iteration 98 | loss=0.86305976 | grad_norm=7.66832102e-03
# iteration 99 | loss=0.86293693 | grad_norm=7.66345020e-03
# iteration 100 | loss=0.86281432 | grad_norm=7.65867205e-03
# iteration 101 | loss=0.86269169 | grad_norm=7.65381195e-03
# iteration 102 | loss=0.86256835 | grad_norm=7.64901284e-03
# iteration 103 | loss=0.86244645 | grad_norm=7.64430547e-03
# iteration 104 | loss=0.86232408 | grad_norm=7.63957296e-03
# iteration 105 | loss=0.86220172 | grad_norm=7.63472635e-03
# iteration 106 | loss=0.86207935 | grad_norm=7.62996310e-03
# iteration 107 | loss=0.86195700 | grad_norm=7.62524735e-03
# iteration 108 | loss=0.86183484 | grad_norm=7.62043055e-03
# iteration 109 | loss=0.86171269 | grad_norm=7.61566544e-03
# iteration 110 | loss=0.86159074 | grad_norm=7.61091476e-03
# iteration 111 | loss=0.86146866 | grad_norm=7.60615245e-03
# iteration 112 | loss=0.86134608 | grad_norm=7.60130538e-03
# iteration 113 | loss=0.86122473 | grad_norm=7.59666925e-03
# iteration 114 | loss=0.86110257 | grad_norm=7.59185990e-03
# iteration 115 | loss=0.86098087 | grad_norm=7.58719677e-03
# iteration 116 | loss=0.86085930 | grad_norm=7.58245587e-03
# iteration 117 | loss=0.86073726 | grad_norm=7.57771358e-03
# iteration 118 | loss=0.86061568 | grad_norm=7.57295545e-03
# iteration 119 | loss=0.86049430 | grad_norm=7.56825786e-03
# iteration 120 | loss=0.86037245 | grad_norm=7.56353326e-03
# iteration 121 | loss=0.86025082 | grad_norm=7.55871972e-03
# iteration 122 | loss=0.86012981 | grad_norm=7.55407428e-03
# iteration 123 | loss=0.86000811 | grad_norm=7.54933804e-03
# iteration 124 | loss=0.85988709 | grad_norm=7.54465768e-03
# iteration 125 | loss=0.85976522 | grad_norm=7.53991213e-03
# iteration 126 | loss=0.85964431 | grad_norm=7.53527135e-03
# iteration 127 | loss=0.85952289 | grad_norm=7.53054535e-03
# iteration 128 | loss=0.85940215 | grad_norm=7.52589619e-03
# iteration 129 | loss=0.85928070 | grad_norm=7.52119208e-03
# iteration 130 | loss=0.85915986 | grad_norm=7.51645630e-03
# iteration 131 | loss=0.85903876 | grad_norm=7.51168188e-03
# iteration 132 | loss=0.85891781 | grad_norm=7.50707323e-03
# iteration 133 | loss=0.85879691 | grad_norm=7.50234490e-03
# iteration 134 | loss=0.85867649 | grad_norm=7.49762775e-03
# iteration 135 | loss=0.85855559 | grad_norm=7.49305496e-03
# iteration 136 | loss=0.85843506 | grad_norm=7.48840813e-03
# iteration 137 | loss=0.85831417 | grad_norm=7.48365931e-03
# iteration 138 | loss=0.85819350 | grad_norm=7.47903856e-03
# iteration 139 | loss=0.85807324 | grad_norm=7.47440802e-03
# iteration 140 | loss=0.85795295 | grad_norm=7.46971741e-03
# iteration 141 | loss=0.85783241 | grad_norm=7.46508362e-03
# iteration 142 | loss=0.85771147 | grad_norm=7.46039394e-03
# iteration 143 | loss=0.85759179 | grad_norm=7.45583093e-03
# iteration 144 | loss=0.85747064 | grad_norm=7.45107746e-03
# iteration 145 | loss=0.85735128 | grad_norm=7.44644040e-03
# iteration 146 | loss=0.85723134 | grad_norm=7.44187972e-03
# iteration 147 | loss=0.85711084 | grad_norm=7.43722310e-03
# iteration 148 | loss=0.85699098 | grad_norm=7.43266894e-03
# iteration 149 | loss=0.85687103 | grad_norm=7.42813246e-03
# iteration 150 | loss=0.85675085 | grad_norm=7.42342183e-03
# iteration 151 | loss=0.85663139 | grad_norm=7.41871772e-03
# iteration 152 | loss=0.85651146 | grad_norm=7.41418637e-03
# iteration 153 | loss=0.85639158 | grad_norm=7.40960333e-03
# iteration 154 | loss=0.85627176 | grad_norm=7.40491878e-03
# iteration 155 | loss=0.85615234 | grad_norm=7.40034878e-03
# iteration 156 | loss=0.85603265 | grad_norm=7.39575736e-03
# iteration 157 | loss=0.85591326 | grad_norm=7.39115477e-03
# iteration 158 | loss=0.85579372 | grad_norm=7.38657452e-03
# iteration 159 | loss=0.85567423 | grad_norm=7.38200219e-03
# iteration 160 | loss=0.85555479 | grad_norm=7.37740984e-03
# iteration 161 | loss=0.85543544 | grad_norm=7.37284310e-03
# iteration 162 | loss=0.85531601 | grad_norm=7.36826519e-03
# iteration 163 | loss=0.85519753 | grad_norm=7.36364629e-03
# iteration 164 | loss=0.85507747 | grad_norm=7.35913916e-03
# iteration 165 | loss=0.85495896 | grad_norm=7.35452771e-03
# iteration 166 | loss=0.85483974 | grad_norm=7.34998798e-03
# iteration 167 | loss=0.85472088 | grad_norm=7.34547665e-03
# iteration 168 | loss=0.85460163 | grad_norm=7.34090898e-03
# iteration 169 | loss=0.85448270 | grad_norm=7.33628124e-03
# iteration 170 | loss=0.85436407 | grad_norm=7.33172754e-03
# iteration 171 | loss=0.85424505 | grad_norm=7.32717570e-03
# iteration 172 | loss=0.85412663 | grad_norm=7.32269185e-03
# iteration 173 | loss=0.85400774 | grad_norm=7.31809065e-03
# iteration 174 | loss=0.85388933 | grad_norm=7.31354672e-03
# iteration 175 | loss=0.85377080 | grad_norm=7.30906380e-03
# iteration 176 | loss=0.85365207 | grad_norm=7.30450032e-03
# iteration 177 | loss=0.85353336 | grad_norm=7.29999458e-03
# iteration 178 | loss=0.85341551 | grad_norm=7.29542039e-03
# iteration 179 | loss=0.85329681 | grad_norm=7.29092676e-03
# iteration 180 | loss=0.85317850 | grad_norm=7.28653185e-03
# iteration 181 | loss=0.85305983 | grad_norm=7.28191296e-03
# iteration 182 | loss=0.85294199 | grad_norm=7.27745378e-03
# iteration 183 | loss=0.85282374 | grad_norm=7.27298111e-03
# iteration 184 | loss=0.85270551 | grad_norm=7.26849260e-03
# iteration 185 | loss=0.85258786 | grad_norm=7.26395566e-03
# iteration 186 | loss=0.85246991 | grad_norm=7.25948950e-03
# iteration 187 | loss=0.85235122 | grad_norm=7.25499354e-03
# iteration 188 | loss=0.85223387 | grad_norm=7.25044962e-03
# iteration 189 | loss=0.85211654 | grad_norm=7.24602118e-03
# iteration 190 | loss=0.85199810 | grad_norm=7.24149263e-03
# iteration 191 | loss=0.85188004 | grad_norm=7.23698549e-03
# iteration 192 | loss=0.85176312 | grad_norm=7.23266415e-03
# iteration 193 | loss=0.85164484 | grad_norm=7.22814025e-03
# iteration 194 | loss=0.85152792 | grad_norm=7.22368015e-03
# iteration 195 | loss=0.85140983 | grad_norm=7.21924240e-03
# iteration 196 | loss=0.85129224 | grad_norm=7.21471477e-03
# iteration 197 | loss=0.85117562 | grad_norm=7.21027656e-03
# iteration 198 | loss=0.85105741 | grad_norm=7.20578944e-03
# iteration 199 | loss=0.85094090 | grad_norm=7.20142014e-03
# iteration 200 | loss=0.85082349 | grad_norm=7.19695631e-03
# iteration 201 | loss=0.85070590 | grad_norm=7.19252229e-03
# iteration 202 | loss=0.85058934 | grad_norm=7.18805892e-03
# iteration 203 | loss=0.85047160 | grad_norm=7.18362024e-03
# iteration 204 | loss=0.85035466 | grad_norm=7.17922440e-03
# iteration 205 | loss=0.85023837 | grad_norm=7.17479084e-03
# iteration 206 | loss=0.85012083 | grad_norm=7.17037497e-03
# iteration 207 | loss=0.85000412 | grad_norm=7.16582639e-03
# iteration 208 | loss=0.84988704 | grad_norm=7.16138631e-03
# iteration 209 | loss=0.84977005 | grad_norm=7.15701049e-03
# iteration 210 | loss=0.84965406 | grad_norm=7.15270126e-03
# iteration 211 | loss=0.84953687 | grad_norm=7.14829005e-03
# iteration 212 | loss=0.84942007 | grad_norm=7.14382296e-03
# iteration 213 | loss=0.84930404 | grad_norm=7.13949418e-03
# iteration 214 | loss=0.84918715 | grad_norm=7.13506248e-03
# iteration 215 | loss=0.84907160 | grad_norm=7.13071460e-03
# iteration 216 | loss=0.84895398 | grad_norm=7.12624751e-03
# iteration 217 | loss=0.84883883 | grad_norm=7.12191639e-03
# iteration 218 | loss=0.84872173 | grad_norm=7.11745722e-03
# iteration 219 | loss=0.84860581 | grad_norm=7.11320993e-03
# iteration 220 | loss=0.84849040 | grad_norm=7.10883504e-03
# iteration 221 | loss=0.84837353 | grad_norm=7.10443035e-03
# iteration 222 | loss=0.84825809 | grad_norm=7.10008852e-03
# iteration 223 | loss=0.84814116 | grad_norm=7.09555857e-03
# iteration 224 | loss=0.84802551 | grad_norm=7.09128194e-03
# iteration 225 | loss=0.84790914 | grad_norm=7.08689820e-03
# iteration 226 | loss=0.84779417 | grad_norm=7.08270678e-03
# iteration 227 | loss=0.84767759 | grad_norm=7.07812514e-03
# iteration 228 | loss=0.84756265 | grad_norm=7.07395980e-03
# iteration 229 | loss=0.84744608 | grad_norm=7.06953742e-03
# iteration 230 | loss=0.84733206 | grad_norm=7.06532737e-03
# iteration 231 | loss=0.84721486 | grad_norm=7.06083700e-03
# iteration 232 | loss=0.84710021 | grad_norm=7.05662370e-03
# iteration 233 | loss=0.84698439 | grad_norm=7.05226418e-03
# iteration 234 | loss=0.84686890 | grad_norm=7.04792328e-03
# iteration 235 | loss=0.84675346 | grad_norm=7.04356749e-03
# iteration 236 | loss=0.84663847 | grad_norm=7.03930063e-03
# iteration 237 | loss=0.84652332 | grad_norm=7.03492714e-03
# iteration 238 | loss=0.84640717 | grad_norm=7.03060720e-03
# iteration 239 | loss=0.84629248 | grad_norm=7.02635711e-03
# iteration 240 | loss=0.84617749 | grad_norm=7.02209026e-03
# iteration 241 | loss=0.84606228 | grad_norm=7.01775076e-03
# iteration 242 | loss=0.84594656 | grad_norm=7.01335864e-03
# iteration 243 | loss=0.84583241 | grad_norm=7.00906804e-03
# iteration 244 | loss=0.84571645 | grad_norm=7.00471317e-03
# iteration 245 | loss=0.84560272 | grad_norm=7.00048404e-03
# iteration 246 | loss=0.84548754 | grad_norm=6.99613104e-03
# iteration 247 | loss=0.84537283 | grad_norm=6.99191028e-03
# iteration 248 | loss=0.84525807 | grad_norm=6.98768580e-03
# iteration 249 | loss=0.84514340 | grad_norm=6.98335888e-03
# iteration 250 | loss=0.84502823 | grad_norm=6.97907992e-03
# iteration 251 | loss=0.84491508 | grad_norm=6.97489921e-03
# iteration 252 | loss=0.84479948 | grad_norm=6.97060814e-03
# iteration 253 | loss=0.84468557 | grad_norm=6.96636178e-03
# iteration 254 | loss=0.84457110 | grad_norm=6.96204416e-03
# iteration 255 | loss=0.84445613 | grad_norm=6.95778662e-03
# iteration 256 | loss=0.84434227 | grad_norm=6.95352443e-03
# iteration 257 | loss=0.84422822 | grad_norm=6.94931531e-03
# iteration 258 | loss=0.84411366 | grad_norm=6.94505172e-03
# iteration 259 | loss=0.84399976 | grad_norm=6.94087194e-03
# iteration 260 | loss=0.84388552 | grad_norm=6.93651102e-03
# iteration 261 | loss=0.84377165 | grad_norm=6.93229167e-03
# iteration 262 | loss=0.84365767 | grad_norm=6.92807557e-03
# iteration 263 | loss=0.84354271 | grad_norm=6.92379801e-03
# iteration 264 | loss=0.84343127 | grad_norm=6.91969739e-03
# iteration 265 | loss=0.84331607 | grad_norm=6.91538490e-03
# iteration 266 | loss=0.84320167 | grad_norm=6.91115204e-03
# iteration 267 | loss=0.84308987 | grad_norm=6.90706167e-03
# iteration 268 | loss=0.84297438 | grad_norm=6.90268446e-03
# iteration 269 | loss=0.84286103 | grad_norm=6.89847767e-03
# iteration 270 | loss=0.84274745 | grad_norm=6.89434819e-03
# iteration 271 | loss=0.84263527 | grad_norm=6.89020194e-03
# iteration 272 | loss=0.84251978 | grad_norm=6.88578142e-03
# iteration 273 | loss=0.84240870 | grad_norm=6.88182190e-03
# iteration 274 | loss=0.84229382 | grad_norm=6.87745307e-03
# iteration 275 | loss=0.84218003 | grad_norm=6.87333895e-03
# iteration 276 | loss=0.84206770 | grad_norm=6.86918804e-03
# iteration 277 | loss=0.84195394 | grad_norm=6.86491514e-03
# iteration 278 | loss=0.84184042 | grad_norm=6.86072325e-03
# iteration 279 | loss=0.84172805 | grad_norm=6.85658539e-03
# iteration 280 | loss=0.84161439 | grad_norm=6.85235253e-03
# iteration 281 | loss=0.84150209 | grad_norm=6.84826123e-03
# iteration 282 | loss=0.84138890 | grad_norm=6.84404094e-03
# iteration 283 | loss=0.84127579 | grad_norm=6.83987234e-03
# iteration 284 | loss=0.84116306 | grad_norm=6.83579175e-03
# iteration 285 | loss=0.84105021 | grad_norm=6.83156261e-03
# iteration 286 | loss=0.84093773 | grad_norm=6.82739122e-03
# iteration 287 | loss=0.84082418 | grad_norm=6.82315556e-03
# iteration 288 | loss=0.84071255 | grad_norm=6.81904284e-03
# iteration 289 | loss=0.84059936 | grad_norm=6.81492081e-03
# iteration 290 | loss=0.84048764 | grad_norm=6.81088958e-03
# iteration 291 | loss=0.84037384 | grad_norm=6.80668000e-03
# iteration 292 | loss=0.84026223 | grad_norm=6.80255145e-03
# iteration 293 | loss=0.84014979 | grad_norm=6.79850485e-03
# iteration 294 | loss=0.84003695 | grad_norm=6.79422636e-03
# iteration 295 | loss=0.83992611 | grad_norm=6.79026963e-03
# iteration 296 | loss=0.83981163 | grad_norm=6.78588310e-03
# iteration 297 | loss=0.83970062 | grad_norm=6.78178715e-03
# iteration 298 | loss=0.83958846 | grad_norm=6.77775824e-03
# iteration 299 | loss=0.83947668 | grad_norm=6.77365996e-03
# iteration 300 | loss=0.83936481 | grad_norm=6.76961010e-03
# iteration 301 | loss=0.83925104 | grad_norm=6.76523428e-03
# iteration 302 | loss=0.83914113 | grad_norm=6.76132506e-03
# iteration 303 | loss=0.83902839 | grad_norm=6.75719976e-03
# iteration 304 | loss=0.83891611 | grad_norm=6.75307773e-03
# iteration 305 | loss=0.83880473 | grad_norm=6.74902694e-03
# iteration 306 | loss=0.83869266 | grad_norm=6.74488489e-03
# iteration 307 | loss=0.83858157 | grad_norm=6.74081873e-03
# iteration 308 | loss=0.83846919 | grad_norm=6.73664175e-03
# iteration 309 | loss=0.83835843 | grad_norm=6.73258770e-03
# iteration 310 | loss=0.83824613 | grad_norm=6.72851829e-03
# iteration 311 | loss=0.83813533 | grad_norm=6.72447030e-03
# iteration 312 | loss=0.83802314 | grad_norm=6.72044372e-03
# iteration 313 | loss=0.83791253 | grad_norm=6.71641761e-03
# iteration 314 | loss=0.83780142 | grad_norm=6.71228115e-03
# iteration 315 | loss=0.83768864 | grad_norm=6.70818752e-03
# iteration 316 | loss=0.83757934 | grad_norm=6.70423731e-03
# iteration 317 | loss=0.83746629 | grad_norm=6.69996906e-03
# iteration 318 | loss=0.83735679 | grad_norm=6.69606309e-03
# iteration 319 | loss=0.83724481 | grad_norm=6.69198902e-03
# iteration 320 | loss=0.83713360 | grad_norm=6.68793311e-03
# iteration 321 | loss=0.83702395 | grad_norm=6.68398757e-03
# iteration 322 | loss=0.83691118 | grad_norm=6.67971931e-03
# iteration 323 | loss=0.83680210 | grad_norm=6.67584687e-03
# iteration 324 | loss=0.83668983 | grad_norm=6.67173974e-03
# iteration 325 | loss=0.83657980 | grad_norm=6.66777370e-03
# iteration 326 | loss=0.83646886 | grad_norm=6.66375272e-03
# iteration 327 | loss=0.83635858 | grad_norm=6.65972941e-03
# iteration 328 | loss=0.83624711 | grad_norm=6.65553985e-03
# iteration 329 | loss=0.83613741 | grad_norm=6.65159384e-03
# iteration 330 | loss=0.83602612 | grad_norm=6.64760312e-03
# iteration 331 | loss=0.83591589 | grad_norm=6.64367760e-03
# iteration 332 | loss=0.83580579 | grad_norm=6.63967710e-03
# iteration 333 | loss=0.83569457 | grad_norm=6.63552294e-03
# iteration 334 | loss=0.83558494 | grad_norm=6.63153175e-03
# iteration 335 | loss=0.83547490 | grad_norm=6.62756758e-03
# iteration 336 | loss=0.83536353 | grad_norm=6.62348187e-03
# iteration 337 | loss=0.83525428 | grad_norm=6.61950512e-03
# iteration 338 | loss=0.83514381 | grad_norm=6.61559682e-03
# iteration 339 | loss=0.83503428 | grad_norm=6.61156792e-03
# iteration 340 | loss=0.83492407 | grad_norm=6.60758745e-03
# iteration 341 | loss=0.83481351 | grad_norm=6.60363538e-03
# iteration 342 | loss=0.83470405 | grad_norm=6.59970613e-03
# iteration 343 | loss=0.83459429 | grad_norm=6.59569772e-03
# iteration 344 | loss=0.83448355 | grad_norm=6.59166230e-03
# iteration 345 | loss=0.83437447 | grad_norm=6.58771815e-03
# iteration 346 | loss=0.83426456 | grad_norm=6.58370601e-03
# iteration 347 | loss=0.83415510 | grad_norm=6.57980517e-03
# iteration 348 | loss=0.83404562 | grad_norm=6.57579256e-03
# iteration 349 | loss=0.83393513 | grad_norm=6.57186797e-03
# iteration 350 | loss=0.83382709 | grad_norm=6.56801183e-03
# iteration 351 | loss=0.83371661 | grad_norm=6.56398153e-03
# iteration 352 | loss=0.83360736 | grad_norm=6.56000152e-03
# iteration 353 | loss=0.83349827 | grad_norm=6.55607600e-03
# iteration 354 | loss=0.83338789 | grad_norm=6.55201636e-03
# iteration 355 | loss=0.83327953 | grad_norm=6.54813414e-03
# iteration 356 | loss=0.83317033 | grad_norm=6.54421467e-03
# iteration 357 | loss=0.83306033 | grad_norm=6.54018437e-03
# iteration 358 | loss=0.83295193 | grad_norm=6.53632917e-03
# iteration 359 | loss=0.83284219 | grad_norm=6.53229235e-03
# iteration 360 | loss=0.83273347 | grad_norm=6.52844179e-03
# iteration 361 | loss=0.83262459 | grad_norm=6.52455026e-03
# iteration 362 | loss=0.83251592 | grad_norm=6.52065640e-03
# iteration 363 | loss=0.83240633 | grad_norm=6.51671086e-03
# iteration 364 | loss=0.83229816 | grad_norm=6.51283469e-03
# iteration 365 | loss=0.83218852 | grad_norm=6.50891149e-03
# iteration 366 | loss=0.83208046 | grad_norm=6.50502602e-03
# iteration 367 | loss=0.83197197 | grad_norm=6.50110049e-03
# iteration 368 | loss=0.83186278 | grad_norm=6.49719173e-03
# iteration 369 | loss=0.83175461 | grad_norm=6.49328250e-03
# iteration 370 | loss=0.83164557 | grad_norm=6.48941938e-03
# iteration 371 | loss=0.83153799 | grad_norm=6.48557534e-03
# iteration 372 | loss=0.83142845 | grad_norm=6.48154551e-03
# iteration 373 | loss=0.83131998 | grad_norm=6.47769868e-03
# iteration 374 | loss=0.83121307 | grad_norm=6.47393195e-03
# iteration 375 | loss=0.83110339 | grad_norm=6.47000084e-03
# iteration 376 | loss=0.83099659 | grad_norm=6.46617170e-03
# iteration 377 | loss=0.83088695 | grad_norm=6.46221405e-03
# iteration 378 | loss=0.83077934 | grad_norm=6.45842403e-03
# iteration 379 | loss=0.83067132 | grad_norm=6.45446591e-03
# iteration 380 | loss=0.83056271 | grad_norm=6.45069033e-03
# iteration 381 | loss=0.83045538 | grad_norm=6.44678995e-03
# iteration 382 | loss=0.83034649 | grad_norm=6.44280389e-03
# iteration 383 | loss=0.83023935 | grad_norm=6.43894169e-03
# iteration 384 | loss=0.83013187 | grad_norm=6.43515680e-03
# iteration 385 | loss=0.83002312 | grad_norm=6.43132068e-03
# iteration 386 | loss=0.82991608 | grad_norm=6.42750459e-03
# iteration 387 | loss=0.82980856 | grad_norm=6.42372388e-03
# iteration 388 | loss=0.82970038 | grad_norm=6.41980115e-03
# iteration 389 | loss=0.82959329 | grad_norm=6.41598878e-03
# iteration 390 | loss=0.82948512 | grad_norm=6.41214801e-03
# iteration 391 | loss=0.82937801 | grad_norm=6.40831748e-03
# iteration 392 | loss=0.82927103 | grad_norm=6.40450791e-03
# iteration 393 | loss=0.82916202 | grad_norm=6.40062476e-03
# iteration 394 | loss=0.82905584 | grad_norm=6.39689481e-03
# iteration 395 | loss=0.82894860 | grad_norm=6.39307033e-03
# iteration 396 | loss=0.82884013 | grad_norm=6.38915179e-03
# iteration 397 | loss=0.82873473 | grad_norm=6.38549682e-03
# iteration 398 | loss=0.82862601 | grad_norm=6.38152193e-03
# iteration 399 | loss=0.82851940 | grad_norm=6.37776963e-03
# iteration 400 | loss=0.82841174 | grad_norm=6.37397543e-03
# iteration 401 | loss=0.82830539 | grad_norm=6.37018168e-03
# iteration 402 | loss=0.82819798 | grad_norm=6.36638561e-03
# iteration 403 | loss=0.82809142 | grad_norm=6.36262167e-03
# iteration 404 | loss=0.82798402 | grad_norm=6.35872921e-03
# iteration 405 | loss=0.82787802 | grad_norm=6.35493919e-03
# iteration 406 | loss=0.82777113 | grad_norm=6.35117991e-03
# iteration 407 | loss=0.82766391 | grad_norm=6.34744996e-03
# iteration 408 | loss=0.82755746 | grad_norm=6.34367624e-03
# iteration 409 | loss=0.82745039 | grad_norm=6.33984013e-03
# iteration 410 | loss=0.82734388 | grad_norm=6.33607758e-03
# iteration 411 | loss=0.82723793 | grad_norm=6.33243518e-03
# iteration 412 | loss=0.82713154 | grad_norm=6.32855296e-03
# iteration 413 | loss=0.82702420 | grad_norm=6.32476807e-03
# iteration 414 | loss=0.82691940 | grad_norm=6.32112613e-03
# iteration 415 | loss=0.82681159 | grad_norm=6.31724019e-03
# iteration 416 | loss=0.82670590 | grad_norm=6.31341524e-03
# iteration 417 | loss=0.82659897 | grad_norm=6.30968064e-03
# iteration 418 | loss=0.82649380 | grad_norm=6.30608527e-03
# iteration 419 | loss=0.82638655 | grad_norm=6.30223192e-03
# iteration 420 | loss=0.82628074 | grad_norm=6.29854435e-03
# iteration 421 | loss=0.82617501 | grad_norm=6.29474362e-03
# iteration 422 | loss=0.82606812 | grad_norm=6.29100157e-03
# iteration 423 | loss=0.82596364 | grad_norm=6.28732378e-03
# iteration 424 | loss=0.82585737 | grad_norm=6.28351932e-03
# iteration 425 | loss=0.82575138 | grad_norm=6.27988810e-03
# iteration 426 | loss=0.82564483 | grad_norm=6.27615396e-03
# iteration 427 | loss=0.82554050 | grad_norm=6.27248827e-03
# iteration 428 | loss=0.82543310 | grad_norm=6.26868010e-03
# iteration 429 | loss=0.82532803 | grad_norm=6.26499206e-03
# iteration 430 | loss=0.82522269 | grad_norm=6.26122532e-03
# iteration 431 | loss=0.82511647 | grad_norm=6.25745580e-03
# iteration 432 | loss=0.82501201 | grad_norm=6.25384273e-03
# iteration 433 | loss=0.82490543 | grad_norm=6.24996750e-03
# iteration 434 | loss=0.82480105 | grad_norm=6.24648342e-03
# iteration 435 | loss=0.82469449 | grad_norm=6.24273904e-03
# iteration 436 | loss=0.82459066 | grad_norm=6.23913296e-03
# iteration 437 | loss=0.82448418 | grad_norm=6.23537926e-03
# iteration 438 | loss=0.82437971 | grad_norm=6.23179972e-03
# iteration 439 | loss=0.82427425 | grad_norm=6.22802414e-03
# iteration 440 | loss=0.82416827 | grad_norm=6.22421876e-03
# iteration 441 | loss=0.82406391 | grad_norm=6.22060616e-03
# iteration 442 | loss=0.82395873 | grad_norm=6.21684361e-03
# iteration 443 | loss=0.82385372 | grad_norm=6.21324731e-03
# iteration 444 | loss=0.82374885 | grad_norm=6.20956253e-03
# iteration 445 | loss=0.82364298 | grad_norm=6.20586239e-03
# iteration 446 | loss=0.82354000 | grad_norm=6.20232476e-03
# iteration 447 | loss=0.82343334 | grad_norm=6.19854312e-03
# iteration 448 | loss=0.82332932 | grad_norm=6.19487511e-03
# iteration 449 | loss=0.82322420 | grad_norm=6.19127136e-03
# iteration 450 | loss=0.82312033 | grad_norm=6.18768763e-03
# iteration 451 | loss=0.82301543 | grad_norm=6.18399028e-03
# iteration 452 | loss=0.82291099 | grad_norm=6.18030131e-03
# iteration 453 | loss=0.82280592 | grad_norm=6.17665611e-03
# iteration 454 | loss=0.82270138 | grad_norm=6.17295736e-03
# iteration 455 | loss=0.82259647 | grad_norm=6.16933079e-03
# iteration 456 | loss=0.82249361 | grad_norm=6.16581645e-03
# iteration 457 | loss=0.82238812 | grad_norm=6.16204459e-03
# iteration 458 | loss=0.82228396 | grad_norm=6.15843758e-03
# iteration 459 | loss=0.82217972 | grad_norm=6.15486223e-03
# iteration 460 | loss=0.82207499 | grad_norm=6.15110341e-03
# iteration 461 | loss=0.82197174 | grad_norm=6.14755321e-03
# iteration 462 | loss=0.82186746 | grad_norm=6.14396064e-03
# iteration 463 | loss=0.82176349 | grad_norm=6.14041463e-03
# iteration 464 | loss=0.82165911 | grad_norm=6.13671727e-03
# iteration 465 | loss=0.82155617 | grad_norm=6.13324018e-03
# iteration 466 | loss=0.82145172 | grad_norm=6.12957356e-03
# iteration 467 | loss=0.82134694 | grad_norm=6.12584967e-03
# iteration 468 | loss=0.82124392 | grad_norm=6.12237165e-03
# iteration 469 | loss=0.82113991 | grad_norm=6.11878373e-03
# iteration 470 | loss=0.82103552 | grad_norm=6.11510081e-03
# iteration 471 | loss=0.82093348 | grad_norm=6.11156365e-03
# iteration 472 | loss=0.82082856 | grad_norm=6.10782951e-03
# iteration 473 | loss=0.82072605 | grad_norm=6.10440504e-03
# iteration 474 | loss=0.82062136 | grad_norm=6.10072771e-03
# iteration 475 | loss=0.82051909 | grad_norm=6.09727856e-03
# iteration 476 | loss=0.82041407 | grad_norm=6.09355886e-03
# iteration 477 | loss=0.82031108 | grad_norm=6.09003147e-03
# iteration 478 | loss=0.82020779 | grad_norm=6.08643610e-03
# iteration 479 | loss=0.82010477 | grad_norm=6.08286867e-03
# iteration 480 | loss=0.82000153 | grad_norm=6.07926212e-03
# iteration 481 | loss=0.81989776 | grad_norm=6.07567048e-03
# iteration 482 | loss=0.81979503 | grad_norm=6.07214076e-03
# iteration 483 | loss=0.81969210 | grad_norm=6.06863014e-03
# iteration 484 | loss=0.81958822 | grad_norm=6.06508786e-03
# iteration 485 | loss=0.81948677 | grad_norm=6.06158096e-03
# iteration 486 | loss=0.81938217 | grad_norm=6.05791714e-03
# iteration 487 | loss=0.81928043 | grad_norm=6.05448149e-03
# iteration 488 | loss=0.81917741 | grad_norm=6.05098763e-03
# iteration 489 | loss=0.81907357 | grad_norm=6.04735035e-03
# iteration 490 | loss=0.81897150 | grad_norm=6.04384625e-03
# iteration 491 | loss=0.81886858 | grad_norm=6.04030443e-03
# iteration 492 | loss=0.81876609 | grad_norm=6.03679847e-03
# iteration 493 | loss=0.81866428 | grad_norm=6.03334745e-03
# iteration 494 | loss=0.81855954 | grad_norm=6.02963753e-03
# iteration 495 | loss=0.81845890 | grad_norm=6.02624658e-03
# iteration 496 | loss=0.81835530 | grad_norm=6.02267636e-03
# iteration 497 | loss=0.81825172 | grad_norm=6.01903815e-03
# iteration 498 | loss=0.81815006 | grad_norm=6.01555081e-03
# iteration 499 | loss=0.81804893 | grad_norm=6.01209747e-03
# iteration 500 | loss=0.81794586 | grad_norm=6.00861385e-03
# iteration 501 | loss=0.81784300 | grad_norm=6.00510184e-03
# iteration 502 | loss=0.81774143 | grad_norm=6.00158377e-03
# iteration 503 | loss=0.81763909 | grad_norm=5.99807687e-03
# iteration 504 | loss=0.81753717 | grad_norm=5.99462632e-03
# iteration 505 | loss=0.81743433 | grad_norm=5.99106029e-03
# iteration 506 | loss=0.81733253 | grad_norm=5.98754734e-03
# iteration 507 | loss=0.81723014 | grad_norm=5.98400179e-03
# iteration 508 | loss=0.81712879 | grad_norm=5.98062761e-03
# iteration 509 | loss=0.81702695 | grad_norm=5.97715564e-03
# iteration 510 | loss=0.81692467 | grad_norm=5.97365201e-03
# iteration 511 | loss=0.81682339 | grad_norm=5.97020704e-03
# iteration 512 | loss=0.81672097 | grad_norm=5.96665591e-03
# iteration 513 | loss=0.81661963 | grad_norm=5.96324354e-03
# iteration 514 | loss=0.81651791 | grad_norm=5.95981302e-03
# iteration 515 | loss=0.81641556 | grad_norm=5.95621578e-03
# iteration 516 | loss=0.81631451 | grad_norm=5.95284346e-03
# iteration 517 | loss=0.81621290 | grad_norm=5.94940037e-03
# iteration 518 | loss=0.81611084 | grad_norm=5.94581524e-03
# iteration 519 | loss=0.81600994 | grad_norm=5.94245410e-03
# iteration 520 | loss=0.81590840 | grad_norm=5.93902823e-03
# iteration 521 | loss=0.81580696 | grad_norm=5.93556184e-03
# iteration 522 | loss=0.81570591 | grad_norm=5.93217276e-03
# iteration 523 | loss=0.81560371 | grad_norm=5.92860766e-03
# iteration 524 | loss=0.81550446 | grad_norm=5.92524838e-03
# iteration 525 | loss=0.81540198 | grad_norm=5.92178293e-03
# iteration 526 | loss=0.81530096 | grad_norm=5.91834169e-03
# iteration 527 | loss=0.81519885 | grad_norm=5.91482781e-03
# iteration 528 | loss=0.81509850 | grad_norm=5.91147551e-03
# iteration 529 | loss=0.81499790 | grad_norm=5.90806222e-03
# iteration 530 | loss=0.81489628 | grad_norm=5.90460282e-03
# iteration 531 | loss=0.81479683 | grad_norm=5.90134179e-03
# iteration 532 | loss=0.81469467 | grad_norm=5.89774875e-03
# iteration 533 | loss=0.81459432 | grad_norm=5.89440577e-03
# iteration 534 | loss=0.81449352 | grad_norm=5.89102088e-03
# iteration 535 | loss=0.81439198 | grad_norm=5.88752376e-03
# iteration 536 | loss=0.81429170 | grad_norm=5.88421104e-03
# iteration 537 | loss=0.81419094 | grad_norm=5.88073907e-03
# iteration 538 | loss=0.81409042 | grad_norm=5.87738259e-03
# iteration 539 | loss=0.81398930 | grad_norm=5.87386359e-03
# iteration 540 | loss=0.81388927 | grad_norm=5.87057695e-03
# iteration 541 | loss=0.81378824 | grad_norm=5.86710870e-03
# iteration 542 | loss=0.81368950 | grad_norm=5.86390588e-03
# iteration 543 | loss=0.81358818 | grad_norm=5.86048514e-03
# iteration 544 | loss=0.81348799 | grad_norm=5.85706299e-03
# iteration 545 | loss=0.81338709 | grad_norm=5.85366366e-03
# iteration 546 | loss=0.81328666 | grad_norm=5.85027458e-03
# iteration 547 | loss=0.81318683 | grad_norm=5.84694417e-03
# iteration 548 | loss=0.81308681 | grad_norm=5.84351923e-03
# iteration 549 | loss=0.81298667 | grad_norm=5.84012037e-03
# iteration 550 | loss=0.81288582 | grad_norm=5.83673548e-03
# iteration 551 | loss=0.81278660 | grad_norm=5.83345443e-03
# iteration 552 | loss=0.81268609 | grad_norm=5.83001273e-03
# iteration 553 | loss=0.81258630 | grad_norm=5.82664553e-03
# iteration 554 | loss=0.81248676 | grad_norm=5.82330581e-03
# iteration 555 | loss=0.81238717 | grad_norm=5.81999775e-03
# iteration 556 | loss=0.81228705 | grad_norm=5.81661193e-03
# iteration 557 | loss=0.81218768 | grad_norm=5.81327686e-03
# iteration 558 | loss=0.81208710 | grad_norm=5.80991711e-03
# iteration 559 | loss=0.81198786 | grad_norm=5.80663700e-03
# iteration 560 | loss=0.81188850 | grad_norm=5.80333034e-03
# iteration 561 | loss=0.81178799 | grad_norm=5.79995895e-03
# iteration 562 | loss=0.81168824 | grad_norm=5.79661690e-03
# iteration 563 | loss=0.81159035 | grad_norm=5.79337543e-03
# iteration 564 | loss=0.81148976 | grad_norm=5.79000684e-03
# iteration 565 | loss=0.81139096 | grad_norm=5.78666013e-03
# iteration 566 | loss=0.81129109 | grad_norm=5.78324823e-03
# iteration 567 | loss=0.81119223 | grad_norm=5.78010269e-03
# iteration 568 | loss=0.81109226 | grad_norm=5.77672012e-03
# iteration 569 | loss=0.81099367 | grad_norm=5.77342743e-03
# iteration 570 | loss=0.81089452 | grad_norm=5.77012543e-03
# iteration 571 | loss=0.81079535 | grad_norm=5.76678291e-03
# iteration 572 | loss=0.81069614 | grad_norm=5.76348277e-03
# iteration 573 | loss=0.81059721 | grad_norm=5.76021336e-03
# iteration 574 | loss=0.81049812 | grad_norm=5.75689273e-03
# iteration 575 | loss=0.81039894 | grad_norm=5.75364940e-03
# iteration 576 | loss=0.81030009 | grad_norm=5.75021282e-03
# iteration 577 | loss=0.81020111 | grad_norm=5.74695691e-03
# iteration 578 | loss=0.81010241 | grad_norm=5.74366003e-03
# iteration 579 | loss=0.81000377 | grad_norm=5.74049028e-03
# iteration 580 | loss=0.80990428 | grad_norm=5.73708816e-03
# iteration 581 | loss=0.80980610 | grad_norm=5.73385414e-03
# iteration 582 | loss=0.80970735 | grad_norm=5.73051674e-03
# iteration 583 | loss=0.80960904 | grad_norm=5.72733721e-03
# iteration 584 | loss=0.80950990 | grad_norm=5.72400074e-03
# iteration 585 | loss=0.80941167 | grad_norm=5.72070153e-03
# iteration 586 | loss=0.80931325 | grad_norm=5.71749453e-03
# iteration 587 | loss=0.80921448 | grad_norm=5.71426004e-03
# iteration 588 | loss=0.80911629 | grad_norm=5.71091566e-03
# iteration 589 | loss=0.80901819 | grad_norm=5.70772914e-03
# iteration 590 | loss=0.80891976 | grad_norm=5.70445694e-03
# iteration 591 | loss=0.80882105 | grad_norm=5.70110930e-03
# iteration 592 | loss=0.80872274 | grad_norm=5.69793023e-03
# iteration 593 | loss=0.80862489 | grad_norm=5.69465244e-03
# iteration 594 | loss=0.80852700 | grad_norm=5.69139235e-03
# iteration 595 | loss=0.80842895 | grad_norm=5.68818999e-03
# iteration 596 | loss=0.80833059 | grad_norm=5.68496902e-03
# iteration 597 | loss=0.80823284 | grad_norm=5.68182208e-03
# iteration 598 | loss=0.80813468 | grad_norm=5.67862717e-03
# iteration 599 | loss=0.80803587 | grad_norm=5.67534287e-03
# iteration 600 | loss=0.80793894 | grad_norm=5.67210512e-03
# iteration 601 | loss=0.80784093 | grad_norm=5.66883711e-03
# iteration 602 | loss=0.80774261 | grad_norm=5.66560589e-03
# iteration 603 | loss=0.80764534 | grad_norm=5.66245709e-03
# iteration 604 | loss=0.80754755 | grad_norm=5.65916253e-03
# iteration 605 | loss=0.80745015 | grad_norm=5.65605331e-03
# iteration 606 | loss=0.80735252 | grad_norm=5.65279881e-03
# iteration 607 | loss=0.80725488 | grad_norm=5.64953638e-03
# iteration 608 | loss=0.80715737 | grad_norm=5.64638386e-03
# iteration 609 | loss=0.80705949 | grad_norm=5.64315123e-03
# iteration 610 | loss=0.80696210 | grad_norm=5.63997496e-03
# iteration 611 | loss=0.80686493 | grad_norm=5.63674746e-03
# iteration 612 | loss=0.80676749 | grad_norm=5.63353579e-03
# iteration 613 | loss=0.80666992 | grad_norm=5.63028362e-03
# iteration 614 | loss=0.80657264 | grad_norm=5.62710175e-03
# iteration 615 | loss=0.80647538 | grad_norm=5.62398368e-03
# iteration 616 | loss=0.80637801 | grad_norm=5.62087120e-03
# iteration 617 | loss=0.80628128 | grad_norm=5.61763300e-03
# iteration 618 | loss=0.80618292 | grad_norm=5.61447581e-03
# iteration 619 | loss=0.80608824 | grad_norm=5.61139220e-03
# iteration 620 | loss=0.80598948 | grad_norm=5.60805202e-03
# iteration 621 | loss=0.80589286 | grad_norm=5.60505269e-03
# iteration 622 | loss=0.80579641 | grad_norm=5.60193136e-03
# iteration 623 | loss=0.80569872 | grad_norm=5.59872389e-03
# iteration 624 | loss=0.80560217 | grad_norm=5.59559418e-03
# iteration 625 | loss=0.80550528 | grad_norm=5.59228519e-03
# iteration 626 | loss=0.80540971 | grad_norm=5.58925280e-03
# iteration 627 | loss=0.80531124 | grad_norm=5.58591541e-03
# iteration 628 | loss=0.80521435 | grad_norm=5.58281271e-03
# iteration 629 | loss=0.80511815 | grad_norm=5.57968020e-03
# iteration 630 | loss=0.80502216 | grad_norm=5.57647925e-03
# iteration 631 | loss=0.80492427 | grad_norm=5.57324290e-03
# iteration 632 | loss=0.80482971 | grad_norm=5.57033392e-03
# iteration 633 | loss=0.80473165 | grad_norm=5.56701794e-03
# iteration 634 | loss=0.80463561 | grad_norm=5.56396088e-03
# iteration 635 | loss=0.80453938 | grad_norm=5.56080928e-03
# iteration 636 | loss=0.80444303 | grad_norm=5.55774244e-03
# iteration 637 | loss=0.80434722 | grad_norm=5.55461040e-03
# iteration 638 | loss=0.80425021 | grad_norm=5.55146206e-03
# iteration 639 | loss=0.80415397 | grad_norm=5.54837473e-03
# iteration 640 | loss=0.80405753 | grad_norm=5.54515375e-03
# iteration 641 | loss=0.80396145 | grad_norm=5.54211764e-03
# iteration 642 | loss=0.80386518 | grad_norm=5.53899119e-03
# iteration 643 | loss=0.80376904 | grad_norm=5.53584239e-03
# iteration 644 | loss=0.80367308 | grad_norm=5.53271919e-03
# iteration 645 | loss=0.80357718 | grad_norm=5.52961044e-03
# iteration 646 | loss=0.80348238 | grad_norm=5.52665396e-03
# iteration 647 | loss=0.80338560 | grad_norm=5.52344276e-03
# iteration 648 | loss=0.80328992 | grad_norm=5.52040059e-03
# iteration 649 | loss=0.80319360 | grad_norm=5.51726064e-03
# iteration 650 | loss=0.80309850 | grad_norm=5.51422266e-03
# iteration 651 | loss=0.80300134 | grad_norm=5.51111344e-03
# iteration 652 | loss=0.80290677 | grad_norm=5.50799351e-03
# iteration 653 | loss=0.80281067 | grad_norm=5.50499745e-03
# iteration 654 | loss=0.80271477 | grad_norm=5.50182816e-03
# iteration 655 | loss=0.80262080 | grad_norm=5.49883675e-03
# iteration 656 | loss=0.80252421 | grad_norm=5.49564697e-03
# iteration 657 | loss=0.80242806 | grad_norm=5.49258245e-03
# iteration 658 | loss=0.80233313 | grad_norm=5.48950071e-03
# iteration 659 | loss=0.80223822 | grad_norm=5.48649672e-03
# iteration 660 | loss=0.80214244 | grad_norm=5.48338098e-03
# iteration 661 | loss=0.80204703 | grad_norm=5.48038771e-03
# iteration 662 | loss=0.80195190 | grad_norm=5.47731668e-03
# iteration 663 | loss=0.80185650 | grad_norm=5.47421305e-03
# iteration 664 | loss=0.80176164 | grad_norm=5.47122071e-03
# iteration 665 | loss=0.80166547 | grad_norm=5.46799833e-03
# iteration 666 | loss=0.80157193 | grad_norm=5.46507305e-03
# iteration 667 | loss=0.80147582 | grad_norm=5.46197454e-03
# iteration 668 | loss=0.80138103 | grad_norm=5.45892539e-03
# iteration 669 | loss=0.80128549 | grad_norm=5.45585761e-03
# iteration 670 | loss=0.80119101 | grad_norm=5.45290345e-03
# iteration 671 | loss=0.80109597 | grad_norm=5.44991856e-03
# iteration 672 | loss=0.80100199 | grad_norm=5.44685684e-03
# iteration 673 | loss=0.80090558 | grad_norm=5.44377230e-03
# iteration 674 | loss=0.80081136 | grad_norm=5.44074737e-03
# iteration 675 | loss=0.80071642 | grad_norm=5.43767819e-03
# iteration 676 | loss=0.80062217 | grad_norm=5.43470867e-03
# iteration 677 | loss=0.80052702 | grad_norm=5.43161621e-03
# iteration 678 | loss=0.80043219 | grad_norm=5.42861549e-03
# iteration 679 | loss=0.80033732 | grad_norm=5.42568322e-03
# iteration 680 | loss=0.80024273 | grad_norm=5.42259961e-03
# iteration 681 | loss=0.80014869 | grad_norm=5.41964872e-03
# iteration 682 | loss=0.80005486 | grad_norm=5.41661074e-03
# iteration 683 | loss=0.79995931 | grad_norm=5.41359140e-03
# iteration 684 | loss=0.79986520 | grad_norm=5.41058695e-03
# iteration 685 | loss=0.79977082 | grad_norm=5.40751172e-03
# iteration 686 | loss=0.79967702 | grad_norm=5.40465349e-03
# iteration 687 | loss=0.79958280 | grad_norm=5.40167419e-03
# iteration 688 | loss=0.79948782 | grad_norm=5.39856730e-03
# iteration 689 | loss=0.79939332 | grad_norm=5.39559871e-03
# iteration 690 | loss=0.79929981 | grad_norm=5.39264176e-03
# iteration 691 | loss=0.79920536 | grad_norm=5.38967270e-03
# iteration 692 | loss=0.79911079 | grad_norm=5.38672088e-03
# iteration 693 | loss=0.79901762 | grad_norm=5.38369874e-03
# iteration 694 | loss=0.79892325 | grad_norm=5.38068870e-03
# iteration 695 | loss=0.79882876 | grad_norm=5.37763955e-03
# iteration 696 | loss=0.79873511 | grad_norm=5.37470449e-03
# iteration 697 | loss=0.79864112 | grad_norm=5.37170004e-03
# iteration 698 | loss=0.79854816 | grad_norm=5.36877709e-03
# iteration 699 | loss=0.79845295 | grad_norm=5.36573632e-03
# iteration 700 | loss=0.79836079 | grad_norm=5.36290230e-03
# iteration 701 | loss=0.79826559 | grad_norm=5.35986479e-03
# iteration 702 | loss=0.79817322 | grad_norm=5.35691436e-03
# iteration 703 | loss=0.79807875 | grad_norm=5.35404449e-03
# iteration 704 | loss=0.79798494 | grad_norm=5.35094878e-03
# iteration 705 | loss=0.79789157 | grad_norm=5.34804212e-03
# iteration 706 | loss=0.79779785 | grad_norm=5.34511171e-03
# iteration 707 | loss=0.79770449 | grad_norm=5.34217851e-03
# iteration 708 | loss=0.79761097 | grad_norm=5.33926720e-03
# iteration 709 | loss=0.79751722 | grad_norm=5.33632655e-03
# iteration 710 | loss=0.79742480 | grad_norm=5.33340406e-03
# iteration 711 | loss=0.79733106 | grad_norm=5.33046480e-03
# iteration 712 | loss=0.79723709 | grad_norm=5.32745710e-03
# iteration 713 | loss=0.79714561 | grad_norm=5.32459468e-03
# iteration 714 | loss=0.79705087 | grad_norm=5.32160234e-03
# iteration 715 | loss=0.79695828 | grad_norm=5.31872967e-03
# iteration 716 | loss=0.79686472 | grad_norm=5.31571452e-03
# iteration 717 | loss=0.79677144 | grad_norm=5.31285722e-03
# iteration 718 | loss=0.79667844 | grad_norm=5.30986302e-03
# iteration 719 | loss=0.79658664 | grad_norm=5.30703040e-03
# iteration 720 | loss=0.79649183 | grad_norm=5.30400639e-03
# iteration 721 | loss=0.79639985 | grad_norm=5.30120684e-03
# iteration 722 | loss=0.79630689 | grad_norm=5.29830996e-03
# iteration 723 | loss=0.79621359 | grad_norm=5.29538142e-03
# iteration 724 | loss=0.79612012 | grad_norm=5.29236440e-03
# iteration 725 | loss=0.79602802 | grad_norm=5.28961793e-03
# iteration 726 | loss=0.79593468 | grad_norm=5.28664840e-03
# iteration 727 | loss=0.79584365 | grad_norm=5.28380927e-03
# iteration 728 | loss=0.79574995 | grad_norm=5.28086955e-03
# iteration 729 | loss=0.79565789 | grad_norm=5.27794845e-03
# iteration 730 | loss=0.79556466 | grad_norm=5.27510466e-03
# iteration 731 | loss=0.79547258 | grad_norm=5.27217379e-03
# iteration 732 | loss=0.79537939 | grad_norm=5.26932767e-03
# iteration 733 | loss=0.79528654 | grad_norm=5.26640983e-03
# iteration 734 | loss=0.79519581 | grad_norm=5.26371971e-03
# iteration 735 | loss=0.79510177 | grad_norm=5.26062725e-03
# iteration 736 | loss=0.79501132 | grad_norm=5.25786309e-03
# iteration 737 | loss=0.79491715 | grad_norm=5.25485910e-03
# iteration 738 | loss=0.79482634 | grad_norm=5.25209168e-03
# iteration 739 | loss=0.79473256 | grad_norm=5.24905277e-03
# iteration 740 | loss=0.79464068 | grad_norm=5.24636917e-03
# iteration 741 | loss=0.79454767 | grad_norm=5.24339033e-03
# iteration 742 | loss=0.79445711 | grad_norm=5.24068112e-03
# iteration 743 | loss=0.79436378 | grad_norm=5.23761893e-03
# iteration 744 | loss=0.79427321 | grad_norm=5.23485290e-03
# iteration 745 | loss=0.79417902 | grad_norm=5.23187919e-03
# iteration 746 | loss=0.79408907 | grad_norm=5.22922352e-03
# iteration 747 | loss=0.79399587 | grad_norm=5.22620091e-03
# iteration 748 | loss=0.79390515 | grad_norm=5.22350799e-03
# iteration 749 | loss=0.79381295 | grad_norm=5.22059714e-03
# iteration 750 | loss=0.79371980 | grad_norm=5.21771889e-03
# iteration 751 | loss=0.79362926 | grad_norm=5.21493936e-03
# iteration 752 | loss=0.79353714 | grad_norm=5.21218311e-03
# iteration 753 | loss=0.79344482 | grad_norm=5.20922057e-03
# iteration 754 | loss=0.79335430 | grad_norm=5.20638376e-03
# iteration 755 | loss=0.79326177 | grad_norm=5.20352693e-03
# iteration 756 | loss=0.79317100 | grad_norm=5.20081026e-03
# iteration 757 | loss=0.79307815 | grad_norm=5.19781001e-03
# iteration 758 | loss=0.79298822 | grad_norm=5.19508682e-03
# iteration 759 | loss=0.79289441 | grad_norm=5.19210519e-03
# iteration 760 | loss=0.79280461 | grad_norm=5.18938433e-03
# iteration 761 | loss=0.79271168 | grad_norm=5.18646277e-03
# iteration 762 | loss=0.79262137 | grad_norm=5.18373726e-03
# iteration 763 | loss=0.79252845 | grad_norm=5.18082455e-03
# iteration 764 | loss=0.79243835 | grad_norm=5.17814560e-03
# iteration 765 | loss=0.79234643 | grad_norm=5.17528178e-03
# iteration 766 | loss=0.79225739 | grad_norm=5.17260935e-03
# iteration 767 | loss=0.79216459 | grad_norm=5.16969012e-03
# iteration 768 | loss=0.79207365 | grad_norm=5.16693294e-03
# iteration 769 | loss=0.79198116 | grad_norm=5.16406586e-03
# iteration 770 | loss=0.79189137 | grad_norm=5.16133057e-03
# iteration 771 | loss=0.79179973 | grad_norm=5.15848445e-03
# iteration 772 | loss=0.79170912 | grad_norm=5.15571376e-03
# iteration 773 | loss=0.79161727 | grad_norm=5.15292678e-03
# iteration 774 | loss=0.79152672 | grad_norm=5.15019614e-03
# iteration 775 | loss=0.79143696 | grad_norm=5.14744362e-03
# iteration 776 | loss=0.79134484 | grad_norm=5.14455000e-03
# iteration 777 | loss=0.79125494 | grad_norm=5.14191343e-03
# iteration 778 | loss=0.79116326 | grad_norm=5.13906730e-03
# iteration 779 | loss=0.79107308 | grad_norm=5.13629988e-03
# iteration 780 | loss=0.79098141 | grad_norm=5.13338670e-03
# iteration 781 | loss=0.79089189 | grad_norm=5.13068959e-03
# iteration 782 | loss=0.79080096 | grad_norm=5.12787607e-03
# iteration 783 | loss=0.79071028 | grad_norm=5.12516452e-03
# iteration 784 | loss=0.79061850 | grad_norm=5.12222853e-03
# iteration 785 | loss=0.79052968 | grad_norm=5.11963479e-03
# iteration 786 | loss=0.79043810 | grad_norm=5.11679100e-03
# iteration 787 | loss=0.79034806 | grad_norm=5.11406502e-03
# iteration 788 | loss=0.79025707 | grad_norm=5.11126546e-03
# iteration 789 | loss=0.79016810 | grad_norm=5.10863541e-03
# iteration 790 | loss=0.79007588 | grad_norm=5.10570081e-03
# iteration 791 | loss=0.78998738 | grad_norm=5.10308146e-03
# iteration 792 | loss=0.78989668 | grad_norm=5.10024931e-03
# iteration 793 | loss=0.78980598 | grad_norm=5.09748608e-03
# iteration 794 | loss=0.78971488 | grad_norm=5.09470841e-03
# iteration 795 | loss=0.78962517 | grad_norm=5.09202341e-03
# iteration 796 | loss=0.78953546 | grad_norm=5.08933607e-03
# iteration 797 | loss=0.78944595 | grad_norm=5.08665154e-03
# iteration 798 | loss=0.78935486 | grad_norm=5.08380821e-03
# iteration 799 | loss=0.78926628 | grad_norm=5.08120144e-03
# iteration 800 | loss=0.78917493 | grad_norm=5.07834135e-03
# iteration 801 | loss=0.78908490 | grad_norm=5.07557718e-03
# iteration 802 | loss=0.78899565 | grad_norm=5.07293036e-03
# iteration 803 | loss=0.78890427 | grad_norm=5.07008517e-03
# iteration 804 | loss=0.78881556 | grad_norm=5.06745325e-03
# iteration 805 | loss=0.78872466 | grad_norm=5.06462250e-03
# iteration 806 | loss=0.78863646 | grad_norm=5.06203296e-03
# iteration 807 | loss=0.78854546 | grad_norm=5.05926786e-03
# iteration 808 | loss=0.78845637 | grad_norm=5.05650835e-03
# iteration 809 | loss=0.78836852 | grad_norm=5.05392626e-03
# iteration 810 | loss=0.78827636 | grad_norm=5.05107408e-03
# iteration 811 | loss=0.78818781 | grad_norm=5.04836952e-03
# iteration 812 | loss=0.78809706 | grad_norm=5.04562166e-03
# iteration 813 | loss=0.78800868 | grad_norm=5.04309032e-03
# iteration 814 | loss=0.78791760 | grad_norm=5.04026469e-03
# iteration 815 | loss=0.78782984 | grad_norm=5.03765140e-03
# iteration 816 | loss=0.78773913 | grad_norm=5.03475172e-03
# iteration 817 | loss=0.78765108 | grad_norm=5.03225857e-03
# iteration 818 | loss=0.78756053 | grad_norm=5.02949068e-03
# iteration 819 | loss=0.78747259 | grad_norm=5.02686854e-03
# iteration 820 | loss=0.78738145 | grad_norm=5.02407271e-03
# iteration 821 | loss=0.78729344 | grad_norm=5.02145523e-03
# iteration 822 | loss=0.78720289 | grad_norm=5.01871761e-03
# iteration 823 | loss=0.78711483 | grad_norm=5.01620350e-03
# iteration 824 | loss=0.78702558 | grad_norm=5.01340721e-03
# iteration 825 | loss=0.78693734 | grad_norm=5.01078367e-03
# iteration 826 | loss=0.78684774 | grad_norm=5.00800926e-03
# iteration 827 | loss=0.78675800 | grad_norm=5.00528933e-03
# iteration 828 | loss=0.78666909 | grad_norm=5.00269840e-03
# iteration 829 | loss=0.78658018 | grad_norm=4.99999430e-03
# iteration 830 | loss=0.78649216 | grad_norm=4.99732140e-03
# iteration 831 | loss=0.78640170 | grad_norm=4.99456376e-03
# iteration 832 | loss=0.78631374 | grad_norm=4.99197142e-03
# iteration 833 | loss=0.78622542 | grad_norm=4.98931389e-03
# iteration 834 | loss=0.78613524 | grad_norm=4.98666568e-03
# iteration 835 | loss=0.78604668 | grad_norm=4.98393551e-03
# iteration 836 | loss=0.78595970 | grad_norm=4.98143211e-03
# iteration 837 | loss=0.78586914 | grad_norm=4.97859111e-03
# iteration 838 | loss=0.78578154 | grad_norm=4.97603370e-03
# iteration 839 | loss=0.78569172 | grad_norm=4.97336686e-03
# iteration 840 | loss=0.78560402 | grad_norm=4.97074891e-03
# iteration 841 | loss=0.78551467 | grad_norm=4.96808439e-03
# iteration 842 | loss=0.78542672 | grad_norm=4.96551488e-03
# iteration 843 | loss=0.78533971 | grad_norm=4.96290158e-03
# iteration 844 | loss=0.78524943 | grad_norm=4.96005360e-03
# iteration 845 | loss=0.78516115 | grad_norm=4.95749246e-03
# iteration 846 | loss=0.78507422 | grad_norm=4.95487824e-03
# iteration 847 | loss=0.78498429 | grad_norm=4.95216111e-03
# iteration 848 | loss=0.78489643 | grad_norm=4.94964281e-03
# iteration 849 | loss=0.78480792 | grad_norm=4.94697271e-03
# iteration 850 | loss=0.78472000 | grad_norm=4.94435383e-03
# iteration 851 | loss=0.78463086 | grad_norm=4.94164275e-03
# iteration 852 | loss=0.78454414 | grad_norm=4.93911933e-03
# iteration 853 | loss=0.78445517 | grad_norm=4.93639382e-03
# iteration 854 | loss=0.78436710 | grad_norm=4.93378192e-03
# iteration 855 | loss=0.78428073 | grad_norm=4.93122591e-03
# iteration 856 | loss=0.78419052 | grad_norm=4.92846267e-03
# iteration 857 | loss=0.78410348 | grad_norm=4.92583727e-03
# iteration 858 | loss=0.78401465 | grad_norm=4.92329244e-03
# iteration 859 | loss=0.78392806 | grad_norm=4.92072664e-03
# iteration 860 | loss=0.78383906 | grad_norm=4.91802348e-03
# iteration 861 | loss=0.78375145 | grad_norm=4.91545163e-03
# iteration 862 | loss=0.78366604 | grad_norm=4.91291750e-03
# iteration 863 | loss=0.78357572 | grad_norm=4.91020922e-03
# iteration 864 | loss=0.78348892 | grad_norm=4.90760570e-03
# iteration 865 | loss=0.78339960 | grad_norm=4.90501709e-03
# iteration 866 | loss=0.78331351 | grad_norm=4.90255747e-03
# iteration 867 | loss=0.78322451 | grad_norm=4.89968387e-03
# iteration 868 | loss=0.78313752 | grad_norm=4.89714602e-03
# iteration 869 | loss=0.78304965 | grad_norm=4.89452388e-03
# iteration 870 | loss=0.78296275 | grad_norm=4.89202188e-03
# iteration 871 | loss=0.78287387 | grad_norm=4.88937180e-03
# iteration 872 | loss=0.78278749 | grad_norm=4.88687446e-03
# iteration 873 | loss=0.78269916 | grad_norm=4.88421461e-03
# iteration 874 | loss=0.78261306 | grad_norm=4.88172192e-03
# iteration 875 | loss=0.78252505 | grad_norm=4.87916498e-03
# iteration 876 | loss=0.78243852 | grad_norm=4.87661967e-03
# iteration 877 | loss=0.78234996 | grad_norm=4.87390440e-03
# iteration 878 | loss=0.78226260 | grad_norm=4.87130554e-03
# iteration 879 | loss=0.78217551 | grad_norm=4.86870483e-03
# iteration 880 | loss=0.78209000 | grad_norm=4.86617070e-03
# iteration 881 | loss=0.78200072 | grad_norm=4.86344192e-03
# iteration 882 | loss=0.78191458 | grad_norm=4.86095669e-03
# iteration 883 | loss=0.78182687 | grad_norm=4.85838670e-03
# iteration 884 | loss=0.78173920 | grad_norm=4.85574873e-03
# iteration 885 | loss=0.78165399 | grad_norm=4.85331751e-03
# iteration 886 | loss=0.78156587 | grad_norm=4.85069584e-03
# iteration 887 | loss=0.78147992 | grad_norm=4.84821526e-03
# iteration 888 | loss=0.78139178 | grad_norm=4.84557264e-03
# iteration 889 | loss=0.78130546 | grad_norm=4.84307995e-03
# iteration 890 | loss=0.78121822 | grad_norm=4.84051742e-03
# iteration 891 | loss=0.78113307 | grad_norm=4.83805453e-03
# iteration 892 | loss=0.78104409 | grad_norm=4.83530154e-03
# iteration 893 | loss=0.78095873 | grad_norm=4.83287871e-03
# iteration 894 | loss=0.78087061 | grad_norm=4.83024400e-03
# iteration 895 | loss=0.78078470 | grad_norm=4.82769962e-03
# iteration 896 | loss=0.78069709 | grad_norm=4.82512871e-03
# iteration 897 | loss=0.78061200 | grad_norm=4.82264301e-03
# iteration 898 | loss=0.78052422 | grad_norm=4.82000923e-03
# iteration 899 | loss=0.78043880 | grad_norm=4.81758127e-03
# iteration 900 | loss=0.78035093 | grad_norm=4.81491862e-03
# iteration 901 | loss=0.78026607 | grad_norm=4.81252419e-03
# iteration 902 | loss=0.78017840 | grad_norm=4.80986247e-03
# iteration 903 | loss=0.78009245 | grad_norm=4.80745081e-03
# iteration 904 | loss=0.78000519 | grad_norm=4.80487850e-03
# iteration 905 | loss=0.77992021 | grad_norm=4.80239186e-03
# iteration 906 | loss=0.77983235 | grad_norm=4.79971757e-03
# iteration 907 | loss=0.77974762 | grad_norm=4.79728635e-03
# iteration 908 | loss=0.77965979 | grad_norm=4.79463721e-03
# iteration 909 | loss=0.77957573 | grad_norm=4.79233079e-03
# iteration 910 | loss=0.77948787 | grad_norm=4.78964066e-03
# iteration 911 | loss=0.77940269 | grad_norm=4.78726532e-03
# iteration 912 | loss=0.77931496 | grad_norm=4.78466414e-03
# iteration 913 | loss=0.77923102 | grad_norm=4.78223665e-03
# iteration 914 | loss=0.77914328 | grad_norm=4.77966340e-03
# iteration 915 | loss=0.77905820 | grad_norm=4.77720657e-03
# iteration 916 | loss=0.77897056 | grad_norm=4.77463752e-03
# iteration 917 | loss=0.77888658 | grad_norm=4.77229338e-03
# iteration 918 | loss=0.77879937 | grad_norm=4.76955157e-03
# iteration 919 | loss=0.77871514 | grad_norm=4.76717856e-03
# iteration 920 | loss=0.77862738 | grad_norm=4.76452755e-03
# iteration 921 | loss=0.77854263 | grad_norm=4.76217130e-03
# iteration 922 | loss=0.77845528 | grad_norm=4.75948630e-03
# iteration 923 | loss=0.77837147 | grad_norm=4.75716498e-03
# iteration 924 | loss=0.77828459 | grad_norm=4.75459686e-03
# iteration 925 | loss=0.77820003 | grad_norm=4.75213071e-03
# iteration 926 | loss=0.77811298 | grad_norm=4.74951835e-03
# iteration 927 | loss=0.77802933 | grad_norm=4.74716816e-03
# iteration 928 | loss=0.77794145 | grad_norm=4.74448502e-03
# iteration 929 | loss=0.77785774 | grad_norm=4.74214600e-03
# iteration 930 | loss=0.77777084 | grad_norm=4.73951828e-03
# iteration 931 | loss=0.77768638 | grad_norm=4.73710243e-03
# iteration 932 | loss=0.77759954 | grad_norm=4.73456923e-03
# iteration 933 | loss=0.77751384 | grad_norm=4.73211892e-03
# iteration 934 | loss=0.77743031 | grad_norm=4.72971518e-03
# iteration 935 | loss=0.77734344 | grad_norm=4.72709257e-03
# iteration 936 | loss=0.77725867 | grad_norm=4.72468277e-03
# iteration 937 | loss=0.77717263 | grad_norm=4.72226599e-03
# iteration 938 | loss=0.77708975 | grad_norm=4.71990230e-03
# iteration 939 | loss=0.77700173 | grad_norm=4.71721962e-03
# iteration 940 | loss=0.77691807 | grad_norm=4.71490854e-03
# iteration 941 | loss=0.77683161 | grad_norm=4.71235299e-03
# iteration 942 | loss=0.77674778 | grad_norm=4.70993202e-03
# iteration 943 | loss=0.77666171 | grad_norm=4.70744958e-03
# iteration 944 | loss=0.77657771 | grad_norm=4.70508076e-03
# iteration 945 | loss=0.77649147 | grad_norm=4.70245909e-03
# iteration 946 | loss=0.77640811 | grad_norm=4.70009306e-03
# iteration 947 | loss=0.77632143 | grad_norm=4.69759712e-03
# iteration 948 | loss=0.77623628 | grad_norm=4.69510397e-03
# iteration 949 | loss=0.77615138 | grad_norm=4.69259685e-03
# iteration 950 | loss=0.77606860 | grad_norm=4.69030952e-03
# iteration 951 | loss=0.77598134 | grad_norm=4.68760962e-03
# iteration 952 | loss=0.77589777 | grad_norm=4.68517374e-03
# iteration 953 | loss=0.77581245 | grad_norm=4.68268665e-03
# iteration 954 | loss=0.77572801 | grad_norm=4.68038209e-03
# iteration 955 | loss=0.77564257 | grad_norm=4.67781909e-03
# iteration 956 | loss=0.77555888 | grad_norm=4.67548380e-03
# iteration 957 | loss=0.77547295 | grad_norm=4.67299577e-03
# iteration 958 | loss=0.77539032 | grad_norm=4.67067724e-03
# iteration 959 | loss=0.77530418 | grad_norm=4.66810726e-03
# iteration 960 | loss=0.77522026 | grad_norm=4.66569187e-03
# iteration 961 | loss=0.77513449 | grad_norm=4.66319639e-03
# iteration 962 | loss=0.77505159 | grad_norm=4.66089463e-03
# iteration 963 | loss=0.77496568 | grad_norm=4.65839729e-03
# iteration 964 | loss=0.77488292 | grad_norm=4.65602800e-03
# iteration 965 | loss=0.77479757 | grad_norm=4.65348084e-03
# iteration 966 | loss=0.77471375 | grad_norm=4.65110503e-03
# iteration 967 | loss=0.77462866 | grad_norm=4.64857323e-03
# iteration 968 | loss=0.77454386 | grad_norm=4.64617414e-03
# iteration 969 | loss=0.77445966 | grad_norm=4.64382814e-03
# iteration 970 | loss=0.77437531 | grad_norm=4.64131916e-03
# iteration 971 | loss=0.77429141 | grad_norm=4.63890098e-03
# iteration 972 | loss=0.77420795 | grad_norm=4.63656336e-03
# iteration 973 | loss=0.77412249 | grad_norm=4.63400176e-03
# iteration 974 | loss=0.77403852 | grad_norm=4.63172654e-03
# iteration 975 | loss=0.77395405 | grad_norm=4.62926552e-03
# iteration 976 | loss=0.77387010 | grad_norm=4.62685060e-03
# iteration 977 | loss=0.77378729 | grad_norm=4.62454231e-03
# iteration 978 | loss=0.77370260 | grad_norm=4.62205289e-03
# iteration 979 | loss=0.77362012 | grad_norm=4.61971620e-03
# iteration 980 | loss=0.77353486 | grad_norm=4.61713830e-03
# iteration 981 | loss=0.77345049 | grad_norm=4.61469870e-03
# iteration 982 | loss=0.77336683 | grad_norm=4.61234665e-03
# iteration 983 | loss=0.77328524 | grad_norm=4.61007748e-03
# iteration 984 | loss=0.77319941 | grad_norm=4.60752891e-03
# iteration 985 | loss=0.77311515 | grad_norm=4.60520294e-03
# iteration 986 | loss=0.77303176 | grad_norm=4.60288348e-03
# iteration 987 | loss=0.77294906 | grad_norm=4.60047927e-03
# iteration 988 | loss=0.77286412 | grad_norm=4.59795771e-03
# iteration 989 | loss=0.77278144 | grad_norm=4.59568296e-03
# iteration 990 | loss=0.77269729 | grad_norm=4.59316326e-03
# iteration 991 | loss=0.77261447 | grad_norm=4.59087268e-03
# iteration 992 | loss=0.77252984 | grad_norm=4.58836509e-03
# iteration 993 | loss=0.77244809 | grad_norm=4.58609033e-03
# iteration 994 | loss=0.77236278 | grad_norm=4.58361302e-03
# iteration 995 | loss=0.77228059 | grad_norm=4.58130892e-03
# iteration 996 | loss=0.77219603 | grad_norm=4.57889074e-03
# iteration 997 | loss=0.77211224 | grad_norm=4.57653776e-03
# iteration 998 | loss=0.77202906 | grad_norm=4.57410188e-03
# iteration 999 | loss=0.77194590 | grad_norm=4.57172329e-03
# CPU times: user 3min 4s, sys: 16.1 s, total: 3min 20s
# Wall time: 3min 22s

# %%
pv_mesh.point_data['E'] = E_values.detach().cpu().numpy()
pv_mesh
# Out:
# UnstructuredGrid (0x14d77cb0d660)
#   N Cells:    88042
#   N Points:   17314
#   X Bounds:   -1.421e+02, 9.507e+01
#   Y Bounds:   7.690e+01, 2.581e+02
#   Z Bounds:   -2.651e+02, -5.242e+01
#   N Arrays:   10

# %%
p = pv.Plotter()
p.add_volume(
    pv_mesh,
    scalars='E',
    cmap='jet',
    opacity=0.05,
    clim=(0, 1e4)
)
p.show()
# Out:
# Widget(value='<iframe id="pyvista-jupyter_trame__template_P_0x14d5fb3e0350_17" src="https://ondemand.bridges2.…
