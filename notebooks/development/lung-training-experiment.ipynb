# %%
# %matplotlib notebook
# %load_ext autoreload
# %pwd
# Out:
# '/ocean/projects/asc170022p/mtragoza/lung-project/notebooks'

# %%
import sys
import pandas as pd
sys.path.append('../../param_search')
import param_search as ps

# %% [markdown]
# ## Setup experiment
#
# [[Setup](#Setup-experiment)] [[Submit](#Submit-jobs)] [[Monitor](#Monitor-jobs)] [[Analyze](#Analyze-results)]

# %%
# define a job template and name format
template = '''\
#!/bin/bash
#SBATCH --job-name={job_name}
#SBATCH --account=bio170034p
#SBATCH --partition=BatComputer
#SBATCH --gres=gpu:rtx6000:1
#SBATCH -x v034
#SBATCH --time=48:00:00
#SBATCH -o %J.stdout
#SBATCH -e %J.stderr
#SBATCH --mail-type=all

# {set_name}

hostname
pwd
module load anaconda3
conda activate /ocean/projects/asc170022p/mtragoza/mambaforge/envs/lung-project
nvidia-smi

python ../../../train.py \\
    --data_root ../../../data/Emory-4DCT \\
    --mesh_radius {mesh_radius} \\
    --interp_radius {interp_radius} \\
    --interp_sigma {interp_sigma} \\
    --output_func {output_func} \\
    --batch_size {batch_size} \\
    --save_prefix {job_name} 

echo Done
'''
name_format = 'train__{set_name}__{mesh_radius}__{interp_radius}__{interp_sigma}__{output_func}__{batch_size}'

# %%
param_space = ps.ParamSpace(
    set_name='mesh_radius',
    mesh_radius=[20, 10, 5],
    interp_radius=[20],
    interp_sigma=[10],
    output_func=['exp'],
    batch_size=[4],
) + \
ps.ParamSpace(
    set_name='interp_radius',
    mesh_radius=[20],
    interp_radius=[20, 10, 5],
    interp_sigma=[10],
    output_func=['exp'],
    batch_size=[4],
) + \
ps.ParamSpace(
    set_name='interp_sigma',
    mesh_radius=[20],
    interp_radius=[20],
    interp_sigma=[20, 10, 5],
    output_func=['exp'],
    batch_size=[4], 
) + \
ps.ParamSpace(
    set_name='output_func',
    mesh_radius=[20],
    interp_radius=[20],
    interp_sigma=[10],
    output_func=['exp', 'splus', 'relu', 'id'],
    batch_size=[4],    
) + \
ps.ParamSpace(
    set_name='batch_size',
    mesh_radius=[20],
    interp_radius=[20],
    interp_sigma=[10],
    output_func=['exp'],
    batch_size=[2, 4, 8, 16],
)

for p in param_space:
    print(name_format.format(**p))

print(len(param_space))
# Out:
# train__mesh_radius__20__20__10__exp__4
# train__mesh_radius__10__20__10__exp__4
# train__mesh_radius__5__20__10__exp__4
# train__interp_radius__20__20__10__exp__4
# train__interp_radius__20__10__10__exp__4
# train__interp_radius__20__5__10__exp__4
# train__interp_sigma__20__20__20__exp__4
# train__interp_sigma__20__20__10__exp__4
# train__interp_sigma__20__20__5__exp__4
# train__output_func__20__20__10__exp__4
# train__output_func__20__20__10__splus__4
# train__output_func__20__20__10__relu__4
# train__output_func__20__20__10__id__4
# train__batch_size__20__20__10__exp__2
# train__batch_size__20__20__10__exp__4
# train__batch_size__20__20__10__exp__8
# train__batch_size__20__20__10__exp__16
# 17

# %% [markdown]
# ## Submit jobs
#
# [[Setup](#Setup-experiment)] [[Submit](#Submit-jobs)] [[Monitor](#Monitor-jobs)] [[Analyze](#Analyze-results)]

# %%
expt_name = ['2024-09-30__initial'][-1]

# %%
do_submit = False
if do_submit:
    jobs = ps.submit(template, name_format, param_space, work_dir=expt_name)
    jobs.to_csv(f'{expt_name}.jobs')

# %% [markdown]
# ## Monitor jobs
#
# [[Setup](#Setup-experiment)] [[Submit](#Submit-jobs)] [[Monitor](#Monitor-jobs)] [[Analyze](#Analyze-results)]

# %%
jobs = pd.read_csv(f'{expt_name}.jobs', index_col=0)
status = ps.status(jobs, parse_stderr=True)
status
# Out:
#           index       set_name  mesh_radius  interp_radius  interp_sigma  \
# job_id
# 26075131      0    mesh_radius           20             20            10
# 26075132      1    mesh_radius           10             20            10
# 26075133      2    mesh_radius            5             20            10
# 26075134      3  interp_radius           20             20            10
# 26075135      4  interp_radius           20             10            10
# 26075136      5  interp_radius           20              5            10
# 26075137      6   interp_sigma           20             20            20
# 26075138      7   interp_sigma           20             20            10
# 26075139      8   interp_sigma           20             20             5
# 26075140      9    output_func           20             20            10
# 26075141     10    output_func           20             20            10
# 26075142     11    output_func           20             20            10
# 26075143     12    output_func           20             20            10
# 26075144     13     batch_size           20             20            10
# 26075145     14     batch_size           20             20            10
# 26075146     15     batch_size           20             20            10
# 26075147     16     batch_size           20             20            10
#
#          output_func  batch_size                                  job_name  \
# job_id
# 26075131         exp           4    train__mesh_radius__20__20__10__exp__4
# 26075132         exp           4    train__mesh_radius__10__20__10__exp__4
# 26075133         exp           4     train__mesh_radius__5__20__10__exp__4
# 26075134         exp           4  train__interp_radius__20__20__10__exp__4
# 26075135         exp           4  train__interp_radius__20__10__10__exp__4
# 26075136         exp           4   train__interp_radius__20__5__10__exp__4
# 26075137         exp           4   train__interp_sigma__20__20__20__exp__4
# 26075138         exp           4   train__interp_sigma__20__20__10__exp__4
# 26075139         exp           4    train__interp_sigma__20__20__5__exp__4
# 26075140         exp           4    train__output_func__20__20__10__exp__4
# 26075141       splus           4  train__output_func__20__20__10__splus__4
# 26075142        relu           4   train__output_func__20__20__10__relu__4
# 26075143          id           4     train__output_func__20__20__10__id__4
# 26075144         exp           2     train__batch_size__20__20__10__exp__2
# 26075145         exp           4     train__batch_size__20__20__10__exp__4
# 26075146         exp           8     train__batch_size__20__20__10__exp__8
# 26075147         exp          16    train__batch_size__20__20__10__exp__16
#
#             partition  job_state  node_id  runtime  \
# job_id
# 26075131  BatComputer        NaN      NaN      NaN
# 26075132  BatComputer        NaN      NaN      NaN
# 26075133  BatComputer        NaN      NaN      NaN
# 26075134  BatComputer        NaN      NaN      NaN
# 26075135  BatComputer        NaN      NaN      NaN
# 26075136  BatComputer        NaN      NaN      NaN
# 26075137  BatComputer        NaN      NaN      NaN
# 26075138  BatComputer        NaN      NaN      NaN
# 26075139  BatComputer        NaN      NaN      NaN
# 26075140  BatComputer        NaN      NaN      NaN
# 26075141  BatComputer        NaN      NaN      NaN
# 26075142  BatComputer        NaN      NaN      NaN
# 26075143  BatComputer        NaN      NaN      NaN
# 26075144  BatComputer        NaN      NaN      NaN
# 26075145  BatComputer        NaN      NaN      NaN
# 26075146  BatComputer        NaN      NaN      NaN
# 26075147  BatComputer        NaN      NaN      NaN
#
#                                                    work_dir  array_idx  \
# job_id
# 26075131  /ocean/projects/asc170022p/mtragoza/lung-proje...        NaN
# 26075132  /ocean/projects/asc170022p/mtragoza/lung-proje...        NaN
# 26075133  /ocean/projects/asc170022p/mtragoza/lung-proje...        NaN
# 26075134  /ocean/projects/asc170022p/mtragoza/lung-proje...        NaN
# 26075135  /ocean/projects/asc170022p/mtragoza/lung-proje...        NaN
# 26075136  /ocean/projects/asc170022p/mtragoza/lung-proje...        NaN
# 26075137  /ocean/projects/asc170022p/mtragoza/lung-proje...        NaN
# 26075138  /ocean/projects/asc170022p/mtragoza/lung-proje...        NaN
# 26075139  /ocean/projects/asc170022p/mtragoza/lung-proje...        NaN
# 26075140  /ocean/projects/asc170022p/mtragoza/lung-proje...        NaN
# 26075141  /ocean/projects/asc170022p/mtragoza/lung-proje...        NaN
# 26075142  /ocean/projects/asc170022p/mtragoza/lung-proje...        NaN
# 26075143  /ocean/projects/asc170022p/mtragoza/lung-proje...        NaN
# 26075144  /ocean/projects/asc170022p/mtragoza/lung-proje...        NaN
# 26075145  /ocean/projects/asc170022p/mtragoza/lung-proje...        NaN
# 26075146  /ocean/projects/asc170022p/mtragoza/lung-proje...        NaN
# 26075147  /ocean/projects/asc170022p/mtragoza/lung-proje...        NaN
#
#                                                      stdout  \
# job_id
# 26075131  dv004.ib.bridges2.psc.edu\n/ocean/projects/asc...
# 26075132  dv004.ib.bridges2.psc.edu\n/ocean/projects/asc...
# 26075133  dv004.ib.bridges2.psc.edu\n/ocean/projects/asc...
# 26075134  dv004.ib.bridges2.psc.edu\n/ocean/projects/asc...
# 26075135  dv004.ib.bridges2.psc.edu\n/ocean/projects/asc...
# 26075136  dv004.ib.bridges2.psc.edu\n/ocean/projects/asc...
# 26075137  dv004.ib.bridges2.psc.edu\n/ocean/projects/asc...
# 26075138  dv004.ib.bridges2.psc.edu\n/ocean/projects/asc...
# 26075139  dv004.ib.bridges2.psc.edu\n/ocean/projects/asc...
# 26075140  dv004.ib.bridges2.psc.edu\n/ocean/projects/asc...
# 26075141  dv004.ib.bridges2.psc.edu\n/ocean/projects/asc...
# 26075142  dv004.ib.bridges2.psc.edu\n/ocean/projects/asc...
# 26075143  dv004.ib.bridges2.psc.edu\n/ocean/projects/asc...
# 26075144  dv004.ib.bridges2.psc.edu\n/ocean/projects/asc...
# 26075145  dv004.ib.bridges2.psc.edu\n/ocean/projects/asc...
# 26075146  dv004.ib.bridges2.psc.edu\n/ocean/projects/asc...
# 26075147  dv004.ib.bridges2.psc.edu\n/ocean/projects/asc...
#
#                                                      stderr
# job_id
# 26075131
# 26075132
# 26075133  torch.OutOfMemoryError: CUDA out of memory. Tr...
# 26075134
# 26075135
# 26075136
# 26075137
# 26075138
# 26075139
# 26075140
# 26075141
# 26075142
# 26075143
# 26075144
# 26075145
# 26075146
# 26075147  torch.OutOfMemoryError: CUDA out of memory. Tr...

# %%
status['job_state'] = status['job_state'].fillna('DONE')
status['stderr'] = status['stderr'].fillna('N/A')
status.groupby(['job_state', 'set_name', 'mesh_radius', 'batch_size', 'stderr'])[['job_name']].count()
# Out:
#                                                                                                    job_name
# job_state set_name      mesh_radius batch_size stderr
# DONE      batch_size    20          2                                                                     1
#                                     4                                                                     1
#                                     8                                                                     1
#                                     16         torch.OutOfMemoryError: CUDA out of memory. Tri...         1
#           interp_radius 20          4                                                                     3
#           interp_sigma  20          4                                                                     3
#           mesh_radius   5           4          torch.OutOfMemoryError: CUDA out of memory. Tri...         1
#                         10          4                                                                     1
#                         20          4                                                                     1
#           output_func   20          4                                                                     4

# %%
print(status.iloc[0].stderr)

# %% [markdown]
# ## Analyze results
#
# [[Setup](#Setup-experiment)] [[Submit](#Submit-jobs)] [[Monitor](#Monitor-jobs)] [[Analyze](#Analyze-results)]

# %%
m = ps.metrics(jobs, sep=',')
m
# Out:
# train__mesh_radius__5__20__10__exp__4 No objects to concatenate
# train__batch_size__20__20__10__exp__16 No objects to concatenate
#            set_name  mesh_radius  interp_radius  interp_sigma output_func  \
# 0       mesh_radius           20             20            10         exp
# 1       mesh_radius           20             20            10         exp
# 2       mesh_radius           20             20            10         exp
# 3       mesh_radius           20             20            10         exp
# 4       mesh_radius           20             20            10         exp
# ...             ...          ...            ...           ...         ...
# 137995   batch_size           20             20            10         exp
# 137996   batch_size           20             20            10         exp
# 137997   batch_size           20             20            10         exp
# 137998   batch_size           20             20            10         exp
# 137999   batch_size           20             20            10         exp
#
#         batch_size                                job_name    job_id  \
# 0                4  train__mesh_radius__20__20__10__exp__4  26075131
# 1                4  train__mesh_radius__20__20__10__exp__4  26075131
# 2                4  train__mesh_radius__20__20__10__exp__4  26075131
# 3                4  train__mesh_radius__20__20__10__exp__4  26075131
# 4                4  train__mesh_radius__20__20__10__exp__4  26075131
# ...            ...                                     ...       ...
# 137995           8   train__batch_size__20__20__10__exp__8  26075146
# 137996           8   train__batch_size__20__20__10__exp__8  26075146
# 137997           8   train__batch_size__20__20__10__exp__8  26075146
# 137998           8   train__batch_size__20__20__10__exp__8  26075146
# 137999           8   train__batch_size__20__20__10__exp__8  26075146
#
#           partition job_state  ...  phase    rep      loss  u_pred_norm  \
# 0       BatComputer   PENDING  ...  train   dofs  0.246343     0.226050
# 1       BatComputer   PENDING  ...  train   dofs  0.101552     0.541731
# 2       BatComputer   PENDING  ...  train   dofs  0.153421     1.291163
# 3       BatComputer   PENDING  ...  train   dofs  0.273858     0.141077
# 4       BatComputer   PENDING  ...  train   dofs  0.452430     0.372193
# ...             ...       ...  ...    ...    ...       ...          ...
# 137995  BatComputer   PENDING  ...  train   dofs  0.127933     1.994515
# 137996  BatComputer   PENDING  ...  train   dofs  0.374313     0.424955
# 137997  BatComputer   PENDING  ...  train   dofs  0.073391     0.748812
# 137998  BatComputer   PENDING  ...   test   dofs  0.117991     0.594863
# 137999  BatComputer   PENDING  ...   test  image  0.702556     0.549928
#
#         u_true_norm  mu_pred_norm mu_anat_corr mu_950_corr mu_900_corr  \
# 0          0.241047    780.979664    -0.357459         NaN         NaN
# 1          0.567068    781.189805    -0.355259         NaN         NaN
# 2          1.279831    781.643284    -0.260387         NaN         NaN
# 3          0.159659    789.292131    -0.480058         NaN         NaN
# 4          0.361809    784.905511    -0.444934         NaN         NaN
# ...             ...           ...          ...         ...         ...
# 137995     2.161982    670.097037     0.414179         NaN         NaN
# 137996     0.453780    672.724714     0.594555         NaN         NaN
# 137997     0.864216    672.764159     0.394303         NaN         NaN
# 137998     0.683685    660.778545     0.487578         NaN         NaN
# 137999     0.783334    532.015930     0.114413   -0.000261   -0.046578
#
#         mu_850_corr
# 0               NaN
# 1               NaN
# 2               NaN
# 3               NaN
# 4               NaN
# ...             ...
# 137995    -0.107164
# 137996          NaN
# 137997          NaN
# 137998    -0.105356
# 137999    -0.115920
#
# [138000 rows x 27 columns]

# %%
d = m.groupby(['job_name'])[['epoch']].max()
d
# Out:
#                                           epoch
# job_name
# train__batch_size__20__20__10__exp__2       100
# train__batch_size__20__20__10__exp__4       100
# train__batch_size__20__20__10__exp__8       100
# train__interp_radius__20__10__10__exp__4    100
# train__interp_radius__20__20__10__exp__4    100
# train__interp_radius__20__5__10__exp__4     100
# train__interp_sigma__20__20__10__exp__4     100
# train__interp_sigma__20__20__20__exp__4     100
# train__interp_sigma__20__20__5__exp__4      100
# train__mesh_radius__10__20__10__exp__4      100
# train__mesh_radius__20__20__10__exp__4      100
# train__output_func__20__20__10__exp__4      100
# train__output_func__20__20__10__id__4       100
# train__output_func__20__20__10__relu__4     100
# train__output_func__20__20__10__splus__4    100

# %%
unfinished_jobs = d[d.epoch < 100]
unfinished_jobs
# Out:
# Empty DataFrame
# Columns: [epoch]
# Index: []

# %%
# %autoreload
fig = ps.plot(
    m[(m.phase == 'train') & (m.epoch > 90) & (m.output_func != 'id')],
    x=['batch_size', 'interp_radius', 'interp_sigma', 'mesh_radius', 'output_func'],
    y=['loss', 'mu_anat_corr'],
    hue=False,
    legend=True,
    legend_kws=dict(bbox_to_anchor=(0, -0.2)),
    tight=True,
)
# Out:
# <img src="data:image/png;base64,..." width="1500">

# %%
# %autoreload
fig = ps.plot(
    m[(m.phase == 'train')],
    x=['image_size', 'n_nodes', 'batch_size'],
    y=['t_model', 't_loss', 't_grad', 't_optim'],
    legend=True,
    legend_kws=dict(bbox_to_anchor=(0, -0.2)),
    tight=True
)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[17], line 2
#       1 get_ipython().run_line_magic('autoreload', '')
# ----> 2 fig = ps.plot(
#       3     m[(m.phase == 'train')],
#       4     x=['image_size', 'n_nodes', 'batch_size'],
#       5     y=['t_model', 't_loss', 't_grad', 't_optim'],
#       6     legend=True,
#       7     legend_kws=dict(bbox_to_anchor=(0, -0.2)),
#       8     tight=True
#       9 )
#
# File /ocean/projects/asc170022p/mtragoza/lung-project/notebooks/../../param_search/param_search/results.py:68, in plot(df, x, y, hue, grouped, block, block_levels, block_orient, height, width, n_cols, xlim, ylim, plot_func, plot_kws, legend, legend_row, legend_col, legend_kws, verbose, tight, gridspec_kws)
#      66     grouped_hues = dict()
#      67     for i, x_i in enumerate(x):
# ---> 68         grouped_hues[x_i] = add_group_column(
#      69             df, [h_j for h_j in hue if h_j != x_i],
#      70             verbose=verbose
#      71         )
#      73 elif non_string_iterable(hue):
#      74     hue = add_group_column(df, list(hue), verbose=verbose)
#
# File /ocean/projects/asc170022p/mtragoza/lung-project/notebooks/../../param_search/param_search/results.py:249, in add_group_column(df, group_cols, sep, verbose)
#     246     print(f'Adding group column {repr(group_name)}')
#     248 pd.options.mode.chained_assignment = None
# --> 249 df[group_name] = df[group_cols].astype(str).agg(sep.join, axis=1)
#     250 pd.options.mode.chained_assignment = 'warn'
#     251 return group_name
#
# File /ocean/projects/asc170022p/mtragoza/mambaforge/envs/lung-project/lib/python3.10/site-packages/pandas/core/frame.py:4108, in DataFrame.__getitem__(self, key)
#    4106     if is_iterator(key):
#    4107         key = list(key)
# -> 4108     indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    4110 # take() does not accept boolean indexers
#    4111 if getattr(indexer, "dtype", None) == bool:
#
# File /ocean/projects/asc170022p/mtragoza/mambaforge/envs/lung-project/lib/python3.10/site-packages/pandas/core/indexes/base.py:6200, in Index._get_indexer_strict(self, key, axis_name)
#    6197 else:
#    6198     keyarr, indexer, new_indexer = self._reindex_non_unique(keyarr)
# -> 6200 self._raise_if_missing(keyarr, indexer, axis_name)
#    6202 keyarr = self.take(indexer)
#    6203 if isinstance(key, Index):
#    6204     # GH 42790 - Preserve name from an Index
#
# File /ocean/projects/asc170022p/mtragoza/mambaforge/envs/lung-project/lib/python3.10/site-packages/pandas/core/indexes/base.py:6252, in Index._raise_if_missing(self, key, indexer, axis_name)
#    6249     raise KeyError(f"None of [{key}] are in the [{axis_name}]")
#    6251 not_found = list(ensure_index(key)[missing_mask.nonzero()[0]].unique())
# -> 6252 raise KeyError(f"{not_found} not in index")
#
# KeyError: "['n_nodes'] not in index"
